# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('paper')
sns.set_style('white')

# %%
import configs

# %%
lstm_confs = configs.get_x_configs('CharLSTM', 324)

# %%
import pandas as pd
df = pd.DataFrame(lstm_confs)

# %%
df.iloc[:100].optimizer.value_counts()
# Out:
# SGD    100
# Name: optimizer, dtype: int64

# %%
df.iloc[:100].lstm_layer.value_counts()
# Out:
# 1    51
# 2    49
# Name: lstm_layer, dtype: int64

# %%
df.iloc[:100].batch_size.value_counts()
# Out:
# 8    54
# 1    46
# Name: batch_size, dtype: int64

# %%
cnn_confs = configs.get_x_configs('CharCNN', 972)

# %%
cdf = pd.DataFrame(cnn_confs)

# %%
cdf.iloc[:100].optimizer.value_counts()
# Out:
# SGD    100
# Name: optimizer, dtype: int64

# %%
cdf.iloc[:100].lstm_layer.value_counts()
# Out:
# 1    54
# 2    46
# Name: lstm_layer, dtype: int64

# %%
cdf.iloc[:100].batch_size.value_counts()
# Out:
# 1    53
# 8    47
# Name: batch_size, dtype: int64

# %%
import os

# %%
os.mkdir('hp_search/models2')

# %%
os.mkdir('hp_search/conf2')

# %%
os.mkdir('hp_search/conf_json2')

# %% [raw]
# import json
#
# max_digits = len(str(len(lstm_confs)))
# full_confs = []
# for i, conf in enumerate(lstm_confs):
#     fc = configs.create_conf_file(f'hp_search/conf2/morph_charlstm.{str(i).zfill(max_digits)}.conf',
#                              f'hp_search/models2/morph_charlstm.{str(i).zfill(max_digits)}.model',
#                              'gold_morpheme',
#                              conf,
#                              'alt_tok_yap_ft_sg')
#     full_confs.append(fc)
#
# for i, fc in enumerate(full_confs):
#     with open( f'hp_search/conf_json2/morph_charlstm.{str(i).zfill(max_digits)}.json', 'w') as of:
#         of.write(json.dumps(fc))

# %% [raw]
# max_digits = len(str(len(cnn_confs)))
# full_confs = []
# for i, conf in enumerate(cnn_confs):
#     fc = configs.create_conf_file(f'hp_search/conf2/morph_charcnn.{str(i).zfill(max_digits)}.conf',
#                              f'hp_search/models2/morph_charcnn.{str(i).zfill(max_digits)}.model',
#                              'gold_morpheme',
#                              conf,
#                              'alt_tok_yap_ft_sg')
#     full_confs.append(fc)
#
# for i, fc in enumerate(full_confs):
#     with open( f'hp_search/conf_json2/morph_charcnn.{str(i).zfill(max_digits)}.json', 'w') as of:
#         of.write(json.dumps(fc))

# %% [markdown]
# ## Token

# %% [raw]
# max_digits = len(str(len(lstm_confs)))
# full_confs = []
# for i, conf in enumerate(lstm_confs):
#     fc = configs.create_conf_file(f'hp_search/conf2/token_charlstm.{str(i).zfill(max_digits)}.conf',
#                              f'hp_search/models2/token_charlstm.{str(i).zfill(max_digits)}.model',
#                              'gold_token_bioes',
#                              conf,
#                              'alt_tok_tokenized_ft_sg')
#     full_confs.append(fc)
#
# for i, fc in enumerate(full_confs):
#     with open( f'hp_search/conf_json2/token_charlstm.{str(i).zfill(max_digits)}.json', 'w') as of:
#         of.write(json.dumps(fc))

# %% [raw]
# max_digits = len(str(len(cnn_confs)))
# full_confs = []
# for i, conf in enumerate(cnn_confs):
#     fc = configs.create_conf_file(f'hp_search/conf2/token_charcnn.{str(i).zfill(max_digits)}.conf',
#                              f'hp_search/models2/token_charcnn.{str(i).zfill(max_digits)}.model',
#                              'gold_token_bioes',
#                              conf,
#                              'alt_tok_tokenized_ft_sg')
#     full_confs.append(fc)
#
# for i, fc in enumerate(full_confs):
#     with open( f'hp_search/conf_json2/token_charcnn.{str(i).zfill(max_digits)}.json', 'w') as of:
#         of.write(json.dumps(fc))

# %% [raw]
# import pickle
# with open('hp_search/conf_json2/cnn_confs.pkl', 'wb') as f:
#     pickle.dump(cnn_confs, f)
# with open('hp_search/conf_json2/lstm_confs.pkl', 'wb') as f:
#     pickle.dump(lstm_confs, f)

# %% [markdown]
# ## Token Multi-Tag

# %% [markdown]
# ## Token

# %% [raw]
# max_digits = len(str(len(lstm_confs)))
# full_confs = []
# for i, conf in enumerate(lstm_confs):
#     fc = configs.create_conf_file(f'hp_search/conf2/multitok_charlstm.{str(i).zfill(max_digits)}.conf',
#                              f'hp_search/models2/multitok_charlstm.{str(i).zfill(max_digits)}.model',
#                              'gold_token_raw',
#                              conf,
#                              'alt_tok_tokenized_ft_sg')
#     full_confs.append(fc)
#
# for i, fc in enumerate(full_confs):
#     with open( f'hp_search/conf_json2/multitok_charlstm.{str(i).zfill(max_digits)}.json', 'w') as of:
#         of.write(json.dumps(fc))

# %% [raw]
# max_digits = len(str(len(cnn_confs)))
# full_confs = []
# for i, conf in enumerate(cnn_confs):
#     fc = configs.create_conf_file(f'hp_search/conf2/multitok_charcnn.{str(i).zfill(max_digits)}.conf',
#                              f'hp_search/models2/multitok_charcnn.{str(i).zfill(max_digits)}.model',
#                              'gold_token_raw',
#                              conf,
#                              'alt_tok_tokenized_ft_sg')
#     full_confs.append(fc)
#
# for i, fc in enumerate(full_confs):
#     with open( f'hp_search/conf_json2/multitok_charcnn.{str(i).zfill(max_digits)}.json', 'w') as of:
#         of.write(json.dumps(fc))

# %%
nochar_confs = configs.get_x_configs('NoChar', 108)

# %%
import pandas as pd
df = pd.DataFrame(nochar_confs)

# %%
df.iloc[:100].optimizer.value_counts()
# Out:
# SGD    100
# Name: optimizer, dtype: int64

# %%
df.iloc[:100].lstm_layer.value_counts()
# Out:
# 2    50
# 1    50
# Name: lstm_layer, dtype: int64

# %%
df.iloc[:100].batch_size.value_counts()
# Out:
# 1    52
# 8    48
# Name: batch_size, dtype: int64

# %% [raw]
# with open('hp_search/conf_json2/nochar_confs.pkl', 'wb') as f:
#     pickle.dump(nochar_confs, f)

# %% [raw]
# import json
#
# max_digits = len(str(len(nochar_confs)))
# full_confs = []
# for i, conf in enumerate(nochar_confs):
#     fc = configs.create_conf_file(f'hp_search/conf2/morph_nochar.{str(i).zfill(max_digits)}.conf',
#                              f'hp_search/models2/morph_nochar.{str(i).zfill(max_digits)}.model',
#                              'gold_morpheme',
#                              conf,
#                              'alt_tok_yap_ft_sg')
#     full_confs.append(fc)
#
# for i, fc in enumerate(full_confs):
#     with open( f'hp_search/conf_json2/morph_nochar.{str(i).zfill(max_digits)}.json', 'w') as of:
#         of.write(json.dumps(fc))

# %% [raw]
# max_digits = len(str(len(nochar_confs)))
# full_confs = []
# for i, conf in enumerate(nochar_confs):
#     fc = configs.create_conf_file(f'hp_search/conf2/token_nochar.{str(i).zfill(max_digits)}.conf',
#                              f'hp_search/models2/token_nochar.{str(i).zfill(max_digits)}.model',
#                              'gold_token_bioes',
#                              conf,
#                              'alt_tok_tokenized_ft_sg')
#     full_confs.append(fc)
#
# for i, fc in enumerate(full_confs):
#     with open( f'hp_search/conf_json2/token_nochar.{str(i).zfill(max_digits)}.json', 'w') as of:
#         of.write(json.dumps(fc))

# %% [raw]
# max_digits = len(str(len(nochar_confs)))
# full_confs = []
# for i, conf in enumerate(nochar_confs):
#     fc = configs.create_conf_file(f'hp_search/conf2/multitok_nochar.{str(i).zfill(max_digits)}.conf',
#                              f'hp_search/models2/multitok_nochar.{str(i).zfill(max_digits)}.model',
#                              'gold_token_raw',
#                              conf,
#                              'alt_tok_tokenized_ft_sg')
#     full_confs.append(fc)
#
# for i, fc in enumerate(full_confs):
#     with open( f'hp_search/conf_json2/multitok_nochar.{str(i).zfill(max_digits)}.json', 'w') as of:
#         of.write(json.dumps(fc))

# %% [markdown]
# # RUNNING ON NLP08, NLP10, NLP11, NLP13, NLP05, NLP14
# cd NCRFpp/
# conda activate ncrf_gpu
# python run4_hp_search.py 3 token_charlstm.2

# %% [markdown]
# ## Check results

# %%
len(cnn_confs[0]), len(lstm_confs[0]), len(nochar_confs[0])
# Out:
# (24, 23, 21)

# %%
import re
DEV_RES_LINE = re.compile('Dev: .*; acc: (?P<acc>[^,]+)(?:, p: (?P<p>[^,]+), r: (?P<r>[^,]+), f: (?P<f>[-\d\.]+))?')
#Dev: time: 0.94s speed: 536.09st/s; acc: 0.9043
#Dev: time: 3.42s, speed: 146.59st/s; acc: 0.9546, p: 0.7577, r: 0.6393, f: 0.6935

mtimes = []
res = []
archs = []
for f in os.scandir('hp_search/logs2'):
    if f.name.startswith('.ipy'):
        continue
    mtimes.append(os.path.getmtime(f.path))
    arch = f.name.split('.')[0]
    archs.append(arch)
    unit = arch.split('_')[0]
    conf_num = f.name.split('.')[1]
    if 'cnn' in arch:
        matching_conf = cnn_confs[int(conf_num)] 
    elif 'lstm' in arch: 
        matching_conf = lstm_confs[int(conf_num)]
    elif 'nochar' in arch:
        matching_conf = nochar_confs[int(conf_num)]
    params = { 'arch': arch, 'unit': unit, 'conf_num': conf_num}
    params.update(matching_conf)
    with open(f.path, 'r') as fp:
        i= 0
        for line in fp:
            m = DEV_RES_LINE.match(line)
            if m:
                r = m.groupdict().copy()
                for k, v in r.items():
                    if v is not None:
                        r[k] = float(v)
                r.update(params)
                r['epoch'] = i
                i+=1
                res.append(r)

# %%
rdf = pd.DataFrame(res)

# %%
rdf['model_file_name'] = rdf.arch + '.' + rdf.conf_num +'.model.' + rdf.epoch.astype(str) + '.model'
rdf['dset_file_name'] =  rdf.arch + '.' + rdf.conf_num +'.model.dset'

# %%
rdf['relevant_score'] = rdf.f.fillna(rdf.acc)

# %%
erdf = rdf[(rdf.groupby(['conf_num', 'arch']).relevant_score.transform(max)==rdf.relevant_score) ]
erdf = erdf[(erdf.groupby(['conf_num', 'arch']).epoch.transform(min)==erdf.epoch) ]

# %% [raw]
# erdf.groupby(['conf_num', 'arch']).f.max().unstack().tail(20)

# %%
erdf.shape
# Out:
# (756, 35)

# %%
erdf.groupby('arch').size()
# Out:
# arch
# morph_charcnn        122
# morph_charlstm       104
# morph_nochar          46
# multitok_charcnn      76
# multitok_charlstm     82
# multitok_nochar       52
# token_charcnn        110
# token_charlstm       108
# token_nochar          56
# dtype: int64

# %%
from collections import Counter
archs = Counter(archs)
archs
# Out:
# Counter({'morph_charcnn': 122,
#          'token_charcnn': 110,
#          'token_charlstm': 108,
#          'morph_charlstm': 104,
#          'multitok_charlstm': 82,
#          'multitok_nochar': 52,
#          'multitok_charcnn': 76,
#          'token_nochar': 56,
#          'morph_nochar': 46})

# %%
print ('Mean time per run:', round((max(mtimes) - min(mtimes) )/ len(mtimes) / 60, 2), 'minutes')
# Out:
# Mean time per run: 7.94 minutes

# %%
import numpy as np 
def perc(n):
    def perc_(x):
        return np.percentile(x, n)
    perc_.__name__ = 'perc_%s' % n
    return perc_

erdf.fillna('NoChar').groupby(['unit', 'char_seq_feature']).f.agg(['max', 'min', 'mean', 'std', 'median', perc(95)])
# Out:
#                            max     min      mean       std  median   perc_95
# unit  char_seq_feature
# morph CNN               0.7991  0.7263  0.777952  0.011397  0.7803  0.791495
#       LSTM              0.7974  0.7611  0.782197  0.007790  0.7826  0.793640
#       NoChar            0.7852  0.7489  0.771805  0.009452  0.7720  0.783490
# token CNN               0.7749  0.7173  0.747663  0.011218  0.7477  0.763330
#       LSTM              0.7766  0.7217  0.753194  0.010896  0.7543  0.769965
#       NoChar            0.7476  0.7052  0.729840  0.008921  0.7293  0.744120

# %%
cols = ['f', 'p', 'r', 'char_seq_feature', 'lstm_layer', 'batch_size', 
        'learning_rate', 'char_hidden_dim', 'char_kernel_size',
        'hidden_dim', 'dropout', 'epoch']

# %%
(erdf[erdf.unit=='morph'].sort_values('f', ascending=False).head(20)[['arch', 'conf_num', 'epoch', 'f']]).fillna('')
# Out:
#                  arch conf_num  epoch       f
# 17957   morph_charcnn      017     57  0.7991
# 41651   morph_charcnn      053     51  0.7987
# 26967   morph_charcnn      034     67  0.7983
# 13826  morph_charlstm      011     26  0.7974
# 36238  morph_charlstm      039     38  0.7966
# 29690  morph_charlstm      224     90  0.7954
# 47251  morph_charlstm      245     51  0.7953
# 31091   morph_charcnn      033     91  0.7949
# 29983  morph_charlstm      028     83  0.7945
# 45959  morph_charlstm      241     59  0.7937
# 6772    morph_charcnn      404     72  0.7935
# 38425   morph_charcnn      046     25  0.7932
# 21999  morph_charlstm      015     99  0.7931
# 35295  morph_charlstm      045     95  0.7928
# 44287  morph_charlstm      250     87  0.7922
# 28431  morph_charlstm      235     31  0.7919
# 27626  morph_charlstm      030     26  0.7918
# 38849  morph_charlstm      032     49  0.7915
# 36948   morph_charcnn      425     48  0.7915
# 49087  morph_charlstm      258     87  0.7914

# %%
(erdf[erdf.unit=='token'].sort_values('f', ascending=False).head(20)[['arch', 'conf_num', 'epoch', 'f']]).fillna('')
# Out:
#                  arch conf_num  epoch       f
# 9968   token_charlstm      017     68  0.7766
# 50194   token_charcnn      075     94  0.7749
# 2470   token_charlstm      205     70  0.7747
# 38648  token_charlstm      057     48  0.7723
# 31895   token_charcnn      438     95  0.7719
# 758    token_charlstm      002     58  0.7711
# 26127  token_charlstm      041     27  0.7704
# 9227   token_charlstm      219     27  0.7700
# 40680  token_charlstm      054     80  0.7699
# 29473  token_charlstm      246     73  0.7683
# 30243  token_charlstm      032     43  0.7679
# 39994  token_charlstm      254     94  0.7674
# 10374   token_charcnn      018     74  0.7672
# 8186   token_charlstm      214     86  0.7666
# 2364   token_charlstm      004     64  0.7666
# 31751   token_charcnn      050     51  0.7666
# 34689  token_charlstm      046     89  0.7651
# 15177  token_charlstm      222     77  0.7648
# 29568   token_charcnn      467     68  0.7645
# 25898   token_charcnn      041     98  0.7636

# %%
(erdf[erdf.unit=='morph'].sort_values('f', ascending=False).head(20)[cols]).fillna('')
# Out:
#             f       p       r char_seq_feature  lstm_layer  batch_size  \
# 17957  0.7991  0.8558  0.7495              CNN           2           1
# 41651  0.7987  0.8472  0.7555              CNN           2           8
# 26967  0.7983  0.8539  0.7495              CNN           2           1
# 13826  0.7974  0.8519  0.7495             LSTM           2           1
# 36238  0.7966  0.8605  0.7415             LSTM           1           8
# 29690  0.7954  0.8396  0.7555             LSTM           2           1
# 47251  0.7953  0.8446  0.7515             LSTM           2           8
# 31091  0.7949  0.8513  0.7455              CNN           2           8
# 29983  0.7945  0.8477  0.7475             LSTM           2           1
# 45959  0.7937  0.8359  0.7555             LSTM           1           1
# 6772   0.7935  0.8670  0.7315              CNN           2           1
# 38425  0.7932  0.8474  0.7455              CNN           2           1
# 21999  0.7931  0.8632  0.7335             LSTM           2           1
# 35295  0.7928  0.8439  0.7475             LSTM           2           8
# 44287  0.7922  0.8667  0.7295             LSTM           1           1
# 28431  0.7919  0.8470  0.7435             LSTM           2           1
# 27626  0.7918  0.8522  0.7395             LSTM           1           1
# 38849  0.7915  0.8386  0.7495             LSTM           2           1
# 36948  0.7915  0.8386  0.7495              CNN           2           1
# 49087  0.7914  0.8486  0.7415             LSTM           2           8
#
#        learning_rate  char_hidden_dim char_kernel_size  hidden_dim  dropout  \
# 17957          0.005             50.0                5         200      0.6
# 41651          0.010             70.0                7         100      0.5
# 26967          0.010             90.0                5         200      0.4
# 13826          0.015             70.0                          100      0.5
# 36238          0.010             50.0                          100      0.4
# 29690          0.010             50.0                          100      0.6
# 47251          0.005             70.0                          200      0.5
# 31091          0.005             70.0                7          50      0.5
# 29983          0.010             70.0                          200      0.5
# 45959          0.015             70.0                           50      0.4
# 6772           0.010             70.0                7         200      0.5
# 38425          0.010             50.0                7         100      0.4
# 21999          0.005             50.0                          200      0.6
# 35295          0.010             50.0                           50      0.4
# 44287          0.010             50.0                          100      0.5
# 28431          0.015             70.0                          100      0.4
# 27626          0.015             50.0                          200      0.4
# 38849          0.010             70.0                          200      0.6
# 36948          0.005             50.0                3         100      0.4
# 49087          0.005             90.0                          200      0.6
#
#        epoch
# 17957     57
# 41651     51
# 26967     67
# 13826     26
# 36238     38
# 29690     90
# 47251     51
# 31091     91
# 29983     83
# 45959     59
# 6772      72
# 38425     25
# 21999     99
# 35295     95
# 44287     87
# 28431     31
# 27626     26
# 38849     49
# 36948     48
# 49087     87

# %%
(erdf[erdf.unit=='morph'].sort_values('f', ascending=True).head(20)[cols]).fillna('')
# Out:
#             f       p       r char_seq_feature  lstm_layer  batch_size  \
# 46389  0.7263  0.8207  0.6513              CNN           2           8
# 38289  0.7467  0.8201  0.6854              CNN           1           8
# 37187  0.7489  0.8313  0.6814                            1           8
# 18989  0.7500  0.8112  0.6974              CNN           1           8
# 42074  0.7525  0.8254  0.6914                            1           8
# 49110  0.7539  0.8437  0.6814                            1           1
# 24636  0.7546  0.8278  0.6934              CNN           1           1
# 42434  0.7558  0.8333  0.6914                            2           1
# 5723   0.7566  0.8354  0.6914              CNN           1           8
# 42247  0.7572  0.8119  0.7094                            2           8
# 44034  0.7586  0.8205  0.7054              CNN           2           1
# 41751  0.7590  0.8325  0.6974                            1           1
# 17361  0.7591  0.8190  0.7074              CNN           2           8
# 50872  0.7600  0.8209  0.7074                            2           1
# 7194   0.7600  0.8294  0.7014              CNN           2           8
# 50258  0.7607  0.8456  0.6914              CNN           2           1
# 50723  0.7609  0.8314  0.7014                            1           1
# 5957   0.7609  0.8314  0.7014              CNN           1           8
# 34554  0.7610  0.8180  0.7114              CNN           2           8
# 43047  0.7611  0.8263  0.7054             LSTM           1           8
#
#        learning_rate char_hidden_dim char_kernel_size  hidden_dim  dropout  \
# 46389          0.015              90                5         200      0.6
# 38289          0.015              90                3         200      0.6
# 37187          0.015                                           50      0.5
# 18989          0.015              90                5         200      0.6
# 42074          0.010                                           50      0.6
# 49110          0.010                                           50      0.6
# 24636          0.015              70                3          50      0.6
# 42434          0.015                                           50      0.6
# 5723           0.015              70                5          50      0.6
# 42247          0.010                                           50      0.6
# 44034          0.015              50                7          50      0.6
# 41751          0.005                                           50      0.6
# 17361          0.015              70                5          50      0.6
# 50872          0.015                                           50      0.4
# 7194           0.015              50                3         100      0.6
# 50258          0.015              90                3         200      0.6
# 50723          0.010                                          100      0.6
# 5957           0.010              50                7          50      0.6
# 34554          0.015              50                3          50      0.6
# 43047          0.015              50                           50      0.6
#
#        epoch
# 46389     89
# 38289     89
# 37187     87
# 18989     89
# 42074     74
# 49110     10
# 24636     36
# 42434     34
# 5723      23
# 42247     47
# 44034     34
# 41751     51
# 17361     61
# 50872     72
# 7194      94
# 50258     58
# 50723     23
# 5957      57
# 34554     54
# 43047     47

# %%
(erdf[erdf.unit=='token'].sort_values('f', ascending=False).head(20)[cols]).fillna('')
# Out:
#             f       p       r char_seq_feature  lstm_layer  batch_size  \
# 9968   0.7766  0.8277  0.7315             LSTM           2           1
# 50194  0.7749  0.8424  0.7174              CNN           2           8
# 2470   0.7747  0.8337  0.7234             LSTM           2           8
# 38648  0.7723  0.8106  0.7375             LSTM           2           8
# 31895  0.7719  0.8246  0.7255              CNN           2           8
# 758    0.7711  0.8361  0.7154             LSTM           2           8
# 26127  0.7704  0.8161  0.7295             LSTM           2           1
# 9227   0.7700  0.8129  0.7315             LSTM           2           8
# 40680  0.7699  0.8176  0.7275             LSTM           2           8
# 29473  0.7683  0.8139  0.7275             LSTM           2           8
# 30243  0.7679  0.8107  0.7295             LSTM           2           1
# 39994  0.7674  0.8249  0.7174             LSTM           2           1
# 10374  0.7672  0.8298  0.7134              CNN           2           8
# 8186   0.7666  0.8230  0.7174             LSTM           2           8
# 2364   0.7666  0.8230  0.7174             LSTM           2           8
# 31751  0.7666  0.8365  0.7074              CNN           1           8
# 34689  0.7651  0.8145  0.7214             LSTM           2           1
# 15177  0.7648  0.8241  0.7134             LSTM           2           1
# 29568  0.7645  0.8207  0.7154              CNN           2           1
# 25898  0.7636  0.8188  0.7154              CNN           2           8
#
#        learning_rate  char_hidden_dim char_kernel_size  hidden_dim  dropout  \
# 9968           0.005             90.0                          100      0.4
# 50194          0.010             70.0                7         200      0.4
# 2470           0.015             70.0                          200      0.5
# 38648          0.010             70.0                          200      0.5
# 31895          0.010             70.0                5         200      0.6
# 758            0.010             70.0                          100      0.5
# 26127          0.015             50.0                          200      0.6
# 9227           0.010             50.0                          200      0.5
# 40680          0.015             50.0                          200      0.5
# 29473          0.015             50.0                          100      0.6
# 30243          0.010             70.0                          200      0.6
# 39994          0.005             50.0                          200      0.4
# 10374          0.005             50.0                5         100      0.5
# 8186           0.010             90.0                          100      0.6
# 2364           0.005             70.0                          100      0.5
# 31751          0.005             70.0                7         200      0.4
# 34689          0.005             70.0                          100      0.6
# 15177          0.015             90.0                          100      0.4
# 29568          0.005             70.0                7         200      0.5
# 25898          0.005             70.0                3         200      0.5
#
#        epoch
# 9968      68
# 50194     94
# 2470      70
# 38648     48
# 31895     95
# 758       58
# 26127     27
# 9227      27
# 40680     80
# 29473     73
# 30243     43
# 39994     94
# 10374     74
# 8186      86
# 2364      64
# 31751     51
# 34689     89
# 15177     77
# 29568     68
# 25898     98

# %%
(erdf[erdf.unit=='token'].sort_values('f', ascending=True).head(20)[cols]).fillna('')
# Out:
#             f       p       r char_seq_feature  lstm_layer  batch_size  \
# 51527  0.7052  0.7746  0.6473                            1           1
# 33390  0.7061  0.7797  0.6453                            1           8
# 34080  0.7121  0.7741  0.6593                            1           8
# 46199  0.7158  0.7801  0.6613                            1           1
# 53696  0.7172  0.7807  0.6633                            2           1
# 14077  0.7173  0.8106  0.6433              CNN           1           1
# 18889  0.7189  0.7990  0.6533              CNN           1           1
# 33661  0.7204  0.7773  0.6713                            2           8
# 44541  0.7210  0.7867  0.6653                            1           8
# 42758  0.7217  0.7886  0.6653                            1           8
# 32254  0.7217  0.7886  0.6653             LSTM           1           8
# 52623  0.7226  0.7692  0.6814                            1           1
# 43864  0.7233  0.8039  0.6573                            1           8
# 42985  0.7234  0.7814  0.6733                            2           1
# 32936  0.7235  0.7957  0.6633             LSTM           1           8
# 26867  0.7237  0.7990  0.6613              CNN           1           8
# 37676  0.7238  0.8145  0.6513                            1           8
# 4258   0.7246  0.8166  0.6513              CNN           1           8
# 42895  0.7247  0.8044  0.6593              CNN           1           1
# 51891  0.7251  0.7882  0.6713                            2           8
#
#        learning_rate char_hidden_dim char_kernel_size  hidden_dim  dropout  \
# 51527          0.015                                           50      0.6
# 33390          0.005                                           50      0.6
# 34080          0.005                                           50      0.5
# 46199          0.005                                           50      0.5
# 53696          0.005                                           50      0.6
# 14077          0.015              50                5          50      0.6
# 18889          0.015              70                3          50      0.6
# 33661          0.015                                           50      0.4
# 44541          0.010                                           50      0.4
# 42758          0.010                                           50      0.5
# 32254          0.010              90                           50      0.6
# 52623          0.015                                           50      0.5
# 43864          0.010                                          100      0.5
# 42985          0.005                                           50      0.5
# 32936          0.015              90                           50      0.6
# 26867          0.010              90                3          50      0.6
# 37676          0.015                                           50      0.5
# 4258           0.015              70                5          50      0.6
# 42895          0.010              70                5          50      0.6
# 51891          0.015                                           50      0.5
#
#        epoch
# 51527     27
# 33390     90
# 34080     80
# 46199     99
# 53696     96
# 14077     77
# 18889     89
# 33661     61
# 44541     41
# 42758     58
# 32254     54
# 52623     23
# 43864     64
# 42985     85
# 32936     36
# 26867     67
# 37676     76
# 4258      58
# 42895     95
# 51891     91

# %%
erdf.groupby('arch').epoch.agg(['median', 'mean', 'std'])
# Out:
#                 median       mean        std
# arch
# morph_charcnn       51  53.786885  26.513751
# morph_charlstm      69  61.970874  27.671907
# morph_nochar        71  64.837209  24.832707
# token_charcnn       68  64.309091  25.733192
# token_charlstm      67  65.888889  21.421159
# token_nochar        75  66.622642  26.725259

# %%
sns.swarmplot(data=erdf, x='unit', y='f', hue='char_seq_feature', dodge=True)

# %%
sns.violinplot(data=erdf, x='unit', y='f', hue='char_seq_feature', split=True, inner='stick')

# %% [markdown]
# ## Learning rate

# %%
erdf.groupby(['optimizer', 'learning_rate', 'arch']).conf_num.nunique().unstack()
# Out:
# arch                     morph_charcnn  morph_charlstm  morph_nochar  \
# optimizer learning_rate
# SGD       0.005                     42              41            12
#           0.010                     44              34            20
#           0.015                     36              28            11
#
# arch                     token_charcnn  token_charlstm  token_nochar
# optimizer learning_rate
# SGD       0.005                     39              45            14
#           0.010                     41              34            18
#           0.015                     30              29            21

# %%
erdf.groupby(['optimizer', 'learning_rate', 'arch']).f.median().unstack()
# Out:
# arch                     morph_charcnn  morph_charlstm  morph_nochar  \
# optimizer learning_rate
# SGD       0.005                0.78165         0.78350       0.77195
#           0.010                0.78045         0.78325       0.77295
#           0.015                0.77280         0.78140       0.77060
#
# arch                     token_charcnn  token_charlstm  token_nochar
# optimizer learning_rate
# SGD       0.005                0.74570         0.75320       0.72770
#           0.010                0.75030         0.75765       0.73195
#           0.015                0.74835         0.75410       0.73270

# %%
erdf.groupby(['optimizer', 'learning_rate', 'arch']).f.max().unstack()
# Out:
# arch                     morph_charcnn  morph_charlstm  morph_nochar  \
# optimizer learning_rate
# SGD       0.005                 0.7991          0.7953        0.7837
#           0.010                 0.7987          0.7966        0.7852
#           0.015                 0.7912          0.7974        0.7835
#
# arch                     token_charcnn  token_charlstm  token_nochar
# optimizer learning_rate
# SGD       0.005                 0.7672          0.7766        0.7424
#           0.010                 0.7749          0.7723        0.7476
#           0.015                 0.7610          0.7747        0.7448

# %%
sns.swarmplot(data=erdf.fillna('NoChar'), x='learning_rate', y='f', hue='char_seq_feature', split=True)

# %%
sns.violinplot(x="learning_rate", y="f", hue="batch_size",
                data=erdf, palette="Set2", split=True,
                scale="count", inner="stick", scale_hue=False)

# %%
sns.catplot(kind='violin', row='char_seq_feature', col='unit', 
            x="learning_rate", y="f", #hue='batch_size',
                data=erdf.fillna('NoChar'), palette="Set2", split=True,
                scale="count", inner="box", scale_hue=True)

# %%
sns.violinplot(data=erdf, x='learning_rate', y='epoch', inner='stick')

# %% [markdown]
# ### Do the lower scores in the lower learning rate come from lack of epochs?

# %%
sns.scatterplot(data=erdf.assign(lr=lambda x: x.learning_rate.astype('str')), hue='lr', x='epoch', y='f',
               palette=sns.color_palette("Set1", erdf.learning_rate.nunique()))

# %%
>>> g = sns.FacetGrid(erdf.rename(columns={'learning_rate': 'lr', 'char_seq_feature': 'charsf'}), col="lr", row='charsf')
>>> g = g.map(plt.scatter, "epoch", "f", edgecolor="w")

# %%
>>> g = sns.FacetGrid(erdf[erdf.unit=='morph'].rename(columns={'learning_rate': 'lr', 'char_seq_feature': 'charsf'}), col="lr", row='charsf')
>>> g = g.map(sns.kdeplot, "epoch", "f")

# %%
>>> g = sns.FacetGrid(erdf[erdf.unit=='token'].rename(columns={'learning_rate': 'lr', 'char_seq_feature': 'charsf'}), col="lr", row='charsf')
>>> g = g.map(sns.kdeplot, "epoch", "f")

# %%
>>> g = sns.FacetGrid(erdf.rename(columns={'char_seq_feature': 'charsf'}), col="batch_size", row='charsf')
>>> g = g.map(plt.scatter, "epoch", "f", edgecolor="w")

# %%
>>> g = sns.FacetGrid(erdf.rename(columns={'char_seq_feature': 'charsf'}), col="batch_size", row='charsf')
>>> g = g.map(sns.kdeplot, "epoch", "f")

# %%
sns.swarmplot(data=erdf, x='arch', y='epoch')

# %% [markdown]
# ## Batch size

# %%
erdf.groupby(['batch_size', 'arch']).f.median().unstack()
# Out:
# arch        morph_charcnn  morph_charlstm  morph_nochar  token_charcnn  \
# batch_size
# 1                 0.78170         0.78515        0.7719         0.7476
# 8                 0.77795         0.78130        0.7721         0.7478
#
# arch        token_charlstm  token_nochar
# batch_size
# 1                  0.75575        0.7290
# 8                  0.75350        0.7306

# %%
sns.swarmplot(data=erdf, x='unit', y='f', hue='batch_size', split=True)

# %%
sns.violinplot(data=erdf, x='unit', y='f', hue='batch_size', split=True, inner='stick')

# %% [markdown]
# ## Char CNN window size

# %%
erdf.groupby(['unit', 'char_kernel_size']).f.mean().unstack()
# Out:
# char_kernel_size       3.0       5.0       7.0
# unit
# morph             0.774034  0.777962  0.781965
# token             0.745823  0.746515  0.750941

# %%
sns.swarmplot(data=erdf, x='arch', y='f', hue='char_kernel_size', split=True)

# %%
sns.catplot(kind='violin', col='unit', x="char_kernel_size", y="f",
                data=erdf, palette="Set2", 
                scale="count", inner="box")

# %% [markdown]
# ## LSTM Layers stacked

# %%
erdf.groupby(['lstm_layer', 'arch']).f.median().unstack()
# Out:
# arch        morph_charcnn  morph_charlstm  morph_nochar  token_charcnn  \
# lstm_layer
# 1                  0.7772          0.7811        0.7751        0.74510
# 2                  0.7809          0.7861        0.7719        0.75225
#
# arch        token_charlstm  token_nochar
# lstm_layer
# 1                   0.7519       0.72890
# 2                   0.7594       0.73055

# %%
erdf.groupby(['lstm_layer', 'arch']).f.max().unstack()
# Out:
# arch        morph_charcnn  morph_charlstm  morph_nochar  token_charcnn  \
# lstm_layer
# 1                  0.7914          0.7966        0.7852         0.7666
# 2                  0.7991          0.7974        0.7835         0.7749
#
# arch        token_charlstm  token_nochar
# lstm_layer
# 1                   0.7618        0.7424
# 2                   0.7766        0.7476

# %%
sns.swarmplot(data=erdf, x='arch', y='f', hue='lstm_layer', split=True)

# %%
sns.catplot(kind='violin', row='unit', col='char_seq_feature', 
            x="lstm_layer", y="f",
                data=erdf, palette="Set2", split=True,
                scale="count", inner="stick", scale_hue=True)

# %% [markdown]
# ## Dropout

# %%
erdf.groupby(['dropout', 'arch']).f.median().unstack()
# Out:
# arch     morph_charcnn  morph_charlstm  morph_nochar  token_charcnn  \
# dropout
# 0.4             0.7846         0.78210        0.7762         0.7524
# 0.5             0.7804         0.78345        0.7760         0.7492
# 0.6             0.7722         0.78090        0.7612         0.7422
#
# arch     token_charlstm  token_nochar
# dropout
# 0.4              0.7521       0.73045
# 0.5              0.7578       0.72930
# 0.6              0.7552       0.73020

# %%
sns.swarmplot(data=erdf, x='arch', y='f', hue='dropout', split=True)

# %% [markdown]
# ## Hidden dimensions

# %% [markdown]
# ### WLSTM

# %%
erdf.groupby(['hidden_dim', 'arch']).f.median().unstack()
# Out:
# arch        morph_charcnn  morph_charlstm  morph_nochar  token_charcnn  \
# hidden_dim
# 50                 0.7742         0.77540        0.7706         0.7371
# 100                0.7850         0.78270        0.7754         0.7512
# 200                0.7817         0.78555        0.7774         0.7522
#
# arch        token_charlstm  token_nochar
# hidden_dim
# 50                 0.74410       0.72360
# 100                0.75765       0.73285
# 200                0.75715       0.73510

# %%
sns.swarmplot(data=erdf, x='arch', y='f', hue='hidden_dim', split=True)

# %% [markdown]
# ### CLSTM / CCNN

# %%
erdf.groupby(['char_hidden_dim', 'arch']).f.median().unstack()
# Out:
# arch             morph_charcnn  morph_charlstm  token_charcnn  token_charlstm
# char_hidden_dim
# 50.0                    0.7819         0.78395         0.7465         0.75485
# 70.0                    0.7772         0.78200         0.7513         0.75190
# 90.0                    0.7803         0.78220         0.7467         0.75600

# %%
sns.swarmplot(data=erdf, x='arch', y='f', hue='char_hidden_dim', split=True)

# %%
sns.catplot(kind='violin', row='unit', col='char_seq_feature', 
            x="char_hidden_dim", y="f",
                data=erdf, palette="Set2", split=True,
                scale="count", inner="stick", scale_hue=True)

# %%
erdf.groupby('arch').apply(lambda x: x.sort_values('f', ascending=False).head(2)).T
# Out:
# arch                                  morph_charcnn  \
#                                               17957
# acc                                            0.97
# p                                            0.8558
# r                                            0.7495
# f                                            0.7991
# arch                                  morph_charcnn
# unit                                          morph
# conf_num                                        017
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        1
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      200
# dropout                                         0.6
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  50
# char_kernel_size                                  5
# learning_rate                                 0.005
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            57
# model_file_name    morph_charcnn.017.model.57.model
# dset_file_name         morph_charcnn.017.model.dset
#
# arch                                                 \
#                                               41651
# acc                                          0.9689
# p                                            0.8472
# r                                            0.7555
# f                                            0.7987
# arch                                  morph_charcnn
# unit                                          morph
# conf_num                                        053
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        8
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      100
# dropout                                         0.5
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  70
# char_kernel_size                                  7
# learning_rate                                  0.01
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            51
# model_file_name    morph_charcnn.053.model.51.model
# dset_file_name         morph_charcnn.053.model.dset
#
# arch                                  morph_charlstm  \
#                                                13826
# acc                                           0.9679
# p                                             0.8519
# r                                             0.7495
# f                                             0.7974
# arch                                  morph_charlstm
# unit                                           morph
# conf_num                                         011
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         2
# batch_size                                         1
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       100
# dropout                                          0.5
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   70
# char_kernel_size                                 NaN
# learning_rate                                  0.015
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             26
# model_file_name    morph_charlstm.011.model.26.model
# dset_file_name         morph_charlstm.011.model.dset
#
# arch                                                  \
#                                                36238
# acc                                           0.9673
# p                                             0.8605
# r                                             0.7415
# f                                             0.7966
# arch                                  morph_charlstm
# unit                                           morph
# conf_num                                         039
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         1
# batch_size                                         8
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       100
# dropout                                          0.4
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   50
# char_kernel_size                                 NaN
# learning_rate                                   0.01
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             38
# model_file_name    morph_charlstm.039.model.38.model
# dset_file_name         morph_charlstm.039.model.dset
#
# arch                                  morph_nochar  \
#                                              40290
# acc                                         0.9666
# p                                           0.8612
# r                                           0.7214
# f                                           0.7852
# arch                                  morph_nochar
# unit                                         morph
# conf_num                                       071
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       1
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                      50
# dropout                                        0.4
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                 0.01
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           90
# model_file_name    morph_nochar.071.model.90.model
# dset_file_name         morph_nochar.071.model.dset
#
# arch                                                \
#                                              52364
# acc                                         0.9666
# p                                           0.8722
# r                                           0.7114
# f                                           0.7837
# arch                                  morph_nochar
# unit                                         morph
# conf_num                                       031
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       1
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                     200
# dropout                                        0.4
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                0.005
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           64
# model_file_name    morph_nochar.031.model.64.model
# dset_file_name         morph_nochar.031.model.dset
#
# arch                                  token_charcnn  \
#                                               50194
# acc                                          0.9655
# p                                            0.8424
# r                                            0.7174
# f                                            0.7749
# arch                                  token_charcnn
# unit                                          token
# conf_num                                        075
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        8
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      200
# dropout                                         0.4
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  70
# char_kernel_size                                  7
# learning_rate                                  0.01
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            94
# model_file_name    token_charcnn.075.model.94.model
# dset_file_name         token_charcnn.075.model.dset
#
# arch                                                 \
#                                               31895
# acc                                           0.965
# p                                            0.8246
# r                                            0.7255
# f                                            0.7719
# arch                                  token_charcnn
# unit                                          token
# conf_num                                        438
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        8
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      200
# dropout                                         0.6
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  70
# char_kernel_size                                  5
# learning_rate                                  0.01
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            95
# model_file_name    token_charcnn.438.model.95.model
# dset_file_name         token_charcnn.438.model.dset
#
# arch                                  token_charlstm  \
#                                                9968
# acc                                           0.9668
# p                                             0.8277
# r                                             0.7315
# f                                             0.7766
# arch                                  token_charlstm
# unit                                           token
# conf_num                                         017
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         2
# batch_size                                         1
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       100
# dropout                                          0.4
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   90
# char_kernel_size                                 NaN
# learning_rate                                  0.005
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             68
# model_file_name    token_charlstm.017.model.68.model
# dset_file_name         token_charlstm.017.model.dset
#
# arch                                                  \
#                                                2470
# acc                                           0.9654
# p                                             0.8337
# r                                             0.7234
# f                                             0.7747
# arch                                  token_charlstm
# unit                                           token
# conf_num                                         205
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         2
# batch_size                                         8
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       200
# dropout                                          0.5
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   70
# char_kernel_size                                 NaN
# learning_rate                                  0.015
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             70
# model_file_name    token_charlstm.205.model.70.model
# dset_file_name         token_charlstm.205.model.dset
#
# arch                                  token_nochar  \
#                                              44894
# acc                                         0.9623
# p                                           0.8137
# r                                           0.6914
# f                                           0.7476
# arch                                  token_nochar
# unit                                         token
# conf_num                                       014
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       2
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                     200
# dropout                                        0.5
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                 0.01
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           94
# model_file_name    token_nochar.014.model.94.model
# dset_file_name         token_nochar.014.model.dset
#
# arch
#                                              48189
# acc                                         0.9624
# p                                           0.8213
# r                                           0.6814
# f                                           0.7448
# arch                                  token_nochar
# unit                                         token
# conf_num                                       022
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       2
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                     200
# dropout                                        0.4
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                0.015
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           89
# model_file_name    token_nochar.022.model.89.model
# dset_file_name         token_nochar.022.model.dset

# %%
rdf[rdf.groupby('arch').f.transform(max)==rdf.f].sort_values('f', ascending=False).T
# Out:
#                                               17957  \
# acc                                            0.97
# p                                            0.8558
# r                                            0.7495
# f                                            0.7991
# arch                                  morph_charcnn
# unit                                          morph
# conf_num                                        017
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        1
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      200
# dropout                                         0.6
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  50
# char_kernel_size                                  5
# learning_rate                                 0.005
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            57
# model_file_name    morph_charcnn.017.model.57.model
# dset_file_name         morph_charcnn.017.model.dset
#
#                                                13826  \
# acc                                           0.9679
# p                                             0.8519
# r                                             0.7495
# f                                             0.7974
# arch                                  morph_charlstm
# unit                                           morph
# conf_num                                         011
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         2
# batch_size                                         1
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       100
# dropout                                          0.5
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   70
# char_kernel_size                                 NaN
# learning_rate                                  0.015
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             26
# model_file_name    morph_charlstm.011.model.26.model
# dset_file_name         morph_charlstm.011.model.dset
#
#                                              40290  \
# acc                                         0.9666
# p                                           0.8612
# r                                           0.7214
# f                                           0.7852
# arch                                  morph_nochar
# unit                                         morph
# conf_num                                       071
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       1
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                      50
# dropout                                        0.4
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                 0.01
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           90
# model_file_name    morph_nochar.071.model.90.model
# dset_file_name         morph_nochar.071.model.dset
#
#                                                9968   \
# acc                                           0.9668
# p                                             0.8277
# r                                             0.7315
# f                                             0.7766
# arch                                  token_charlstm
# unit                                           token
# conf_num                                         017
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         2
# batch_size                                         1
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       100
# dropout                                          0.4
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   90
# char_kernel_size                                 NaN
# learning_rate                                  0.005
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             68
# model_file_name    token_charlstm.017.model.68.model
# dset_file_name         token_charlstm.017.model.dset
#
#                                               50194  \
# acc                                          0.9655
# p                                            0.8424
# r                                            0.7174
# f                                            0.7749
# arch                                  token_charcnn
# unit                                          token
# conf_num                                        075
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        8
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      200
# dropout                                         0.4
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  70
# char_kernel_size                                  7
# learning_rate                                  0.01
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            94
# model_file_name    token_charcnn.075.model.94.model
# dset_file_name         token_charcnn.075.model.dset
#
#                                              44894
# acc                                         0.9623
# p                                           0.8137
# r                                           0.6914
# f                                           0.7476
# arch                                  token_nochar
# unit                                         token
# conf_num                                       014
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       2
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                     200
# dropout                                        0.5
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                 0.01
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           94
# model_file_name    token_nochar.014.model.94.model
# dset_file_name         token_nochar.014.model.dset

# %%
with open('../NER/data/for_ncrf/morph_yap_dev.bmes', 'r') as f, open('../NER/data/for_ncrf/morph_yap_dev_dummy_o.bmes', 'w') as of:
    for line in f:
        if len(line.strip())>0:
            of.write(line.strip() + ' O\n')
        else:
            of.write('\n')

# %%
with open('../NER/data/for_ncrf/token_gold_dev_concat.bmes', 'r') as f, open('../NER/data/for_ncrf/token_gold_dev_concat_dummy_o.bmes', 'w') as of:
    for line in f:
        if len(line.strip())>0:
            of.write(line.strip() + ' O\n')
        else:
            of.write('\n')

# %%
with open('../NER/data/for_ncrf/morph_yap_test.bmes', 'r') as f, open('../NER/data/for_ncrf/morph_yap_test_dummy_o.bmes', 'w') as of:
    for line in f:
        if len(line.strip())>0:
            of.write(line.strip() + ' O\n')
        else:
            of.write('\n')

# %% [markdown]
# ## Evaluate files (Mention Evaluation)

# %%
import sys
sys.path.append('../NER')

# %%
import ne_evaluate_mentions as nem

# %%
from functools import lru_cache

@lru_cache(32)
def read_file_sents(path, comment_prefix='#', field_delim=' ', multi_delim='^', fix_multi_tag=True):
    sents = []
    for i, sent in enumerate(open(path, 'r', encoding='utf8').read().split('\n\n')):
        if len(sent)>0:
            cur = []
            for line in sent.split('\n'):
                if not line.startswith(comment_prefix):
                    ls = line.split(field_delim)
                    tok, tag = ls[0], ls[-1]
                    if fix_multi_tag and multi_delim in tag:
                        tag = nem.fix_multi_biose(tag, multi_delim=multi_delim)
                    cur.append((tok, tag))
            sents.append((cur, i))
    idx, values = zip(*sents)
    sents = pd.Series(idx, values)
    return sents

# %%
def evaluate_files(gold_path, pred_path, fix_multi_tag_pred=True):
    gold_sents = read_file_sents(gold_path)
    pred_sents = read_file_sents(pred_path)
    gold_mentions = nem.sents_to_mentions(gold_sents)
    pred_mentions = nem.sents_to_mentions(pred_sents)
    return nem.evaluate_mentions(gold_mentions, pred_mentions, verbose=False)

# %%
evaluate_files('../NER/data/for_ncrf/token_gold_dev_fix.bmes', 'data/dev_multitok_charlstm.002.bmes')
# Out:
# (0.6973947895791583, 0.8188235294117647, 0.7532467532467533)

# %%
evaluate_files('../NER/data/for_ncrf/morph_gold_dev.bmes', 'data/morph_yap_morph_charcnn.401.bmes', fix_multi_tag_pred=False)
# Out:
# (0.6325301204819277, 0.8076923076923077, 0.7094594594594594)

# %% [markdown]
# ## Create configs for decoding

# %% [raw]
# status=decode
# raw_dir=../NER/data/for_ncrf/token_gold_dev_concat_dummy_o.bmes
# #nbest=10
# decode_dir=data/dev_multitok_charlstm.002.bmes
# dset_dir=hp_search/models2/multitok_charlstm.002.model.dset
# load_model_dir=hp_search/models2/multitok_charlstm.002.model.96.model

# %%
model_folder = 'hp_search/models2'
output_folder = 'hp_search/decode_output2'
conf_folder = 'hp_search/decode_conf2'

if not os.path.exists(output_folder):
    os.mkdir(output_folder)

if not os.path.exists(conf_folder):
    os.mkdir(conf_folder)
    
decode_sets = {
    'morph': {
        'morph_dev_gold': '../NER/data/for_ncrf/morph_gold_dev.bmes',
        'morph_dev_yap': '../NER/data/for_ncrf/morph_yap_dev_dummy_o.bmes',
        'morph_test_gold': '../NER/data/for_ncrf/morph_gold_test.bmes',
        'morph_test_yap': '../NER/data/for_ncrf/morph_yap_test_dummy_o.bmes',
    },
    'token': {
        'token_dev': '../NER/data/for_ncrf/token_gold_dev_fix.bmes',
        'token_test': '../NER/data/for_ncrf/token_gold_test_fix.bmes',
    },
    'multitok': {
        'token_dev': '../NER/data/for_ncrf/token_gold_dev_concat.bmes',
        'token_test': '../NER/data/for_ncrf/token_gold_test_concat.bmes',
    }
}

params = { 'status': 'decode' }

for i, row in erdf.iterrows():
    unit = row['arch'].split('_')[0]
    for name, set_path in decode_sets[unit].items():
        row_par = params.copy()
        row_par['load_model_dir'] = os.path.join(model_folder, row['model_file_name'])
        row_par['dset_dir'] = os.path.join(model_folder, row['dset_file_name'])
        row_par['decode_dir'] = os.path.join(output_folder, name+'.'+row['arch']+'.'+row['conf_num']+'.bmes')
        row_par['raw_dir'] = set_path
        
        conf_path = os.path.join(conf_folder, name+'.'+row['arch']+'.'+row['conf_num']+'.decode.conf')
        if not os.path.exists(conf_path):
            with open(conf_path, 'w', encoding='utf8') as of:
                for k, v in row_par.items():
                    of.write(k+'='+str(v)+'\n')

# %% [markdown]
# ## Evaluate decoded folder

# %%
scores = []

for file in os.scandir(output_folder):
    if file.name=='.ipynb_checkpoints':
        continue
    gold_name, arch, conf_num = file.name.split('.')[:3]
    _, charsf = arch.split('_')
    if len(gold_name.split('_'))>2:
        unit, pred_set, _ = gold_name.split('_')
        gold_path = decode_sets[unit][unit+'_'+pred_set+'_gold']
    else:
        unit, pred_set = gold_name.split('_')
        gold_path = decode_sets[unit][unit+'_'+pred_set]
    p, r, f = evaluate_files(gold_path, file)
    scores.append((gold_name, arch, conf_num, p, r, f))

# %%
mev = pd.DataFrame(scores, columns=('gold_name', 'arch', 'conf_num', 'p', 'r', 'f'))
mev.head()
# Out:
#          gold_name           arch conf_num         p         r         f
# 0   morph_dev_gold  morph_charcnn      002  0.724900  0.841492  0.778857
# 1    morph_dev_yap  morph_charcnn      002  0.650602  0.775120  0.707424
# 2  morph_test_gold  morph_charcnn      002  0.729614  0.789779  0.758505
# 3   morph_test_yap  morph_charcnn      400  0.618026  0.679245  0.647191
# 4        token_dev  token_charcnn      002  0.687375  0.828502  0.751369

# %%
mev[~mev.gold_name.str.contains('test')].groupby(['gold_name', 'arch']).f.agg(['max', 'min', 'mean', 'std', 'median', perc(95)])
# Out:
#                                        max       min      mean       std  \
# gold_name      arch
# morph_dev_gold morph_charcnn      0.800857  0.727884  0.779122  0.011530
#                morph_charlstm     0.797040  0.761803  0.783506  0.007769
#                morph_nochar       0.786026  0.748344  0.772713  0.009540
# morph_dev_yap  morph_charcnn      0.728051  0.662116  0.701504  0.010649
#                morph_charlstm     0.726486  0.682454  0.705199  0.008880
#                morph_nochar       0.712360  0.677966  0.696387  0.009055
# token_dev      multitok_charlstm  0.751055  0.745055  0.748055  0.004243
#                multitok_nochar    0.746015  0.746015  0.746015       NaN
#                token_charcnn      0.774892  0.717318  0.748456  0.011469
#                token_charlstm     0.778252  0.721739  0.754348  0.011042
#                token_nochar       0.747562  0.705240  0.731005  0.009311
#
#                                     median   perc_95
# gold_name      arch
# morph_dev_gold morph_charcnn      0.781116  0.793000
#                morph_charlstm     0.784355  0.794392
#                morph_nochar       0.773504  0.784201
# morph_dev_yap  morph_charcnn      0.702881  0.716437
#                morph_charlstm     0.706013  0.718696
#                morph_nochar       0.696507  0.709876
# token_dev      multitok_charlstm  0.748055  0.750755
#                multitok_nochar    0.746015  0.746015
#                token_charcnn      0.748926  0.764399
#                token_charlstm     0.756099  0.770256
#                token_nochar       0.731924  0.745553
