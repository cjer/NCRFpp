# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('paper')
sns.set_style('white')

# %%
import pandas as pd
import configs

# %%
import os

# %%
import pickle
with open('hp_search/conf_json3/cnn_confs.pkl', 'rb') as f:
    cnn_confs = pickle.load(f)
with open('hp_search/conf_json3/lstm_confs.pkl', 'rb') as f:
    lstm_confs = pickle.load(f)
with open('hp_search/conf_json3/nochar_confs.pkl', 'rb') as f:
    nochar_confs = pickle.load(f)

# %%
len(cnn_confs[0]), len(lstm_confs[0]), len(nochar_confs[0])
# Out:
# (24, 23, 21)

# %%
cnn_confs[0]
# Out:
# {'word_seq_feature': 'LSTM',
#  'word_emb_dim': 300,
#  'char_emb_dim': 30,
#  'iteration': 200,
#  'bilstm': True,
#  'norm_word_emb': False,
#  'norm_char_emb': False,
#  'ave_batch_loss': False,
#  'l2': 1e-08,
#  'lstm_layer': 2,
#  'batch_size': 8,
#  'number_normalized': False,
#  'optimizer': 'SGD',
#  'nbest': 1,
#  'hidden_dim': 200,
#  'dropout': 0.4,
#  'use_char': True,
#  'use_crf': True,
#  'char_seq_feature': 'CNN',
#  'char_hidden_dim': 70,
#  'char_kernel_size': 7,
#  'learning_rate': 0.01,
#  'lr_decay': 0.05,
#  'momentum': 0}

# %%
cnn_confs[0]['number_normalized'], lstm_confs[0]['number_normalized'], nochar_confs[0]['number_normalized']
# Out:
# (False, False, False)

# %%
def change_value(cfs, k, v):
    for c in cfs:
        c[k] = v
change_value(cnn_confs, 'number_normalized', True)
change_value(lstm_confs, 'number_normalized', True)
change_value(nochar_confs, 'number_normalized', True)
cnn_confs[0]['number_normalized'], lstm_confs[0]['number_normalized'], nochar_confs[0]['number_normalized']
# Out:
# (True, True, True)

# %%
models_folder = 'hp_search/models8'
conf_folder = 'hp_search/conf8'
json_folder = 'hp_search/conf_json8'
logs_folder = 'hp_search/logs8'

# %%
if not os.path.exists(models_folder):
    os.mkdir(models_folder)
if not os.path.exists(conf_folder):
    os.mkdir(conf_folder)
if not os.path.exists(json_folder):
    os.mkdir(json_folder)
if not os.path.exists(logs_folder):
    os.mkdir(logs_folder)

# %%
import json
def create_all_confs(confs, arch_name, ds_name, emb_name, conf_folder, models_folder, json_folder):
    max_digits = len(str(len(confs)))
    full_confs = []
    for i, conf in enumerate(confs):
        fc = configs.create_conf_file(os.path.join(conf_folder, arch_name+f'.{str(i).zfill(max_digits)}.conf'), 
                                 os.path.join(models_folder, arch_name+f'.{str(i).zfill(max_digits)}.model'), 
                                 ds_name, 
                                 conf, 
                                 emb_name)
        full_confs.append(fc)

    for i, fc in enumerate(full_confs):
        with open( os.path.join(json_folder, arch_name+f'.{str(i).zfill(max_digits)}.json'), 'w') as of:
            of.write(json.dumps(fc))

# %%
create_all_confs(lstm_confs, 'morph_charlstm', 'gold_morpheme', 'htb_all_alt_tok_yap_ft_sg', 
                 conf_folder, models_folder, json_folder)

# %%
create_all_confs(cnn_confs, 'morph_charcnn', 'gold_morpheme', 'htb_all_alt_tok_yap_ft_sg', 
                 conf_folder, models_folder, json_folder)

# %% [markdown]
# ## Token

# %%
create_all_confs(lstm_confs, 'token_charlstm', 'gold_token_bioes', 'htb_all_alt_tok_tokenized_ft_sg', 
                 conf_folder, models_folder, json_folder)

# %%
create_all_confs(cnn_confs, 'token_charcnn', 'gold_token_bioes', 'htb_all_alt_tok_tokenized_ft_sg', 
                 conf_folder, models_folder, json_folder)

# %% [markdown]
# ## Token Multi-Tag

# %%
create_all_confs(lstm_confs, 'multitok_charlstm', 'gold_token_raw', 'htb_all_alt_tok_tokenized_ft_sg', 
                 conf_folder, models_folder, json_folder)

# %%
create_all_confs(cnn_confs, 'multitok_charcnn', 'gold_token_raw', 'htb_all_alt_tok_tokenized_ft_sg', 
                 conf_folder, models_folder, json_folder)

# %% [markdown]
# ## NoChar

# %%
create_all_confs(nochar_confs, 'morph_nochar', 'gold_morpheme', 'htb_all_alt_tok_yap_ft_sg', 
                 conf_folder, models_folder, json_folder)

# %%
create_all_confs(nochar_confs, 'token_nochar', 'gold_token_bioes', 'htb_all_alt_tok_tokenized_ft_sg', 
                 conf_folder, models_folder, json_folder)

# %%
create_all_confs(nochar_confs, 'multitok_nochar', 'gold_token_raw', 'htb_all_alt_tok_tokenized_ft_sg', 
                 conf_folder, models_folder, json_folder)

# %% [markdown]
# # RUNNING ON NLP08, NLP10, NLP11, NLP13, NLP05, NLP14
# cd NCRFpp/
# conda activate ncrf_gpu
# python run4_hp_search.py 3 token_charlstm.2

# %% [markdown]
# ## Check results

# %%
import pickle
with open('hp_search/conf_json3/cnn_confs.pkl', 'rb') as f:
    cnn_confs = pickle.load(f)
with open('hp_search/conf_json3/lstm_confs.pkl', 'rb') as f:
    lstm_confs = pickle.load(f)
with open('hp_search/conf_json3/nochar_confs.pkl', 'rb') as f:
    nochar_confs = pickle.load(f)

# %%
len(cnn_confs[0]), len(lstm_confs[0]), len(nochar_confs[0])

# %%
import re
import os
DEV_RES_LINE = re.compile('Dev: .*; acc: (?P<acc>[^,]+)(?:, p: (?P<p>[^,]+), r: (?P<r>[^,]+), f: (?P<f>[-\d\.]+))?')
#Dev: time: 0.94s speed: 536.09st/s; acc: 0.9043
#Dev: time: 3.42s, speed: 146.59st/s; acc: 0.9546, p: 0.7577, r: 0.6393, f: 0.6935

mtimes = []
res = []
archs = []
for f in os.scandir('hp_search/logs8'):
    if f.name.startswith('.ipy'):
        continue
    mtimes.append(os.path.getmtime(f.path))
    arch = f.name.split('.')[0]
    archs.append(arch)
    unit = arch.split('_')[0]
    conf_num = f.name.split('.')[1]
    if 'cnn' in arch:
        matching_conf = cnn_confs[int(conf_num)] 
    elif 'lstm' in arch: 
        matching_conf = lstm_confs[int(conf_num)]
    elif 'nochar' in arch:
        matching_conf = nochar_confs[int(conf_num)]
    params = { 'arch': arch, 'unit': unit, 'conf_num': conf_num}
    params.update(matching_conf)
    with open(f.path, 'r') as fp:
        i= 0
        for line in fp:
            m = DEV_RES_LINE.match(line)
            if m:
                r = m.groupdict().copy()
                for k, v in r.items():
                    if v is not None:
                        r[k] = float(v)
                r.update(params)
                r['epoch'] = i
                i+=1
                res.append(r)

rdf = pd.DataFrame(res)

rdf['model_file_name'] = rdf.arch + '.' + rdf.conf_num +'.model.' + rdf.epoch.astype(str) + '.model'
rdf['dset_file_name'] =  rdf.arch + '.' + rdf.conf_num +'.model.dset'
rdf['char_seq_feature'] = rdf.char_seq_feature.fillna('NoChar')

rdf['relevant_score'] = rdf.f.fillna(rdf.acc)

erdf = rdf[(rdf.groupby(['conf_num', 'arch']).relevant_score.transform(max)==rdf.relevant_score) ]
erdf = erdf[(erdf.groupby(['conf_num', 'arch']).epoch.transform(min)==erdf.epoch) ]

# %%
erdf.shape
# Out:
# (11, 35)

# %%
erdf.groupby('arch').size()
# Out:
# arch
# multitok_charcnn    2
# multitok_nochar     3
# token_charcnn       4
# token_nochar        2
# dtype: int64

# %%
from collections import Counter
archs = Counter(archs)
archs
# Out:
# Counter({'token_nochar': 2,
#          'token_charcnn': 4,
#          'multitok_nochar': 3,
#          'multitok_charcnn': 2})

# %%
print ('Mean time per run:', round((max(mtimes) - min(mtimes) )/ len(mtimes) / 60, 2), 'minutes')
# Out:
# Mean time per run: 3.66 minutes

# %%
import numpy as np 
def perc(n):
    def perc_(x):
        return np.percentile(x, n)
    perc_.__name__ = 'perc_%s' % n
    return perc_

erdf.groupby(['unit', 'char_seq_feature']).f.agg(['max', 'min', 'mean', 'std', 'median', perc(95)])
# Out:
#                               max     min      mean       std   median  \
# unit     char_seq_feature
# multitok CNN                  NaN     NaN       NaN       NaN      NaN
#          NoChar               NaN     NaN       NaN       NaN      NaN
# token    CNN               0.7815  0.7743  0.778175  0.002979  0.77845
#          NoChar            0.7678  0.7655  0.766650  0.001626  0.76665
#
#                             perc_95
# unit     char_seq_feature
# multitok CNN                    NaN
#          NoChar                 NaN
# token    CNN               0.781110
#          NoChar            0.767685

# %% [markdown]
# ## Evaluate files (Mention Evaluation)

# %%
import sys
sys.path.append('../NER')

# %%
import ne_evaluate_mentions as nem

# %% [markdown]
# ## Create configs for decoding

# %%
model_folder = 'hp_search/models8'
output_folder = 'hp_search/decode_output8'
conf_folder = 'hp_search/decode_conf8'
logs_folder = 'hp_search/decode_logs8'

if not os.path.exists(output_folder):
    os.mkdir(output_folder)

if not os.path.exists(conf_folder):
    os.mkdir(conf_folder)
    
if not os.path.exists(logs_folder):
    os.mkdir(logs_folder)
    
decode_sets = {
    'morph': {
        'morph_dev_gold': '../NER/data/for_ncrf/morph_gold_dev.bmes',
        'morph_dev_yap': '../NER/data/for_ncrf/morph_yap_dev_dummy_o.bmes',
        'morph_test_gold': '../NER/data/for_ncrf/morph_gold_test.bmes',
        'morph_test_yap': '../NER/data/for_ncrf/morph_yap_test_dummy_o.bmes',
    },
    'token': {
        'token_dev': '../NER/data/for_ncrf/token_gold_dev_fix.bmes',
        'token_test': '../NER/data/for_ncrf/token_gold_test_fix.bmes',
    },
    'multitok': {
        'token_dev': '../NER/data/for_ncrf/token_gold_dev_concat.bmes',
        'token_test': '../NER/data/for_ncrf/token_gold_test_concat.bmes',
    }
}

params = { 'status': 'decode' }

for i, row in erdf.iterrows():
    unit = row['arch'].split('_')[0]
    for name, set_path in decode_sets[unit].items():
        row_par = params.copy()
        row_par['load_model_dir'] = os.path.join(model_folder, row['model_file_name'])
        row_par['dset_dir'] = os.path.join(model_folder, row['dset_file_name'])
        row_par['decode_dir'] = os.path.join(output_folder, name+'.'+row['arch']+'.'+row['conf_num']+'.bmes')
        row_par['raw_dir'] = set_path
        
        conf_path = os.path.join(conf_folder, name+'.'+row['arch']+'.'+row['conf_num']+'.decode.conf')
        if not os.path.exists(conf_path):
            with open(conf_path, 'w', encoding='utf8') as of:
                for k, v in row_par.items():
                    of.write(k+'='+str(v)+'\n')

# %% [markdown]
# ## Evaluate decoded folder

# %%
scores = {}

# %%
if os.path.exists('hp_search/scores8.pkl'):
    scores = pickle.load(open('hp_search/scores8.pkl', 'rb'))

# %%
for file in os.scandir(output_folder):
    if file.name=='.ipynb_checkpoints':
        continue
    gold_name, arch, conf_num = file.name.split('.')[:3]
    if (gold_name, arch, conf_num) not in scores:
        _, charsf = arch.split('_')
        if len(gold_name.split('_'))>2:
            unit, pred_set, _ = gold_name.split('_')
            gold_path = decode_sets[unit][unit+'_'+pred_set+'_gold']
        else:
            unit, pred_set = gold_name.split('_')
            gold_path = decode_sets[unit][unit+'_'+pred_set]
        p, r, f = nem.evaluate_files(gold_path, file)
        scores[(gold_name, arch, conf_num)] = (p, r, f)
    
pickle.dump(scores, open('hp_search/scores8.pkl', 'wb'))

# %%
score_tups = [(*k, *v) for k,v in scores.items()]

# %%
mev = pd.DataFrame(score_tups, columns=('gold_name', 'arch', 'conf_num', 'p', 'r', 'f'))
mev[mev.gold_name.str.contains('dev')].groupby(['gold_name', 'arch']).f.agg(['max', 'min', 'mean', 'std', 'median', perc(95)])
# Out:
#                                  max       min      mean  std    median  \
# gold_name arch
# token_dev multitok_charcnn  0.773504  0.773504  0.773504  NaN  0.773504
#           multitok_nochar   0.773446  0.773446  0.773446  NaN  0.773446
#           token_charcnn     0.778013  0.778013  0.778013  NaN  0.778013
#           token_nochar      0.768577  0.768577  0.768577  NaN  0.768577
#
#                              perc_95
# gold_name arch
# token_dev multitok_charcnn  0.773504
#           multitok_nochar   0.773446
#           token_charcnn     0.778013
#           token_nochar      0.768577

# %%
mev['pred_set'] = mev.gold_name.apply(lambda x: '_'.join(x.split('_')[1:]).replace('_yap', ''))

# %%
mev = mev.set_index(['arch', 'conf_num', 'pred_set'])[['p', 'r', 'f']].unstack()
mev.columns = ['_'.join(col).rstrip('_') for col in mev.columns.values]
mev.head()
# Out:
#                            p_dev  p_dev_gold    p_test  p_test_gold     r_dev  \
# arch          conf_num
# morph_charcnn 00        0.678715    0.757028  0.637339     0.763948  0.789720
#               01        0.674699    0.759036  0.639485     0.758584  0.785047
#               02        0.686747    0.767068  0.649142     0.780043  0.777273
#               03        0.686747    0.773092  0.656652     0.781116  0.763393
#               04        0.680723    0.755020  0.650215     0.778970  0.781106
#
#                         r_dev_gold    r_test  r_test_gold     f_dev  \
# arch          conf_num
# morph_charcnn 00          0.847191  0.704626     0.787611  0.730022
#               01          0.843750  0.720677     0.797968  0.725702
#               02          0.845133  0.713443     0.804204  0.729211
#               03          0.833333  0.701835     0.783638  0.723044
#               04          0.830022  0.715466     0.800441  0.727468
#
#                         f_dev_gold    f_test  f_test_gold
# arch          conf_num
# morph_charcnn 00          0.799576  0.669296     0.775599
#               01          0.799154  0.677658     0.777778
#               02          0.804211  0.679775     0.791939
#               03          0.802083  0.678492     0.782375
#               04          0.790747  0.681282     0.789560

# %%
erdf = erdf.merge(mev.reset_index(), on=['arch', 'conf_num'])

# %%
sns.catplot(kind='violin', row='char_seq_feature', col='unit', 
            x="learning_rate", y="f_dev", #hue='batch_size',
                data=erdf, palette="Set2",
                scale="count", inner="box", scale_hue=True)

# %%
>>> g = sns.FacetGrid(erdf[erdf.unit=='morph'].rename(columns={'learning_rate': 'lr', 'char_seq_feature': 'charsf'}), col='charsf')
>>> g = g.map(plt.scatter, "f_dev_gold", "f_dev", edgecolor="w")

# %%
cols = ['f', 'p', 'r', 'char_seq_feature', 'lstm_layer', 'batch_size', 
        'learning_rate', 'char_hidden_dim', 'char_kernel_size',
        'hidden_dim', 'dropout', 'epoch']

# %%
(erdf[erdf.unit=='morph'].sort_values('f', ascending=False).head(20)[['arch', 'conf_num', 'epoch', 'f']]).fillna('')
# Out:
#                arch conf_num  epoch       f
# 21    morph_charcnn       09    103  0.8118
# 37   morph_charlstm        1    126  0.8113
# 19     morph_nochar        0    107  0.8075
# 62    morph_charcnn       22     42  0.8072
# 64    morph_charcnn       02    102  0.8038
# 51   morph_charlstm        4    169  0.8038
# 89    morph_charcnn       17     28  0.8034
# 100   morph_charcnn       16     34  0.8004
# 75    morph_charcnn       13    131  0.8004
# 68    morph_charcnn       18     71  0.8004
# 77    morph_charcnn       03     56  0.8004
# 18    morph_charcnn       00    116  0.8000
# 50    morph_charcnn       07    102  0.8000
# 17   morph_charlstm        0     74  0.7996
# 22   morph_charlstm        6     92  0.7992
# 74    morph_charcnn       23     56  0.7992
# 61   morph_charlstm        2     43  0.7987
# 36     morph_nochar        1    139  0.7987
# 13    morph_charcnn       10     17  0.7987
# 20    morph_charcnn       20    124  0.7979

# %%
erdf.groupby('arch').epoch.agg(['max', 'min', 'mean', 'std', 'median', perc(95)])
# Out:
#                    max  min        mean        std  median  perc_95
# arch
# morph_charcnn      193   17   80.166667  49.821129    74.0   180.20
# morph_charlstm     169   43  108.875000  39.280811   115.0   156.40
# morph_nochar       139   29   98.000000  47.902679   112.0   135.70
# multitok_charcnn   184   22   99.958333  45.067562   109.0   157.55
# multitok_charlstm  167   20  101.875000  57.177512   114.5   162.80
# multitok_nochar    169   72  101.500000  45.420260    82.5   156.70
# token_charcnn      179   35  101.041667  44.441930   100.5   165.50
# token_charlstm     161   55   92.500000  37.109875    83.0   148.75
# token_nochar       178  101  134.250000  35.226647   129.0   173.35

# %%
(erdf[erdf.unit=='token'].sort_values('f', ascending=False).head(20)[['arch', 'conf_num', 'epoch', 'f']]).fillna('')
# Out:
#                arch conf_num  epoch       f
# 26    token_charcnn       22    104  0.7928
# 66    token_charcnn       21    118  0.7885
# 83   token_charlstm        4     71  0.7853
# 101   token_charcnn       13     90  0.7851
# 56   token_charlstm        2     55  0.7836
# 2     token_charcnn       00     51  0.7835
# 96    token_charcnn       11    179  0.7835
# 0      token_nochar        0    111  0.7829
# 25    token_charcnn       01     35  0.7816
# 65    token_charcnn       03    121  0.7803
# 78    token_charcnn       04    123  0.7802
# 47    token_charcnn       14    167  0.7797
# 27    token_charcnn       12     74  0.7794
# 9    token_charlstm        0    126  0.7792
# 49   token_charlstm        5    161  0.7777
# 95    token_charcnn       06    153  0.7769
# 85    token_charcnn       05    157  0.7761
# 1     token_charcnn       10     54  0.7760
# 88    token_charcnn       19     38  0.7759
# 45    token_charcnn       02     97  0.7758

# %%
(erdf[erdf.unit=='morph'].sort_values('f_dev', ascending=False).head(20)[cols]).fillna('')
# Out:
#           f       p       r char_seq_feature  lstm_layer  batch_size  \
# 19   0.8075  0.8398  0.7776           NoChar           2           8
# 40   0.7954  0.8396  0.7555              CNN           2           8
# 21   0.8118  0.8591  0.7695              CNN           2           8
# 75   0.8004  0.8460  0.7595              CNN           2           8
# 62   0.8072  0.8511  0.7675              CNN           2           8
# 37   0.8113  0.8457  0.7796             LSTM           2           8
# 51   0.8038  0.8436  0.7675             LSTM           2           8
# 18   0.8000  0.8475  0.7575              CNN           2           8
# 22   0.7992  0.8407  0.7615             LSTM           2           8
# 64   0.8038  0.8436  0.7675              CNN           2           8
# 17   0.7996  0.8441  0.7595             LSTM           2           8
# 87   0.7891  0.8282  0.7535              CNN           2           8
# 102  0.7975  0.8468  0.7535              CNN           2           8
# 100  0.8004  0.8460  0.7595              CNN           2           8
# 42   0.7911  0.8352  0.7515              CNN           2           8
# 41   0.7975  0.8419  0.7575              CNN           2           8
# 89   0.8034  0.8451  0.7655              CNN           2           8
# 23   0.7975  0.8370  0.7615             LSTM           2           8
# 36   0.7987  0.8523  0.7515           NoChar           2           8
# 61   0.7987  0.8374  0.7635             LSTM           2           8
#
#      learning_rate char_hidden_dim char_kernel_size  hidden_dim  dropout  \
# 19           0.010                                          200      0.5
# 40           0.010              50                7         200      0.4
# 21           0.010              50                5         200      0.4
# 75           0.010              50                7         200      0.5
# 62           0.010              70                7         200      0.5
# 37           0.005              70                          200      0.5
# 51           0.010              70                          200      0.5
# 18           0.010              70                7         200      0.4
# 22           0.010              70                          200      0.4
# 64           0.010              70                3         200      0.5
# 17           0.005              50                          200      0.5
# 87           0.005              50                3         200      0.5
# 102          0.005              70                5         200      0.4
# 100          0.010              50                3         200      0.5
# 42           0.005              50                3         200      0.4
# 41           0.005              70                7         200      0.5
# 89           0.005              50                5         200      0.4
# 23           0.005              70                          200      0.4
# 36           0.005                                          200      0.5
# 61           0.010              50                          200      0.5
#
#      epoch
# 19     107
# 40     188
# 21     103
# 75     131
# 62      42
# 37     126
# 51     169
# 18     116
# 22      92
# 64     102
# 17      74
# 87     193
# 102     77
# 100     34
# 42      53
# 41      43
# 89      28
# 23     104
# 36     139
# 61      43

# %%
(erdf[erdf.unit=='morph'].sort_values('f_dev', ascending=True).head(20)[cols]).fillna('')
# Out:
#          f       p       r char_seq_feature  lstm_layer  batch_size  \
# 35  0.7895  0.8315  0.7515              CNN           2           8
# 8   0.7920  0.8322  0.7555           NoChar           2           8
# 94  0.7944  0.8529  0.7435              CNN           2           8
# 60  0.7975  0.8370  0.7615           NoChar           2           8
# 50  0.8000  0.8426  0.7615              CNN           2           8
# 32  0.7941  0.8344  0.7575             LSTM           2           8
# 97  0.7906  0.8416  0.7455              CNN           2           8
# 58  0.7979  0.8503  0.7515              CNN           2           8
# 34  0.7962  0.8516  0.7475              CNN           2           8
# 76  0.7883  0.8264  0.7535             LSTM           2           8
# 74  0.7992  0.8359  0.7655              CNN           2           8
# 20  0.7979  0.8555  0.7475              CNN           2           8
# 13  0.7987  0.8472  0.7555              CNN           2           8
# 77  0.8004  0.8315  0.7715              CNN           2           8
# 84  0.7971  0.8385  0.7595              CNN           2           8
# 68  0.8004  0.8460  0.7595              CNN           2           8
# 61  0.7987  0.8374  0.7635             LSTM           2           8
# 36  0.7987  0.8523  0.7515           NoChar           2           8
# 23  0.7975  0.8370  0.7615             LSTM           2           8
# 89  0.8034  0.8451  0.7655              CNN           2           8
#
#     learning_rate char_hidden_dim char_kernel_size  hidden_dim  dropout  epoch
# 35          0.005              50                7         200      0.5     87
# 8           0.005                                          200      0.4     29
# 94          0.005              70                5         200      0.5     18
# 60          0.010                                          200      0.4    117
# 50          0.005              50                5         200      0.5    102
# 32          0.005              50                          200      0.4    130
# 97          0.010              70                5         200      0.4     33
# 58          0.010              70                3         200      0.4    136
# 34          0.005              70                3         200      0.5     84
# 76          0.010              50                          200      0.4    133
# 74          0.005              70                7         200      0.4     56
# 20          0.010              50                5         200      0.5    124
# 13          0.005              50                7         200      0.4     17
# 77          0.010              70                5         200      0.5     56
# 84          0.010              50                3         200      0.4     30
# 68          0.005              70                3         200      0.4     71
# 61          0.010              50                          200      0.5     43
# 36          0.005                                          200      0.5    139
# 23          0.005              70                          200      0.4    104
# 89          0.005              50                5         200      0.4     28

# %%
(erdf[erdf.unit=='token'].sort_values('f_dev', ascending=False).head(20)[cols]).fillna('')
# Out:
#          f       p       r char_seq_feature  lstm_layer  batch_size  \
# 26  0.7928  0.8389  0.7515              CNN           2           8
# 66  0.7885  0.8444  0.7395              CNN           2           8
# 83  0.7853  0.8271  0.7475             LSTM           2           8
# 2   0.7835  0.8281  0.7435              CNN           2           8
# 56  0.7836  0.8234  0.7475             LSTM           2           8
# 96  0.7835  0.8281  0.7435              CNN           2           8
# 0   0.7829  0.8170  0.7515           NoChar           2           8
# 25  0.7816  0.8166  0.7495              CNN           2           8
# 65  0.7803  0.8162  0.7475              CNN           2           8
# 78  0.7802  0.8208  0.7435              CNN           2           8
# 27  0.7794  0.8190  0.7435              CNN           2           8
# 47  0.7797  0.8270  0.7375              CNN           2           8
# 49  0.7777  0.8200  0.7395             LSTM           2           8
# 9   0.7792  0.8113  0.7495             LSTM           2           8
# 95  0.7769  0.8311  0.7295              CNN           2           8
# 88  0.7759  0.8043  0.7495              CNN           2           8
# 85  0.7761  0.8292  0.7295              CNN           2           8
# 1   0.7760  0.8164  0.7395              CNN           2           8
# 45  0.7758  0.8258  0.7315              CNN           2           8
# 38  0.7749  0.8114  0.7415           NoChar           2           8
#
#     learning_rate char_hidden_dim char_kernel_size  hidden_dim  dropout  epoch
# 26          0.010              70                7         200      0.5    104
# 66          0.010              50                7         200      0.4    118
# 83          0.010              70                          200      0.5     71
# 2           0.010              70                7         200      0.4     51
# 56          0.010              50                          200      0.5     55
# 96          0.005              70                3         200      0.5    179
# 0           0.010                                          200      0.5    111
# 25          0.005              70                7         200      0.5     35
# 65          0.010              70                5         200      0.5    121
# 78          0.005              50                3         200      0.5    123
# 27          0.010              70                3         200      0.4     74
# 47          0.010              50                3         200      0.4    167
# 49          0.005              50                          200      0.4    161
# 9           0.005              50                          200      0.5    126
# 95          0.005              70                5         200      0.4    153
# 88          0.005              50                3         200      0.4     38
# 85          0.010              70                5         200      0.4    157
# 1           0.005              50                7         200      0.4     54
# 45          0.010              70                3         200      0.5     97
# 38          0.010                                          200      0.4    147

# %%
(erdf[erdf.unit=='token'].sort_values('f_dev', ascending=True).head(20)[cols]).fillna('')
# Out:
#          f       p       r char_seq_feature  lstm_layer  batch_size  \
# 59  0.7611  0.8054  0.7214           NoChar           2           8
# 24  0.7637  0.8062  0.7255           NoChar           2           8
# 93  0.7660  0.8040  0.7315             LSTM           2           8
# 3   0.7669  0.8135  0.7255              CNN           2           8
# 5   0.7671  0.8089  0.7295              CNN           2           8
# 72  0.7696  0.8143  0.7295             LSTM           2           8
# 79  0.7708  0.8026  0.7415              CNN           2           8
# 67  0.7746  0.8206  0.7335              CNN           2           8
# 6   0.7749  0.8239  0.7315             LSTM           2           8
# 48  0.7755  0.8056  0.7475              CNN           2           8
# 28  0.7747  0.8039  0.7475             LSTM           2           8
# 38  0.7749  0.8114  0.7415           NoChar           2           8
# 45  0.7758  0.8258  0.7315              CNN           2           8
# 1   0.7760  0.8164  0.7395              CNN           2           8
# 85  0.7761  0.8292  0.7295              CNN           2           8
# 88  0.7759  0.8043  0.7495              CNN           2           8
# 95  0.7769  0.8311  0.7295              CNN           2           8
# 9   0.7792  0.8113  0.7495             LSTM           2           8
# 49  0.7777  0.8200  0.7395             LSTM           2           8
# 47  0.7797  0.8270  0.7375              CNN           2           8
#
#     learning_rate char_hidden_dim char_kernel_size  hidden_dim  dropout  epoch
# 59          0.005                                          200      0.4    178
# 24          0.005                                          200      0.5    101
# 93          0.005              70                          200      0.4    105
# 3           0.010              50                5         200      0.5    118
# 5           0.010              50                5         200      0.4     56
# 72          0.010              50                          200      0.4     95
# 79          0.005              50                5         200      0.4     71
# 67          0.005              70                5         200      0.5    157
# 6           0.010              70                          200      0.4     56
# 48          0.005              70                7         200      0.4     73
# 28          0.005              70                          200      0.5     71
# 38          0.010                                          200      0.4    147
# 45          0.010              70                3         200      0.5     97
# 1           0.005              50                7         200      0.4     54
# 85          0.010              70                5         200      0.4    157
# 88          0.005              50                3         200      0.4     38
# 95          0.005              70                5         200      0.4    153
# 9           0.005              50                          200      0.5    126
# 49          0.005              50                          200      0.4    161
# 47          0.010              50                3         200      0.4    167

# %%
erdf.groupby('arch').epoch.agg(['median', 'mean', 'std'])
# Out:
#                    median        mean        std
# arch
# morph_charcnn          95   88.500000  38.370562
# morph_charlstm         98  100.000000  23.494680
# morph_nochar           68   68.000000  55.154329
# multitok_charcnn      106  104.285714  48.082271
# multitok_charlstm      83   83.000000  16.970563
# multitok_nochar        87  111.333333  50.143128
# token_charcnn          56   70.285714  30.313442
# token_charlstm         71   84.333333  36.855574
# token_nochar          106  106.000000   7.071068

# %%
sns.swarmplot(data=erdf, x='unit', y='f_dev', hue='char_seq_feature', dodge=True)

# %%
sns.violinplot(data=erdf, x='unit', y='f_dev', hue='char_seq_feature', inner='stick')

# %% [markdown]
# ## Learning rate

# %%
erdf.groupby(['optimizer', 'learning_rate', 'arch']).conf_num.nunique().unstack()
# Out:
# arch                     morph_charcnn  morph_charlstm  morph_nochar  \
# optimizer learning_rate
# SGD       0.005                      7               4             2
#           0.010                     11               3             2
#
# arch                     multitok_charcnn  multitok_charlstm  multitok_nochar  \
# optimizer learning_rate
# SGD       0.005                         6                  4                2
#           0.010                        10                  4                2
#
# arch                     token_charcnn  token_charlstm  token_nochar
# optimizer learning_rate
# SGD       0.005                      8               4             2
#           0.010                      8               4             2

# %%
erdf.groupby(['optimizer', 'learning_rate', 'arch']).f_dev.median().unstack()
# Out:
# arch                     morph_charcnn  morph_charlstm  morph_nochar  \
# optimizer learning_rate
# SGD       0.005               0.722162        0.726104      0.718385
#           0.010               0.729616        0.726600      0.726482
#
# arch                     multitok_charcnn  multitok_charlstm  multitok_nochar  \
# optimizer learning_rate
# SGD       0.005                  0.772967           0.774611         0.783426
#           0.010                  0.770957           0.774641         0.775959
#
# arch                     token_charcnn  token_charlstm  token_nochar
# optimizer learning_rate
# SGD       0.005               0.776739        0.776912      0.762809
#           0.010               0.779124        0.779280      0.779281

# %%
erdf.groupby(['optimizer', 'learning_rate', 'arch']).f_dev.max().unstack()
# Out:
# arch                     morph_charcnn  morph_charlstm  morph_nochar  \
# optimizer learning_rate
# SGD       0.005               0.727468        0.731707      0.724324
#           0.010               0.737634        0.731343      0.738070
#
# arch                     multitok_charcnn  multitok_charlstm  multitok_nochar  \
# optimizer learning_rate
# SGD       0.005                  0.781780           0.781152         0.785340
#           0.010                  0.778723           0.780021         0.781876
#
# arch                     token_charcnn  token_charlstm  token_nochar
# optimizer learning_rate
# SGD       0.005               0.783527        0.778481      0.764520
#           0.010               0.792812        0.785263      0.782881

# %%
plt.figure(figsize=(12,5))
g = sns.swarmplot(data=erdf, hue='learning_rate', y='f_dev', x='arch', split=True)

# %%
sns.catplot(kind='violin', row='char_seq_feature', col='unit', 
            x="learning_rate", y="f_dev", #hue='batch_size',
                data=erdf, palette="Set2",
                scale="count", inner="box", scale_hue=True)

# %%
from scipy.stats import f_oneway

anov = {}
for a in erdf.arch.unique():
        anov[a] = f_oneway(erdf[(erdf.arch==a) & (erdf.learning_rate==0.005)].f_dev,
                             erdf[(erdf.arch==a) & (erdf.learning_rate==0.01)].f_dev,
                )
anov
# Out:
# {'token_nochar': F_onewayResult(statistic=17.08208424301395, pvalue=0.05385537773583853),
#  'token_charcnn': F_onewayResult(statistic=0.2026884728573448, pvalue=0.6569646270595475),
#  'multitok_nochar': F_onewayResult(statistic=1.442028593023551, pvalue=0.35273861372282656),
#  'token_charlstm': F_onewayResult(statistic=0.6691114275709772, pvalue=0.44462423872714374),
#  'multitok_charcnn': F_onewayResult(statistic=3.985488229119226e-05, pvalue=0.9950198280065146),
#  'morph_nochar': F_onewayResult(statistic=0.3866104530696531, pvalue=0.59751840363168),
#  'multitok_charlstm': F_onewayResult(statistic=0.2753705040792583, pvalue=0.6185671287686626),
#  'morph_charcnn': F_onewayResult(statistic=5.99019219336127, pvalue=0.022831741001739052),
#  'morph_charlstm': F_onewayResult(statistic=0.07435256740643002, pvalue=0.7942433506936235)}

# %%
sns.violinplot(data=erdf, x='learning_rate', y='epoch', inner='stick')

# %% [markdown]
# ### Do the lower scores in the lower learning rate come from lack of epochs?

# %%
sns.scatterplot(data=erdf.assign(lr=lambda x: x.learning_rate.astype('str')), hue='lr', x='epoch', y='f_dev',
               palette=sns.color_palette("Set1", erdf.learning_rate.nunique()))

# %%
>>> g = sns.FacetGrid(erdf.rename(columns={'learning_rate': 'lr', 'char_seq_feature': 'charsf'}), col="lr", row='charsf')
>>> g = g.map(plt.scatter, "epoch", "f_dev", edgecolor="w")

# %% [raw]
# >>> g = sns.FacetGrid(erdf[erdf.unit=='morph'].rename(columns={'learning_rate': 'lr', 'char_seq_feature': 'charsf'}), col="lr", row='charsf')
# >>> g = g.map(sns.kdeplot, "epoch", "f_dev")

# %% [raw]
# >>> g = sns.FacetGrid(erdf[erdf.unit=='token'].rename(columns={'learning_rate': 'lr', 'char_seq_feature': 'charsf'}), col="lr", row='charsf')
# >>> g = g.map(sns.kdeplot, "epoch", "f")

# %%
>>> g = sns.FacetGrid(erdf.rename(columns={'char_seq_feature': 'charsf'}), col="batch_size", row='charsf')
>>> g = g.map(plt.scatter, "epoch", "f", edgecolor="w")

# %%
>>> g = sns.FacetGrid(erdf.rename(columns={'char_seq_feature': 'charsf'}), col="batch_size", row='charsf')
>>> g = g.map(sns.kdeplot, "epoch", "f")

# %%
sns.swarmplot(data=erdf, x='arch', y='epoch')

# %% [markdown]
# ## Char CNN window size

# %%
erdf.groupby(['unit', 'char_kernel_size']).f_dev.mean().unstack()
# Out:
# char_kernel_size       3.0       5.0       7.0
# unit
# morph             0.724344  0.722903  0.726968
# multitok          0.774297  0.767934  0.765420
# token             0.778370  0.773274  0.783160

# %%
plt.figure(figsize=(12,5))
sns.swarmplot(data=erdf, x='arch', y='f_dev', hue='char_kernel_size', split=True)

# %%
sns.catplot(kind='violin', col='unit', x="char_kernel_size", y="f_dev",
                data=erdf, palette="Set2", 
                scale="count", inner="box")

# %%
from scipy.stats import f_oneway

anov = {}
for a in erdf.arch.unique():
    if 'charcnn' in a:
        anov[a] = f_oneway(erdf[(erdf.arch==a) &   (erdf.char_kernel_size==3)].f_dev,
                             erdf[(erdf.arch==a) & (erdf.char_kernel_size==5)].f_dev,
                             erdf[(erdf.arch==a) & (erdf.char_kernel_size==7)].f_dev
                )
anov
# Out:
# {'token_charcnn': F_onewayResult(statistic=7.723003511981166, pvalue=0.0030618088363864224),
#  'multitok_charcnn': F_onewayResult(statistic=2.620820724537918, pvalue=0.0963600737372599),
#  'morph_charcnn': F_onewayResult(statistic=0.7105064857234022, pvalue=0.5028317362434915)}

# %% [markdown]
# ## Dropout

# %%
erdf.groupby(['dropout', 'arch']).f_dev.median().unstack()
# Out:
# arch     morph_charcnn  morph_charlstm  morph_nochar  multitok_charcnn  \
# dropout
# 0.4           0.724340        0.722700      0.713670          0.765642
# 0.5           0.723044        0.729504      0.731197          0.774500
#
# arch     multitok_charlstm  multitok_nochar  token_charcnn  token_charlstm  \
# dropout
# 0.4               0.772657         0.777691       0.776739        0.772251
# 0.5               0.778546         0.781694       0.780283        0.780985
#
# arch     token_nochar
# dropout
# 0.4           0.76839
# 0.5           0.77370

# %%
plt.figure(figsize=(12,5))
sns.swarmplot(data=erdf, x='arch', y='f_dev', hue='dropout', split=True)

# %%
from scipy.stats import f_oneway

anov = {}
for a in erdf.arch.unique():
        anov[a] = f_oneway(erdf[(erdf.arch==a) & (erdf.dropout==0.4)].f_dev,
                             erdf[(erdf.arch==a) & (erdf.dropout==0.5)].f_dev,
                )
anov
# Out:
# {'token_nochar': F_onewayResult(statistic=0.20513897452662255, pvalue=0.6949955979291704),
#  'token_charcnn': F_onewayResult(statistic=0.07028084321220335, pvalue=0.793396462340472),
#  'multitok_nochar': F_onewayResult(statistic=0.2737057857205389, pvalue=0.6530436379370816),
#  'token_charlstm': F_onewayResult(statistic=5.412878385566709, pvalue=0.05891751869482368),
#  'multitok_charcnn': F_onewayResult(statistic=2.7296501395695416, pvalue=0.11270336351849328),
#  'morph_nochar': F_onewayResult(statistic=6.303759634528305, pvalue=0.12871058535116103),
#  'multitok_charlstm': F_onewayResult(statistic=6.109419948818164, pvalue=0.04834457161500776),
#  'morph_charcnn': F_onewayResult(statistic=0.7053679020704857, pvalue=0.41002046255424995),
#  'morph_charlstm': F_onewayResult(statistic=2.8684051956028758, pvalue=0.14127512664667563)}

# %% [markdown]
# ## Hidden dimensions

# %% [markdown]
# ### CLSTM / CCNN

# %%
erdf.groupby(['char_hidden_dim', 'arch']).f_dev.median().unstack()
# Out:
# arch             morph_charcnn  morph_charlstm  multitok_charcnn  \
# char_hidden_dim
# 50.0                  0.725322        0.722221          0.774880
# 70.0                  0.723201        0.730479          0.766595
#
# arch             multitok_charlstm  token_charcnn  token_charlstm
# char_hidden_dim
# 50.0                      0.773816       0.776382        0.778418
# 70.0                      0.777417       0.779412        0.775207

# %%
erdf.groupby(['char_hidden_dim', 'arch']).f_dev.mean().unstack()
# Out:
# arch             morph_charcnn  morph_charlstm  multitok_charcnn  \
# char_hidden_dim
# 50.0                  0.725759        0.722322          0.772050
# 70.0                  0.723718        0.729302          0.766384
#
# arch             multitok_charlstm  token_charcnn  token_charlstm
# char_hidden_dim
# 50.0                      0.772055       0.776337        0.777502
# 70.0                      0.777035       0.780199        0.775219

# %%
plt.figure(figsize=(12,5))
sns.swarmplot(data=erdf, x='arch', y='f_dev', hue='char_hidden_dim', split=True)

# %%
plt.figure(figsize=(12,5))
sns.swarmplot(data=erdf, x='arch', y='f_dev', hue='char_hidden_dim', split=True)

# %%
sns.catplot(kind='violin', row='unit', col='char_seq_feature', 
            x="char_hidden_dim", y="f_dev",
                data=erdf, palette="Set2", split=True,
                scale="count", inner="stick", scale_hue=True)

# %%
from scipy.stats import f_oneway

anov = {}
for a in erdf.arch.unique():
    if 'charcnn' in a:
        anov[a] = f_oneway(erdf[(erdf.arch==a) &   (erdf.char_hidden_dim==3)].f_dev,
                             erdf[(erdf.arch==a) & (erdf.char_hidden_dim==5)].f_dev,
                             erdf[(erdf.arch==a) & (erdf.char_hidden_dim==7)].f_dev
                )
anov

# %%
relevant_cols = ['arch', 'f_dev', 'char_hidden_dim', 'char_kernel_size', 'learning_rate']

# %%
erdf[relevant_cols].groupby('arch').apply(lambda x: x.sort_values('f_dev', ascending=False).head(2))
# Out:
#                                    arch     f_dev  char_hidden_dim  \
# arch
# morph_charcnn     40      morph_charcnn  0.737634             50.0
#                   21      morph_charcnn  0.737069             50.0
# morph_charlstm    37     morph_charlstm  0.731707             70.0
#                   51     morph_charlstm  0.731343             70.0
# morph_nochar      19       morph_nochar  0.738070              NaN
#                   36       morph_nochar  0.724324              NaN
# multitok_charcnn  86   multitok_charcnn  0.781780             50.0
#                   29   multitok_charcnn  0.780384             70.0
# multitok_charlstm 16  multitok_charlstm  0.781152             70.0
#                   63  multitok_charlstm  0.780021             70.0
# multitok_nochar   4     multitok_nochar  0.785340              NaN
#                   15    multitok_nochar  0.781876              NaN
# token_charcnn     26      token_charcnn  0.792812             70.0
#                   66      token_charcnn  0.789305             50.0
# token_charlstm    83     token_charlstm  0.785263             70.0
#                   56     token_charlstm  0.783613             50.0
# token_nochar      0        token_nochar  0.782881              NaN
#                   38       token_nochar  0.775681              NaN
#
#                       char_kernel_size  learning_rate
# arch
# morph_charcnn     40               7.0          0.010
#                   21               5.0          0.010
# morph_charlstm    37               NaN          0.005
#                   51               NaN          0.010
# morph_nochar      19               NaN          0.010
#                   36               NaN          0.005
# multitok_charcnn  86               3.0          0.005
#                   29               3.0          0.005
# multitok_charlstm 16               NaN          0.005
#                   63               NaN          0.010
# multitok_nochar   4                NaN          0.005
#                   15               NaN          0.010
# token_charcnn     26               7.0          0.010
#                   66               7.0          0.010
# token_charlstm    83               NaN          0.010
#                   56               NaN          0.010
# token_nochar      0                NaN          0.010
#                   38               NaN          0.010

# %%
rdf[rdf.groupby('arch').f.transform(max)==rdf.f].sort_values('f', ascending=False).T
# Out:
#                                               17957  \
# acc                                            0.97
# p                                            0.8558
# r                                            0.7495
# f                                            0.7991
# arch                                  morph_charcnn
# unit                                          morph
# conf_num                                        017
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        1
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      200
# dropout                                         0.6
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  50
# char_kernel_size                                  5
# learning_rate                                 0.005
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            57
# model_file_name    morph_charcnn.017.model.57.model
# dset_file_name         morph_charcnn.017.model.dset
#
#                                                13826  \
# acc                                           0.9679
# p                                             0.8519
# r                                             0.7495
# f                                             0.7974
# arch                                  morph_charlstm
# unit                                           morph
# conf_num                                         011
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         2
# batch_size                                         1
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       100
# dropout                                          0.5
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   70
# char_kernel_size                                 NaN
# learning_rate                                  0.015
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             26
# model_file_name    morph_charlstm.011.model.26.model
# dset_file_name         morph_charlstm.011.model.dset
#
#                                              40290  \
# acc                                         0.9666
# p                                           0.8612
# r                                           0.7214
# f                                           0.7852
# arch                                  morph_nochar
# unit                                         morph
# conf_num                                       071
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       1
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                      50
# dropout                                        0.4
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                 0.01
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           90
# model_file_name    morph_nochar.071.model.90.model
# dset_file_name         morph_nochar.071.model.dset
#
#                                                9968   \
# acc                                           0.9668
# p                                             0.8277
# r                                             0.7315
# f                                             0.7766
# arch                                  token_charlstm
# unit                                           token
# conf_num                                         017
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         2
# batch_size                                         1
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       100
# dropout                                          0.4
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   90
# char_kernel_size                                 NaN
# learning_rate                                  0.005
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             68
# model_file_name    token_charlstm.017.model.68.model
# dset_file_name         token_charlstm.017.model.dset
#
#                                               50194  \
# acc                                          0.9655
# p                                            0.8424
# r                                            0.7174
# f                                            0.7749
# arch                                  token_charcnn
# unit                                          token
# conf_num                                        075
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        8
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      200
# dropout                                         0.4
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  70
# char_kernel_size                                  7
# learning_rate                                  0.01
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            94
# model_file_name    token_charcnn.075.model.94.model
# dset_file_name         token_charcnn.075.model.dset
#
#                                              44894
# acc                                         0.9623
# p                                           0.8137
# r                                           0.6914
# f                                           0.7476
# arch                                  token_nochar
# unit                                         token
# conf_num                                       014
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       2
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                     200
# dropout                                        0.5
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                 0.01
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           94
# model_file_name    token_nochar.014.model.94.model
# dset_file_name         token_nochar.014.model.dset
