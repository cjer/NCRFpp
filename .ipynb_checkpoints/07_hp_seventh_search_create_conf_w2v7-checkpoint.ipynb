# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('paper')
sns.set_style('white')

# %%
import pandas as pd
import configs

# %%
import os

# %%
import pickle
with open('hp_search/conf_json3/cnn_confs.pkl', 'rb') as f:
    cnn_confs = pickle.load(f)
with open('hp_search/conf_json3/lstm_confs.pkl', 'rb') as f:
    lstm_confs = pickle.load(f)
with open('hp_search/conf_json3/nochar_confs.pkl', 'rb') as f:
    nochar_confs = pickle.load(f)

# %%
len(cnn_confs[0]), len(lstm_confs[0]), len(nochar_confs[0])
# Out:
# (24, 23, 21)

# %%
models_folder = 'hp_search/models5'
conf_folder = 'hp_search/conf5'
json_folder = 'hp_search/conf_json5'
logs_folder = 'hp_search/logs5'

# %%
if not os.path.exists(models_folder):
    os.mkdir(models_folder)
if not os.path.exists(conf_folder):
    os.mkdir(conf_folder)
if not os.path.exists(json_folder):
    os.mkdir(json_folder)
if not os.path.exists(logs_folder):
    os.mkdir(logs_folder)

# %%
import json
def create_all_confs(confs, arch_name, ds_name, emb_name, conf_folder, models_folder, json_folder):
    max_digits = len(str(len(confs)))
    full_confs = []
    for i, conf in enumerate(confs):
        fc = configs.create_conf_file(os.path.join(conf_folder, arch_name+f'.{str(i).zfill(max_digits)}.conf'), 
                                 os.path.join(models_folder, arch_name+f'.{str(i).zfill(max_digits)}.model'), 
                                 ds_name, 
                                 conf, 
                                 emb_name)
        full_confs.append(fc)

    for i, fc in enumerate(full_confs):
        with open( os.path.join(json_folder, arch_name+f'.{str(i).zfill(max_digits)}.json'), 'w') as of:
            of.write(json.dumps(fc))

# %%
create_all_confs(lstm_confs, 'morph_charlstm', 'gold_morpheme', 'alt_tok_yap_w2v_sg', 
                 conf_folder, models_folder, json_folder)

# %%
create_all_confs(cnn_confs, 'morph_charcnn', 'gold_morpheme', 'alt_tok_yap_w2v_sg', 
                 conf_folder, models_folder, json_folder)

# %% [markdown]
# ## Token

# %%
create_all_confs(lstm_confs, 'token_charlstm', 'gold_token_bioes', 'alt_tok_tokenized_w2v_sg', 
                 conf_folder, models_folder, json_folder)

# %%
create_all_confs(cnn_confs, 'token_charcnn', 'gold_token_bioes', 'alt_tok_tokenized_w2v_sg', 
                 conf_folder, models_folder, json_folder)

# %% [markdown]
# ## Token Multi-Tag

# %%
create_all_confs(lstm_confs, 'multitok_charlstm', 'gold_token_raw', 'alt_tok_tokenized_w2v_sg', 
                 conf_folder, models_folder, json_folder)

# %%
create_all_confs(cnn_confs, 'multitok_charcnn', 'gold_token_raw', 'alt_tok_tokenized_w2v_sg', 
                 conf_folder, models_folder, json_folder)

# %% [markdown]
# ## NoChar

# %%
create_all_confs(nochar_confs, 'morph_nochar', 'gold_morpheme', 'alt_tok_yap_w2v_sg', 
                 conf_folder, models_folder, json_folder)

# %%
create_all_confs(nochar_confs, 'token_nochar', 'gold_token_bioes', 'alt_tok_tokenized_w2v_sg', 
                 conf_folder, models_folder, json_folder)

# %%
create_all_confs(nochar_confs, 'multitok_nochar', 'gold_token_raw', 'alt_tok_tokenized_w2v_sg', 
                 conf_folder, models_folder, json_folder)

# %% [markdown]
# # RUNNING ON NLP08, NLP10, NLP11, NLP13, NLP05, NLP14
# cd NCRFpp/
# conda activate ncrf_gpu
# python run4_hp_search.py 3 token_charlstm.2

# %% [markdown]
# ## Check results

# %%
import pickle
with open('hp_search/conf_json3/cnn_confs.pkl', 'rb') as f:
    cnn_confs = pickle.load(f)
with open('hp_search/conf_json3/lstm_confs.pkl', 'rb') as f:
    lstm_confs = pickle.load(f)
with open('hp_search/conf_json3/nochar_confs.pkl', 'rb') as f:
    nochar_confs = pickle.load(f)

# %%
len(cnn_confs[0]), len(lstm_confs[0]), len(nochar_confs[0])
# Out:
# (24, 23, 21)

# %%
import re
import os
DEV_RES_LINE = re.compile('Dev: .*; acc: (?P<acc>[^,]+)(?:, p: (?P<p>[^,]+), r: (?P<r>[^,]+), f: (?P<f>[-\d\.]+))?')
#Dev: time: 0.94s speed: 536.09st/s; acc: 0.9043
#Dev: time: 3.42s, speed: 146.59st/s; acc: 0.9546, p: 0.7577, r: 0.6393, f: 0.6935

mtimes = []
res = []
archs = []
for f in os.scandir('hp_search/logs5'):
    if f.name.startswith('.ipy'):
        continue
    mtimes.append(os.path.getmtime(f.path))
    arch = f.name.split('.')[0]
    archs.append(arch)
    unit = arch.split('_')[0]
    conf_num = f.name.split('.')[1]
    if 'cnn' in arch:
        matching_conf = cnn_confs[int(conf_num)] 
    elif 'lstm' in arch: 
        matching_conf = lstm_confs[int(conf_num)]
    elif 'nochar' in arch:
        matching_conf = nochar_confs[int(conf_num)]
    params = { 'arch': arch, 'unit': unit, 'conf_num': conf_num}
    params.update(matching_conf)
    with open(f.path, 'r') as fp:
        i= 0
        for line in fp:
            m = DEV_RES_LINE.match(line)
            if m:
                r = m.groupdict().copy()
                for k, v in r.items():
                    if v is not None:
                        r[k] = float(v)
                r.update(params)
                r['epoch'] = i
                i+=1
                res.append(r)

rdf = pd.DataFrame(res)

rdf['model_file_name'] = rdf.arch + '.' + rdf.conf_num +'.model.' + rdf.epoch.astype(str) + '.model'
rdf['dset_file_name'] =  rdf.arch + '.' + rdf.conf_num +'.model.dset'
rdf['char_seq_feature'] = rdf.char_seq_feature.fillna('NoChar')

rdf['relevant_score'] = rdf.f.fillna(rdf.acc)

erdf = rdf[(rdf.groupby(['conf_num', 'arch']).relevant_score.transform(max)==rdf.relevant_score) ]
erdf = erdf[(erdf.groupby(['conf_num', 'arch']).epoch.transform(min)==erdf.epoch) ]

# %%
erdf.shape
# Out:
# (77, 35)

# %%
erdf.groupby('arch').size()
# Out:
# arch
# morph_charcnn        13
# morph_charlstm        5
# morph_nochar          4
# multitok_charcnn     17
# multitok_charlstm     7
# multitok_nochar       4
# token_charcnn        17
# token_charlstm        6
# token_nochar          4
# dtype: int64

# %%
print ('Mean time per run:', round((max(mtimes) - min(mtimes) )/ len(mtimes) / 60, 2), 'minutes')
# Out:
# Mean time per run: 15.43 minutes

# %%
import numpy as np 
def perc(n):
    def perc_(x):
        return np.percentile(x, n)
    perc_.__name__ = 'perc_%s' % n
    return perc_

erdf.groupby(['unit', 'char_seq_feature']).f.agg(['max', 'min', 'mean', 'std', 'median', perc(95)])
# Out:
#                               max     min      mean       std   median  \
# unit     char_seq_feature
# morph    CNN               0.7093  0.6285  0.681508  0.023578  0.68760
#          LSTM              0.6988  0.6846  0.692780  0.006180  0.69330
#          NoChar            0.6843  0.6736  0.678600  0.005170  0.67825
# multitok CNN                  NaN     NaN       NaN       NaN      NaN
#          LSTM                 NaN     NaN       NaN       NaN      NaN
#          NoChar               NaN     NaN       NaN       NaN      NaN
# token    CNN               0.6539  0.6330  0.643676  0.006103  0.64400
#          LSTM              0.6464  0.6300  0.639783  0.007294  0.64095
#          NoChar            0.6227  0.6124  0.618375  0.004582  0.61920
#
#                             perc_95
# unit     char_seq_feature
# morph    CNN               0.706780
#          LSTM              0.698740
#          NoChar            0.683895
# multitok CNN                    NaN
#          LSTM                   NaN
#          NoChar                 NaN
# token    CNN               0.652220
#          LSTM              0.646375
#          NoChar            0.622460

# %% [markdown]
# ## Evaluate files (Mention Evaluation)

# %%
import sys
sys.path.append('../NER')

# %%
import ne_evaluate_mentions as nem

# %% [markdown]
# ## Create configs for decoding

# %%
model_folder = 'hp_search/models5'
output_folder = 'hp_search/decode_output5'
conf_folder = 'hp_search/decode_conf5'

if not os.path.exists(output_folder):
    os.mkdir(output_folder)

if not os.path.exists(conf_folder):
    os.mkdir(conf_folder)
    
decode_sets = {
    'morph': {
        'morph_dev_gold': '../NER/data/for_ncrf/morph_gold_dev.bmes',
        'morph_dev_yap': '../NER/data/for_ncrf/morph_yap_dev_dummy_o.bmes',
        'morph_test_gold': '../NER/data/for_ncrf/morph_gold_test.bmes',
        'morph_test_yap': '../NER/data/for_ncrf/morph_yap_test_dummy_o.bmes',
    },
    'token': {
        'token_dev': '../NER/data/for_ncrf/token_gold_dev_fix.bmes',
        'token_test': '../NER/data/for_ncrf/token_gold_test_fix.bmes',
    },
    'multitok': {
        'token_dev': '../NER/data/for_ncrf/token_gold_dev_concat.bmes',
        'token_test': '../NER/data/for_ncrf/token_gold_test_concat.bmes',
    }
}

params = { 'status': 'decode' }

for i, row in erdf.iterrows():
    unit = row['arch'].split('_')[0]
    for name, set_path in decode_sets[unit].items():
        row_par = params.copy()
        row_par['load_model_dir'] = os.path.join(model_folder, row['model_file_name'])
        row_par['dset_dir'] = os.path.join(model_folder, row['dset_file_name'])
        row_par['decode_dir'] = os.path.join(output_folder, name+'.'+row['arch']+'.'+row['conf_num']+'.bmes')
        row_par['raw_dir'] = set_path
        
        conf_path = os.path.join(conf_folder, name+'.'+row['arch']+'.'+row['conf_num']+'.decode.conf')
        if not os.path.exists(conf_path):
            with open(conf_path, 'w', encoding='utf8') as of:
                for k, v in row_par.items():
                    of.write(k+'='+str(v)+'\n')

# %% [markdown]
# ## Evaluate decoded folder

# %%
scores = {}

# %%
if os.path.exists('hp_search/scores5.pkl'):
    scores = pickle.load(open('hp_search/scores5.pkl', 'rb'))

# %%
for file in os.scandir(output_folder):
    if file.name=='.ipynb_checkpoints':
        continue
    gold_name, arch, conf_num = file.name.split('.')[:3]
    if (gold_name, arch, conf_num) not in scores:
        _, charsf = arch.split('_')
        if len(gold_name.split('_'))>2:
            unit, pred_set, _ = gold_name.split('_')
            gold_path = decode_sets[unit][unit+'_'+pred_set+'_gold']
        else:
            unit, pred_set = gold_name.split('_')
            gold_path = decode_sets[unit][unit+'_'+pred_set]
        p, r, f = nem.evaluate_files(gold_path, file)
        scores[(gold_name, arch, conf_num)] = (p, r, f)
        
pickle.dump(scores, open('hp_search/scores5.pkl', 'wb'))

# %%
score_tups = [(*k, *v) for k,v in scores.items()]

# %%
mev = pd.DataFrame(score_tups, columns=('gold_name', 'arch', 'conf_num', 'p', 'r', 'f'))
mev[mev.gold_name.str.contains('dev')].groupby(['gold_name', 'arch']).f.agg(['max', 'min', 'mean', 'std', 'median', perc(95)])
# Out:
#                                        max       min      mean       std  \
# gold_name      arch
# morph_dev_gold morph_charcnn      0.693182  0.629108  0.674156  0.026549
#                morph_charlstm     0.700114  0.694878  0.697496  0.003703
#                morph_nochar       0.686636  0.686636  0.686636       NaN
# morph_dev_yap  morph_charcnn      0.624714  0.590909  0.612677  0.013562
#                morph_charlstm     0.629418  0.626007  0.627713  0.002412
#                morph_nochar       0.616628  0.616628  0.616628       NaN
# token_dev      multitok_charcnn   0.644571  0.622322  0.631227  0.006732
#                multitok_charlstm  0.633406  0.622472  0.629038  0.005789
#                multitok_nochar    0.626374  0.620155  0.623264  0.004397
#                token_charcnn      0.654628  0.633028  0.643945  0.006425
#                token_charlstm     0.647123  0.632287  0.641763  0.008230
#                token_nochar       0.624130  0.620296  0.622213  0.002711
#
#                                     median   perc_95
# gold_name      arch
# morph_dev_gold morph_charcnn      0.684869  0.692888
#                morph_charlstm     0.697496  0.699852
#                morph_nochar       0.686636  0.686636
# morph_dev_yap  morph_charcnn      0.619154  0.623813
#                morph_charlstm     0.627713  0.629248
#                morph_nochar       0.616628  0.616628
# token_dev      multitok_charcnn   0.630435  0.640996
#                multitok_charlstm  0.631236  0.633189
#                multitok_nochar    0.623264  0.626063
#                token_charcnn      0.643914  0.652235
#                token_charlstm     0.645880  0.646998
#                token_nochar       0.622213  0.623938

# %%
mev['pred_set'] = mev.gold_name.apply(lambda x: '_'.join(x.split('_')[1:]).replace('_yap', ''))

# %%
mev = mev.set_index(['arch', 'conf_num', 'pred_set'])[['p', 'r', 'f']].unstack()
mev.columns = ['_'.join(col).rstrip('_') for col in mev.columns.values]
mev.head()
# Out:
#                            p_dev  p_dev_gold    p_test  p_test_gold     r_dev  \
# arch          conf_num
# morph_charcnn 00        0.558233    0.628514  0.534335     0.637339  0.695000
#               09        0.495984    0.538153  0.463519     0.530043  0.730769
#               10        0.536145    0.604418  0.530043     0.629828  0.735537
#               11        0.548193    0.612450  0.523605     0.634120  0.726064
#               20        0.538153    0.600402  0.532189     0.630901  0.699739
#
#                         r_dev_gold    r_test  r_test_gold     f_dev  \
# arch          conf_num
# morph_charcnn 00          0.769042  0.654402     0.734240  0.619154
#               09          0.757062  0.645740     0.689944  0.590909
#               10          0.790026  0.675787     0.759379  0.620209
#               11          0.798429  0.658570     0.744332  0.624714
#               20          0.762755  0.672087     0.756757  0.608400
#
#                         f_dev_gold    f_test  f_test_gold
# arch          conf_num
# morph_charcnn 00          0.691713  0.588305     0.682366
#               09          0.629108  0.539663     0.599515
#               10          0.684869  0.594107     0.688563
#               11          0.693182  0.583383     0.684820
#               20          0.671910  0.594012     0.688122

# %%
erdf = erdf.merge(mev.reset_index(), on=['arch', 'conf_num'])

# %%
sns.catplot(kind='violin', row='char_seq_feature', col='unit', 
            x="learning_rate", y="f_dev", #hue='batch_size',
                data=erdf, palette="Set2",
                scale="count", inner="box", scale_hue=True)

# %%
>>> g = sns.FacetGrid(erdf[erdf.unit=='morph'].rename(columns={'learning_rate': 'lr', 'char_seq_feature': 'charsf'}), col='charsf')
>>> g = g.map(plt.scatter, "f_dev_gold", "f_dev", edgecolor="w")

# %%
cols = ['f', 'p', 'r', 'char_seq_feature', 'lstm_layer', 'batch_size', 
        'learning_rate', 'char_hidden_dim', 'char_kernel_size',
        'hidden_dim', 'dropout', 'epoch']

# %%
(erdf[erdf.unit=='morph'].sort_values('f', ascending=False).head(20)[['arch', 'conf_num', 'epoch', 'f']]).fillna('')

# %%
(erdf[erdf.unit=='token'].sort_values('f', ascending=False).head(20)[['arch', 'conf_num', 'epoch', 'f']]).fillna('')

# %%
(erdf[erdf.unit=='morph'].sort_values('f', ascending=False).head(20)[cols]).fillna('')
# Out:
#          f       p       r char_seq_feature  lstm_layer  batch_size  \
# 21  0.8118  0.8591  0.7695              CNN           2           8
# 19  0.8075  0.8398  0.7776           NoChar           2           8
# 18  0.8000  0.8475  0.7575              CNN           2           8
# 17  0.7996  0.8441  0.7595             LSTM           2           8
# 22  0.7992  0.8407  0.7615             LSTM           2           8
# 13  0.7987  0.8472  0.7555              CNN           2           8
# 20  0.7979  0.8555  0.7475              CNN           2           8
# 23  0.7975  0.8370  0.7615             LSTM           2           8
# 34  0.7962  0.8516  0.7475              CNN           2           8
# 32  0.7941  0.8344  0.7575             LSTM           2           8
# 8   0.7920  0.8322  0.7555           NoChar           2           8
# 35  0.7895  0.8315  0.7515              CNN           2           8
#
#     learning_rate char_hidden_dim char_kernel_size  hidden_dim  dropout  epoch
# 21          0.010              50                5         200      0.4    103
# 19          0.010                                          200      0.5    107
# 18          0.010              70                7         200      0.4    116
# 17          0.005              50                          200      0.5     74
# 22          0.010              70                          200      0.4     92
# 13          0.005              50                7         200      0.4     17
# 20          0.010              50                5         200      0.5    124
# 23          0.005              70                          200      0.4    104
# 34          0.005              70                3         200      0.5     84
# 32          0.005              50                          200      0.4    130
# 8           0.005                                          200      0.4     29
# 35          0.005              50                7         200      0.5     87

# %%
(erdf[erdf.unit=='morph'].sort_values('f', ascending=True).head(20)[cols]).fillna('')
# Out:
#          f       p       r char_seq_feature  lstm_layer  batch_size  \
# 35  0.7895  0.8315  0.7515              CNN           2           8
# 8   0.7920  0.8322  0.7555           NoChar           2           8
# 32  0.7941  0.8344  0.7575             LSTM           2           8
# 34  0.7962  0.8516  0.7475              CNN           2           8
# 23  0.7975  0.8370  0.7615             LSTM           2           8
# 20  0.7979  0.8555  0.7475              CNN           2           8
# 13  0.7987  0.8472  0.7555              CNN           2           8
# 22  0.7992  0.8407  0.7615             LSTM           2           8
# 17  0.7996  0.8441  0.7595             LSTM           2           8
# 18  0.8000  0.8475  0.7575              CNN           2           8
# 19  0.8075  0.8398  0.7776           NoChar           2           8
# 21  0.8118  0.8591  0.7695              CNN           2           8
#
#     learning_rate char_hidden_dim char_kernel_size  hidden_dim  dropout  epoch
# 35          0.005              50                7         200      0.5     87
# 8           0.005                                          200      0.4     29
# 32          0.005              50                          200      0.4    130
# 34          0.005              70                3         200      0.5     84
# 23          0.005              70                          200      0.4    104
# 20          0.010              50                5         200      0.5    124
# 13          0.005              50                7         200      0.4     17
# 22          0.010              70                          200      0.4     92
# 17          0.005              50                          200      0.5     74
# 18          0.010              70                7         200      0.4    116
# 19          0.010                                          200      0.5    107
# 21          0.010              50                5         200      0.4    103

# %%
(erdf[erdf.unit=='token'].sort_values('f', ascending=False).head(20)[cols]).fillna('')
# Out:
#          f       p       r char_seq_feature  lstm_layer  batch_size  \
# 26  0.7928  0.8389  0.7515              CNN           2           8
# 2   0.7835  0.8281  0.7435              CNN           2           8
# 0   0.7829  0.8170  0.7515           NoChar           2           8
# 25  0.7816  0.8166  0.7495              CNN           2           8
# 27  0.7794  0.8190  0.7435              CNN           2           8
# 9   0.7792  0.8113  0.7495             LSTM           2           8
# 1   0.7760  0.8164  0.7395              CNN           2           8
# 6   0.7749  0.8239  0.7315             LSTM           2           8
# 28  0.7747  0.8039  0.7475             LSTM           2           8
# 5   0.7671  0.8089  0.7295              CNN           2           8
# 3   0.7669  0.8135  0.7255              CNN           2           8
# 24  0.7637  0.8062  0.7255           NoChar           2           8
#
#     learning_rate char_hidden_dim char_kernel_size  hidden_dim  dropout  epoch
# 26          0.010              70                7         200      0.5    104
# 2           0.010              70                7         200      0.4     51
# 0           0.010                                          200      0.5    111
# 25          0.005              70                7         200      0.5     35
# 27          0.010              70                3         200      0.4     74
# 9           0.005              50                          200      0.5    126
# 1           0.005              50                7         200      0.4     54
# 6           0.010              70                          200      0.4     56
# 28          0.005              70                          200      0.5     71
# 5           0.010              50                5         200      0.4     56
# 3           0.010              50                5         200      0.5    118
# 24          0.005                                          200      0.5    101

# %%
(erdf[erdf.unit=='token'].sort_values('f', ascending=True).head(20)[cols]).fillna('')
# Out:
#          f       p       r char_seq_feature  lstm_layer  batch_size  \
# 24  0.7637  0.8062  0.7255           NoChar           2           8
# 3   0.7669  0.8135  0.7255              CNN           2           8
# 5   0.7671  0.8089  0.7295              CNN           2           8
# 28  0.7747  0.8039  0.7475             LSTM           2           8
# 6   0.7749  0.8239  0.7315             LSTM           2           8
# 1   0.7760  0.8164  0.7395              CNN           2           8
# 9   0.7792  0.8113  0.7495             LSTM           2           8
# 27  0.7794  0.8190  0.7435              CNN           2           8
# 25  0.7816  0.8166  0.7495              CNN           2           8
# 0   0.7829  0.8170  0.7515           NoChar           2           8
# 2   0.7835  0.8281  0.7435              CNN           2           8
# 26  0.7928  0.8389  0.7515              CNN           2           8
#
#     learning_rate char_hidden_dim char_kernel_size  hidden_dim  dropout  epoch
# 24          0.005                                          200      0.5    101
# 3           0.010              50                5         200      0.5    118
# 5           0.010              50                5         200      0.4     56
# 28          0.005              70                          200      0.5     71
# 6           0.010              70                          200      0.4     56
# 1           0.005              50                7         200      0.4     54
# 9           0.005              50                          200      0.5    126
# 27          0.010              70                3         200      0.4     74
# 25          0.005              70                7         200      0.5     35
# 0           0.010                                          200      0.5    111
# 2           0.010              70                7         200      0.4     51
# 26          0.010              70                7         200      0.5    104

# %%
erdf.groupby('arch').epoch.agg(['median', 'mean', 'std'])
# Out:
#                    median        mean        std
# arch
# morph_charcnn          95   88.500000  38.370562
# morph_charlstm         98  100.000000  23.494680
# morph_nochar           68   68.000000  55.154329
# multitok_charcnn      106  104.285714  48.082271
# multitok_charlstm      83   83.000000  16.970563
# multitok_nochar        87  111.333333  50.143128
# token_charcnn          56   70.285714  30.313442
# token_charlstm         71   84.333333  36.855574
# token_nochar          106  106.000000   7.071068

# %%
sns.swarmplot(data=erdf, x='unit', y='f', hue='char_seq_feature', dodge=True)

# %%
sns.violinplot(data=erdf, x='unit', y='f', hue='char_seq_feature', inner='stick')

# %% [markdown]
# ## Learning rate

# %%
erdf.groupby(['optimizer', 'learning_rate', 'arch']).conf_num.nunique().unstack()
# Out:
# arch                     morph_charcnn  morph_charlstm  morph_nochar  \
# optimizer learning_rate
# SGD       0.005                      7               4             2
#           0.010                     11               3             2
#
# arch                     multitok_charcnn  multitok_charlstm  multitok_nochar  \
# optimizer learning_rate
# SGD       0.005                         6                  4                2
#           0.010                        10                  4                2
#
# arch                     token_charcnn  token_charlstm  token_nochar
# optimizer learning_rate
# SGD       0.005                      8               4             2
#           0.010                      8               4             2

# %%
erdf.groupby(['optimizer', 'learning_rate', 'arch']).f.median().unstack()
# Out:
# arch                     morph_charcnn  morph_charlstm  morph_nochar  \
# optimizer learning_rate
# SGD       0.005                 0.7832         0.79385         0.779
#           0.010                 0.7866         0.79090         0.780
#
# arch                     multitok_charcnn  multitok_charlstm  multitok_nochar  \
# optimizer learning_rate
# SGD       0.005                       NaN                NaN              NaN
#           0.010                       NaN                NaN              NaN
#
# arch                     token_charcnn  token_charlstm  token_nochar
# optimizer learning_rate
# SGD       0.005                0.76300         0.76480        0.7352
#           0.010                0.76615         0.77195        0.7431

# %%
erdf.groupby(['optimizer', 'learning_rate', 'arch']).f.max().unstack()
# Out:
# arch                     morph_charcnn  morph_charlstm  morph_nochar  \
# optimizer learning_rate
# SGD       0.005                 0.7918          0.7974        0.7791
#           0.010                 0.7966          0.7918        0.7826
#
# arch                     multitok_charcnn  multitok_charlstm  multitok_nochar  \
# optimizer learning_rate
# SGD       0.005                       NaN                NaN              NaN
#           0.010                       NaN                NaN              NaN
#
# arch                     token_charcnn  token_charlstm  token_nochar
# optimizer learning_rate
# SGD       0.005                 0.7717          0.7676        0.7372
#           0.010                 0.7789          0.7749        0.7484

# %%
sns.swarmplot(data=erdf, x='learning_rate', y='f', hue='char_seq_feature', split=True)

# %%
sns.catplot(kind='violin', row='char_seq_feature', col='unit', 
            x="learning_rate", y="f", #hue='batch_size',
                data=erdf, palette="Set2",
                scale="count", inner="box", scale_hue=True)

# %%
sns.violinplot(data=erdf, x='learning_rate', y='epoch', inner='stick')

# %% [markdown]
# ### Do the lower scores in the lower learning rate come from lack of epochs?

# %%
sns.scatterplot(data=erdf.assign(lr=lambda x: x.learning_rate.astype('str')), hue='lr', x='epoch', y='f',
               palette=sns.color_palette("Set1", erdf.learning_rate.nunique()))

# %%
>>> g = sns.FacetGrid(erdf.rename(columns={'learning_rate': 'lr', 'char_seq_feature': 'charsf'}), col="lr", row='charsf')
>>> g = g.map(plt.scatter, "epoch", "f", edgecolor="w")

# %%
>>> g = sns.FacetGrid(erdf[erdf.unit=='morph'].rename(columns={'learning_rate': 'lr', 'char_seq_feature': 'charsf'}), col="lr", row='charsf')
>>> g = g.map(sns.kdeplot, "epoch", "f")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-163-5852e4dbce54> in <module>
#       1 g = sns.FacetGrid(erdf[erdf.unit=='morph'].rename(columns={'learning_rate': 'lr', 'char_seq_feature': 'charsf'}), col="lr", row='charsf')
# ----> 2 g = g.map(sns.kdeplot, "epoch", "f")
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     752
#     753             # Draw the plot
# --> 754             self._facet_plot(func, ax, plot_args, kwargs)
#     755
#     756         # Finalize the annotations and layout
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     836
#     837         # Draw the plot
# --> 838         func(*plot_args, **plot_kwargs)
#     839
#     840         # Sort out the supporting information
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     685         ax = _bivariate_kdeplot(x, y, shade, shade_lowest,
#     686                                 kernel, bw, gridsize, cut, clip, legend,
# --> 687                                 cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     688     else:
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/seaborn/distributions.py in _bivariate_kdeplot(x, y, filled, fill_lowest, kernel, bw, gridsize, cut, clip, axlabel, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     391     # Calculate the KDE
#     392     if _has_statsmodels:
# --> 393         xx, yy, z = _statsmodels_bivariate_kde(x, y, bw, gridsize, cut, clip)
#     394     else:
#     395         xx, yy, z = _scipy_bivariate_kde(x, y, bw, gridsize, cut, clip)
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/seaborn/distributions.py in _statsmodels_bivariate_kde(x, y, bw, gridsize, cut, clip)
#     461         y = y.values
#     462
# --> 463     kde = smnp.KDEMultivariate([x, y], "cc", bw)
#     464     x_support = _kde_support(x, kde.bw[0], gridsize, cut, clip[0])
#     465     y_support = _kde_support(y, kde.bw[1], gridsize, cut, clip[1])
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/statsmodels/nonparametric/kernel_density.py in __init__(self, data, var_type, bw, defaults)
#     109         self.nobs, self.k_vars = np.shape(self.data)
#     110         if self.nobs <= self.k_vars:
# --> 111             raise ValueError("The number of observations must be larger " \
#     112                              "than the number of variables.")
#     113         defaults = EstimatorSettings() if defaults is None else defaults
#
# ValueError: The number of observations must be larger than the number of variables.

# %%
>>> g = sns.FacetGrid(erdf[erdf.unit=='token'].rename(columns={'learning_rate': 'lr', 'char_seq_feature': 'charsf'}), col="lr", row='charsf')
>>> g = g.map(sns.kdeplot, "epoch", "f")

# %%
>>> g = sns.FacetGrid(erdf.rename(columns={'char_seq_feature': 'charsf'}), col="batch_size", row='charsf')
>>> g = g.map(plt.scatter, "epoch", "f", edgecolor="w")

# %%
>>> g = sns.FacetGrid(erdf.rename(columns={'char_seq_feature': 'charsf'}), col="batch_size", row='charsf')
>>> g = g.map(sns.kdeplot, "epoch", "f")

# %%
sns.swarmplot(data=erdf, x='arch', y='epoch')

# %% [markdown]
# ## Batch size

# %%
erdf.groupby(['batch_size', 'arch']).f.median().unstack()
# Out:
# arch        morph_charcnn  morph_charlstm  morph_nochar  token_charcnn  \
# batch_size
# 1                 0.78170         0.78515        0.7719         0.7476
# 8                 0.77795         0.78130        0.7721         0.7478
#
# arch        token_charlstm  token_nochar
# batch_size
# 1                  0.75575        0.7290
# 8                  0.75350        0.7306

# %%
sns.swarmplot(data=erdf, x='unit', y='f', hue='batch_size', split=True)

# %%
sns.violinplot(data=erdf, x='unit', y='f', hue='batch_size', split=True, inner='stick')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-ef54613d7bc1> in <module>
# ----> 1 sns.violinplot(data=erdf, x='unit', y='f', hue='batch_size', split=True, inner='stick')
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/seaborn/categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2385                              bw, cut, scale, scale_hue, gridsize,
#    2386                              width, inner, split, dodge, orient, linewidth,
# -> 2387                              color, palette, saturation)
#    2388
#    2389     if ax is None:
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation)
#     579         if split and self.hue_names is not None and len(self.hue_names) != 2:
#     580             msg = "There must be exactly two hue levels to use `split`.'"
# --> 581             raise ValueError(msg)
#     582         self.split = split
#     583
#
# ValueError: There must be exactly two hue levels to use `split`.'

# %% [markdown]
# ## Char CNN window size

# %%
erdf.groupby(['unit', 'char_kernel_size']).f.mean().unstack()
# Out:
# char_kernel_size       3.0       5.0       7.0
# unit
# morph             0.774034  0.777962  0.781965
# token             0.745823  0.746515  0.750941

# %%
sns.swarmplot(data=erdf, x='arch', y='f', hue='char_kernel_size', split=True)

# %%
sns.catplot(kind='violin', col='unit', x="char_kernel_size", y="f",
                data=erdf, palette="Set2", 
                scale="count", inner="box")

# %% [markdown]
# ## LSTM Layers stacked

# %%
erdf.groupby(['lstm_layer', 'arch']).f.median().unstack()
# Out:
# arch        morph_charcnn  morph_charlstm  morph_nochar  token_charcnn  \
# lstm_layer
# 1                  0.7772          0.7811        0.7751        0.74510
# 2                  0.7809          0.7861        0.7719        0.75225
#
# arch        token_charlstm  token_nochar
# lstm_layer
# 1                   0.7519       0.72890
# 2                   0.7594       0.73055

# %%
erdf.groupby(['lstm_layer', 'arch']).f.max().unstack()
# Out:
# arch        morph_charcnn  morph_charlstm  morph_nochar  token_charcnn  \
# lstm_layer
# 1                  0.7914          0.7966        0.7852         0.7666
# 2                  0.7991          0.7974        0.7835         0.7749
#
# arch        token_charlstm  token_nochar
# lstm_layer
# 1                   0.7618        0.7424
# 2                   0.7766        0.7476

# %%
sns.swarmplot(data=erdf, x='arch', y='f', hue='lstm_layer', split=True)

# %%
sns.catplot(kind='violin', row='unit', col='char_seq_feature', 
            x="lstm_layer", y="f",
                data=erdf, palette="Set2", split=True,
                scale="count", inner="stick", scale_hue=True)

# %% [markdown]
# ## Dropout

# %%
erdf.groupby(['dropout', 'arch']).f.median().unstack()
# Out:
# arch     morph_charcnn  morph_charlstm  morph_nochar  token_charcnn  \
# dropout
# 0.4             0.7846         0.78210        0.7762         0.7524
# 0.5             0.7804         0.78345        0.7760         0.7492
# 0.6             0.7722         0.78090        0.7612         0.7422
#
# arch     token_charlstm  token_nochar
# dropout
# 0.4              0.7521       0.73045
# 0.5              0.7578       0.72930
# 0.6              0.7552       0.73020

# %%
sns.swarmplot(data=erdf, x='arch', y='f', hue='dropout', split=True)

# %% [markdown]
# ## Hidden dimensions

# %% [markdown]
# ### WLSTM

# %%
erdf.groupby(['hidden_dim', 'arch']).f.median().unstack()
# Out:
# arch        morph_charcnn  morph_charlstm  morph_nochar  token_charcnn  \
# hidden_dim
# 50                 0.7742         0.77540        0.7706         0.7371
# 100                0.7850         0.78270        0.7754         0.7512
# 200                0.7817         0.78555        0.7774         0.7522
#
# arch        token_charlstm  token_nochar
# hidden_dim
# 50                 0.74410       0.72360
# 100                0.75765       0.73285
# 200                0.75715       0.73510

# %%
sns.swarmplot(data=erdf, x='arch', y='f', hue='hidden_dim', split=True)

# %% [markdown]
# ### CLSTM / CCNN

# %%
erdf.groupby(['char_hidden_dim', 'arch']).f.median().unstack()
# Out:
# arch             morph_charcnn  morph_charlstm  token_charcnn  token_charlstm
# char_hidden_dim
# 50.0                    0.7819         0.78395         0.7465         0.75485
# 70.0                    0.7772         0.78200         0.7513         0.75190
# 90.0                    0.7803         0.78220         0.7467         0.75600

# %%
sns.swarmplot(data=erdf, x='arch', y='f', hue='char_hidden_dim', split=True)

# %%
sns.catplot(kind='violin', row='unit', col='char_seq_feature', 
            x="char_hidden_dim", y="f",
                data=erdf, palette="Set2", split=True,
                scale="count", inner="stick", scale_hue=True)

# %%
erdf.groupby('arch').apply(lambda x: x.sort_values('f', ascending=False).head(2)).T
# Out:
# arch                                  morph_charcnn  \
#                                               17957
# acc                                            0.97
# p                                            0.8558
# r                                            0.7495
# f                                            0.7991
# arch                                  morph_charcnn
# unit                                          morph
# conf_num                                        017
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        1
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      200
# dropout                                         0.6
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  50
# char_kernel_size                                  5
# learning_rate                                 0.005
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            57
# model_file_name    morph_charcnn.017.model.57.model
# dset_file_name         morph_charcnn.017.model.dset
#
# arch                                                 \
#                                               41651
# acc                                          0.9689
# p                                            0.8472
# r                                            0.7555
# f                                            0.7987
# arch                                  morph_charcnn
# unit                                          morph
# conf_num                                        053
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        8
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      100
# dropout                                         0.5
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  70
# char_kernel_size                                  7
# learning_rate                                  0.01
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            51
# model_file_name    morph_charcnn.053.model.51.model
# dset_file_name         morph_charcnn.053.model.dset
#
# arch                                  morph_charlstm  \
#                                                13826
# acc                                           0.9679
# p                                             0.8519
# r                                             0.7495
# f                                             0.7974
# arch                                  morph_charlstm
# unit                                           morph
# conf_num                                         011
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         2
# batch_size                                         1
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       100
# dropout                                          0.5
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   70
# char_kernel_size                                 NaN
# learning_rate                                  0.015
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             26
# model_file_name    morph_charlstm.011.model.26.model
# dset_file_name         morph_charlstm.011.model.dset
#
# arch                                                  \
#                                                36238
# acc                                           0.9673
# p                                             0.8605
# r                                             0.7415
# f                                             0.7966
# arch                                  morph_charlstm
# unit                                           morph
# conf_num                                         039
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         1
# batch_size                                         8
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       100
# dropout                                          0.4
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   50
# char_kernel_size                                 NaN
# learning_rate                                   0.01
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             38
# model_file_name    morph_charlstm.039.model.38.model
# dset_file_name         morph_charlstm.039.model.dset
#
# arch                                  morph_nochar  \
#                                              40290
# acc                                         0.9666
# p                                           0.8612
# r                                           0.7214
# f                                           0.7852
# arch                                  morph_nochar
# unit                                         morph
# conf_num                                       071
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       1
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                      50
# dropout                                        0.4
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                 0.01
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           90
# model_file_name    morph_nochar.071.model.90.model
# dset_file_name         morph_nochar.071.model.dset
#
# arch                                                \
#                                              52364
# acc                                         0.9666
# p                                           0.8722
# r                                           0.7114
# f                                           0.7837
# arch                                  morph_nochar
# unit                                         morph
# conf_num                                       031
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       1
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                     200
# dropout                                        0.4
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                0.005
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           64
# model_file_name    morph_nochar.031.model.64.model
# dset_file_name         morph_nochar.031.model.dset
#
# arch                                  token_charcnn  \
#                                               50194
# acc                                          0.9655
# p                                            0.8424
# r                                            0.7174
# f                                            0.7749
# arch                                  token_charcnn
# unit                                          token
# conf_num                                        075
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        8
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      200
# dropout                                         0.4
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  70
# char_kernel_size                                  7
# learning_rate                                  0.01
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            94
# model_file_name    token_charcnn.075.model.94.model
# dset_file_name         token_charcnn.075.model.dset
#
# arch                                                 \
#                                               31895
# acc                                           0.965
# p                                            0.8246
# r                                            0.7255
# f                                            0.7719
# arch                                  token_charcnn
# unit                                          token
# conf_num                                        438
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        8
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      200
# dropout                                         0.6
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  70
# char_kernel_size                                  5
# learning_rate                                  0.01
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            95
# model_file_name    token_charcnn.438.model.95.model
# dset_file_name         token_charcnn.438.model.dset
#
# arch                                  token_charlstm  \
#                                                9968
# acc                                           0.9668
# p                                             0.8277
# r                                             0.7315
# f                                             0.7766
# arch                                  token_charlstm
# unit                                           token
# conf_num                                         017
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         2
# batch_size                                         1
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       100
# dropout                                          0.4
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   90
# char_kernel_size                                 NaN
# learning_rate                                  0.005
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             68
# model_file_name    token_charlstm.017.model.68.model
# dset_file_name         token_charlstm.017.model.dset
#
# arch                                                  \
#                                                2470
# acc                                           0.9654
# p                                             0.8337
# r                                             0.7234
# f                                             0.7747
# arch                                  token_charlstm
# unit                                           token
# conf_num                                         205
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         2
# batch_size                                         8
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       200
# dropout                                          0.5
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   70
# char_kernel_size                                 NaN
# learning_rate                                  0.015
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             70
# model_file_name    token_charlstm.205.model.70.model
# dset_file_name         token_charlstm.205.model.dset
#
# arch                                  token_nochar  \
#                                              44894
# acc                                         0.9623
# p                                           0.8137
# r                                           0.6914
# f                                           0.7476
# arch                                  token_nochar
# unit                                         token
# conf_num                                       014
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       2
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                     200
# dropout                                        0.5
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                 0.01
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           94
# model_file_name    token_nochar.014.model.94.model
# dset_file_name         token_nochar.014.model.dset
#
# arch
#                                              48189
# acc                                         0.9624
# p                                           0.8213
# r                                           0.6814
# f                                           0.7448
# arch                                  token_nochar
# unit                                         token
# conf_num                                       022
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       2
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                     200
# dropout                                        0.4
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                0.015
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           89
# model_file_name    token_nochar.022.model.89.model
# dset_file_name         token_nochar.022.model.dset

# %%
rdf[rdf.groupby('arch').f.transform(max)==rdf.f].sort_values('f', ascending=False).T
# Out:
#                                               17957  \
# acc                                            0.97
# p                                            0.8558
# r                                            0.7495
# f                                            0.7991
# arch                                  morph_charcnn
# unit                                          morph
# conf_num                                        017
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        1
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      200
# dropout                                         0.6
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  50
# char_kernel_size                                  5
# learning_rate                                 0.005
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            57
# model_file_name    morph_charcnn.017.model.57.model
# dset_file_name         morph_charcnn.017.model.dset
#
#                                                13826  \
# acc                                           0.9679
# p                                             0.8519
# r                                             0.7495
# f                                             0.7974
# arch                                  morph_charlstm
# unit                                           morph
# conf_num                                         011
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         2
# batch_size                                         1
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       100
# dropout                                          0.5
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   70
# char_kernel_size                                 NaN
# learning_rate                                  0.015
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             26
# model_file_name    morph_charlstm.011.model.26.model
# dset_file_name         morph_charlstm.011.model.dset
#
#                                              40290  \
# acc                                         0.9666
# p                                           0.8612
# r                                           0.7214
# f                                           0.7852
# arch                                  morph_nochar
# unit                                         morph
# conf_num                                       071
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       1
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                      50
# dropout                                        0.4
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                 0.01
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           90
# model_file_name    morph_nochar.071.model.90.model
# dset_file_name         morph_nochar.071.model.dset
#
#                                                9968   \
# acc                                           0.9668
# p                                             0.8277
# r                                             0.7315
# f                                             0.7766
# arch                                  token_charlstm
# unit                                           token
# conf_num                                         017
# word_seq_feature                                LSTM
# word_emb_dim                                     300
# char_emb_dim                                      30
# iteration                                        100
# bilstm                                          True
# norm_word_emb                                  False
# norm_char_emb                                  False
# ave_batch_loss                                 False
# l2                                             1e-08
# lstm_layer                                         2
# batch_size                                         1
# number_normalized                              False
# optimizer                                        SGD
# nbest                                              1
# hidden_dim                                       100
# dropout                                          0.4
# char_seq_feature                                LSTM
# use_char                                        True
# use_crf                                         True
# char_hidden_dim                                   90
# char_kernel_size                                 NaN
# learning_rate                                  0.005
# lr_decay                                        0.05
# momentum                                           0
# epoch                                             68
# model_file_name    token_charlstm.017.model.68.model
# dset_file_name         token_charlstm.017.model.dset
#
#                                               50194  \
# acc                                          0.9655
# p                                            0.8424
# r                                            0.7174
# f                                            0.7749
# arch                                  token_charcnn
# unit                                          token
# conf_num                                        075
# word_seq_feature                               LSTM
# word_emb_dim                                    300
# char_emb_dim                                     30
# iteration                                       100
# bilstm                                         True
# norm_word_emb                                 False
# norm_char_emb                                 False
# ave_batch_loss                                False
# l2                                            1e-08
# lstm_layer                                        2
# batch_size                                        8
# number_normalized                             False
# optimizer                                       SGD
# nbest                                             1
# hidden_dim                                      200
# dropout                                         0.4
# char_seq_feature                                CNN
# use_char                                       True
# use_crf                                        True
# char_hidden_dim                                  70
# char_kernel_size                                  7
# learning_rate                                  0.01
# lr_decay                                       0.05
# momentum                                          0
# epoch                                            94
# model_file_name    token_charcnn.075.model.94.model
# dset_file_name         token_charcnn.075.model.dset
#
#                                              44894
# acc                                         0.9623
# p                                           0.8137
# r                                           0.6914
# f                                           0.7476
# arch                                  token_nochar
# unit                                         token
# conf_num                                       014
# word_seq_feature                              LSTM
# word_emb_dim                                   300
# char_emb_dim                                    30
# iteration                                      100
# bilstm                                        True
# norm_word_emb                                False
# norm_char_emb                                False
# ave_batch_loss                               False
# l2                                           1e-08
# lstm_layer                                       2
# batch_size                                       1
# number_normalized                            False
# optimizer                                      SGD
# nbest                                            1
# hidden_dim                                     200
# dropout                                        0.5
# char_seq_feature                               NaN
# use_char                                     False
# use_crf                                       True
# char_hidden_dim                                NaN
# char_kernel_size                               NaN
# learning_rate                                 0.01
# lr_decay                                      0.05
# momentum                                         0
# epoch                                           94
# model_file_name    token_nochar.014.model.94.model
# dset_file_name         token_nochar.014.model.dset
