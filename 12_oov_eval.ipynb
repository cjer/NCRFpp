# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('paper')
sns.set_style('white')

# %%
import sys
sys.path.append('/home/nlp/danb')
sys.path.append('/home/nlp/danb/NER')

import bclm
import ne_evaluate_mentions as nem

# %% [markdown]
# ## Get all OOV words

# %%
data_folder = '../NER/data/for_ncrf'

datasets = {
    'morph': {
        '_unit': 'morpheme',
        '_scheme': 'bioes',
        'train_dir': 'morph_gold_train.bmes',
        'dev_dir': 'morph_gold_dev.bmes',
        'test_dir': 'morph_gold_test.bmes', 
    },
    'token': {
        '_unit': 'token',
        '_scheme': 'bioes',
        'train_dir': 'token_gold_train_fix.bmes',
        'dev_dir': 'token_gold_dev_fix.bmes',
        'test_dir': 'token_gold_test_fix.bmes',
    },
    'multitok': {
        '_unit': 'token',
        '_scheme': 'concat_bioes',
        'seg': False,
        'train_dir': 'token_gold_train_concat.bmes',
        'dev_dir': 'token_gold_dev_concat.bmes',
        'test_dir': 'token_gold_test_concat.bmes',
    },
}

# %% [markdown]
# ### out-of-training-vocabulary words (OOTV)

# %%
import os

# %%
from collections import Counter

train_words = {}
for n, ds in datasets.items():
    for k in ds:
        if 'train' in k:
            train_words[n] = []
            path = os.path.join(data_folder, ds[k])
            print(path)
            for line in open(path, 'r'):
                word = line.split(' ')[0].strip()
                if word!='':
                    train_words[n].append(word)
            train_words[n] = set(train_words[n])
                
[len(x) for x in train_words.values()]
# Out:
# ../NER/data/for_ncrf/morph_gold_train.bmes
# ../NER/data/for_ncrf/token_gold_train_fix.bmes
# ../NER/data/for_ncrf/token_gold_train_concat.bmes
# [15959, 24889, 24889]

# %% [markdown]
# ### out-of-embedding-vocabulary words (OOEV)

# %%
word_embedding_files = {
    'ft_yap': '../wordembedding-hebrew/vectors_alt_tok/wikipedia.alt_tok.yap_form.fasttext_skipgram.model.vec.nofirstline',
    'ft_tok': '../wordembedding-hebrew/vectors_alt_tok/wikipedia.alt_tok.tokenized.fasttext_skipgram.model.vec.nofirstline',
    'ft_oov_yap': 'data/htb_all_words.wikipedia.alt_tok.yap_form.fasttext_skipgram.txt',
    'ft_oov_tok': 'data/htb_all_words.wikipedia.alt_tok.tokenized.fasttext_skipgram.txt',
    #'w2v_yap': '../wordembedding-hebrew/vectors_alt_tok/wikipedia.alt_tok.yap_form.word2vec_skipgram.txt.nofirstline',
    #'w2v_tok': '../wordembedding-hebrew/vectors_alt_tok/wikipedia.alt_tok.tokenized.word2vec_skipgram.txt.nofirstline',
    'glv_yap': '../wordembedding-hebrew/vectors_alt_tok/wikipedia.alt_tok.yap_form.glove.txt',
    'glv_tok': '../wordembedding-hebrew/vectors_alt_tok/wikipedia.alt_tok.tokenized.glove.txt',
    'no_word': None,
}

# %%
emb_words = {}

def get_words_from_emb_file(path):
    words = []
    for line in open(path):
        line = line.strip()
        if line!='':
            words.append(line.split()[0])
    return set(words)

emb_words['tok'] = get_words_from_emb_file(word_embedding_files['glv_tok'])
emb_words['yap'] = get_words_from_emb_file(word_embedding_files['glv_yap'])

# %%
len(emb_words['tok']), len(emb_words['yap'])
# Out:
# (359320, 245642)

# %%
for k, v in word_embedding_files.items():
    if v is not None:
        # !wc -l {v}
# Out:
# 245641 ../wordembedding-hebrew/vectors_alt_tok/wikipedia.alt_tok.yap_form.fasttext_skipgram.model.vec.nofirstline
# 359320 ../wordembedding-hebrew/vectors_alt_tok/wikipedia.alt_tok.tokenized.fasttext_skipgram.model.vec.nofirstline
# 32852 data/htb_all_words.wikipedia.alt_tok.yap_form.fasttext_skipgram.txt
# 32852 data/htb_all_words.wikipedia.alt_tok.tokenized.fasttext_skipgram.txt
# 245642 ../wordembedding-hebrew/vectors_alt_tok/wikipedia.alt_tok.yap_form.glove.txt
# 359320 ../wordembedding-hebrew/vectors_alt_tok/wikipedia.alt_tok.tokenized.glove.txt

# %% [markdown]
# ### IV (in-vocabulary)

# %%
inter = {}
for ds, trw in train_words.items():
    inter[ds] = {}
    for eu, emw in emb_words.items():
        inter[ds][eu] = trw & emw
        print (ds, eu, len(inter[ds][eu]))
# Out:
# morph tok 14753
# morph yap 14926
# token tok 22487
# token yap 14175
# multitok tok 22487
# multitok yap 14175

# %% [markdown]
# ### out-of-both-vocabulary words (OOBV)

# %% [markdown]
# anything that isn't in the other three

# %% [markdown]
# ## Find mentions that contain (parts of) unknown tokens

# %% [markdown]
# 1. Token unknown (T)
# 2. At least one morpheme unknown (M)
# 3. At least one lemma unknown (L)
# 4. All possible combinations

# %%
dropped = [5438, 5444, 5445, 5446, 5448, 5449, 5450, 5451, 5453, 5459]
spdf = bclm.read_dataframe('spmrl')
spdf = spdf[(~spdf.sent_id.isin(dropped))]

# %% [markdown]
# ### Full unknown
# Token unknown and at least one morpheme unknown (most obvious when token is made up of 1 morpheme)

# %%
train_gold = spdf[spdf.set=='train']
dev_gold = spdf[spdf.set=='dev']
test_gold = spdf[spdf.set=='test']

# %%
train_tokens = set(train_gold.token_str.tolist())
dev_tokens =   set(dev_gold.token_str.tolist())
test_tokens =  set(test_gold.token_str.tolist())

# %%
dev_unk_tokens = dev_tokens-train_tokens
test_unk_tokens = test_tokens-train_tokens
len(dev_unk_tokens), len(dev_tokens)
# Out:
# (1500, 3995)

# %%
dev_gold[~dev_gold.token_str.isin(train_tokens)].shape, dev_gold.shape
# Out:
# ((2738, 27), (11301, 27))

# %%
dev_gold[~dev_gold.token_str.isin(train_tokens)].groupby(['sent_id', 'token_id']).size().shape, dev_gold.groupby(['sent_id', 'token_id']).size().shape
# Out:
# ((1748,), (8531,))

# %%
train_morphs  = set(train_gold.form.tolist())
dev_morphs    =   set(dev_gold.form.tolist())
test_morphs   =  set(test_gold.form.tolist())

# %%
train_lemmas  =   set(train_gold.lemma.tolist())
dev_lemmas    =   set(dev_gold.lemma.tolist())
test_lemmas  =    set(test_gold.lemma.tolist())

# %%
dev_gold.head()
# Out:
#    id    form   lemma      upostag      xpostag  \
# 0   1   עשרות     עשר          CDT          CDT
# 1   2   אנשים     איש           NN           NN
# 2   3  מגיעים    הגיע           BN           BN
# 3   4       מ       מ  PREPOSITION  PREPOSITION
# 4   5  תאילנד  תאילנד          NNP          NNP
#
#                                feats  token_id  sent_id token_str  \
# 0                        gen=F|num=P         1        1     עשרות
# 1                        gen=M|num=P         2        1     אנשים
# 2  gen=M|num=P|per=A|HebBinyan=HIFIL         3        1    מגיעים
# 3                                  _         4        1   מתאילנד
# 4                                  _         4        1   מתאילנד
#
#    global_sent_id  ...  deps misc ner_escaped  set duplicate_sent_id  \
# 0               1  ...     _    _           _  dev               NaN
# 1               1  ...     _    _           _  dev               NaN
# 2               1  ...     _    _           _  dev               NaN
# 3               1  ...     _    _           _  dev               NaN
# 4               1  ...     _    _         GPE  dev               NaN
#
#    very_similar_sent_id biose_layer0 biose_layer1 biose_layer2 biose_layer3
# 0                   NaN            O            O            O            O
# 1                   NaN            O            O            O            O
# 2                   NaN            O            O            O            O
# 3                   NaN            O            O            O            O
# 4                   NaN        S-GPE            O            O            O
#
# [5 rows x 27 columns]

# %%
def unk_funq(x):
    def get_unk_type(t, m, l):
        ut = ''
        if t:
            ut+='T'
        if m:
            ut+='M'
#        if l:
#            ut+='L'
        return ut
    a = {}
    a['token_unk'] = not (x.token_str.iat[0] in train_tokens)
    a['morph_unk'] = (~x.form.isin(train_morphs)).any()
    a['lemma_unk'] = (~x.lemma.isin(train_lemmas)).any()
    a['unk_type'] = get_unk_type(a['token_unk'], a['morph_unk'], a['lemma_unk'])
    a['has_ner'] = not (x.biose_layer0=='O').all()
    a['morpheme_count'] = len(x)
    a['token_id_rep'] = x.token_id.iat[0]

    return pd.Series(a)

dev_unk = (dev_gold.groupby(['sent_id', 'token_id', 'token_str'])
                           .apply(unk_funq)).reset_index()

# %%
dev_unk.groupby(['unk_type', 'has_ner']).size().to_frame()
# Out:
#                      0
# unk_type has_ner
#          False    6252
#          True      519
# M        False      12
# T        False     617
#          True       53
# TM       False     820
#          True      258

# %%
def unk_funq(x):
    def get_unk_type(t, m, l):
        ut = ''
        if t:
            ut+='T'
        if m:
            ut+='M'
#        if l:
#            ut+='L'
        return ut
    a = {}
    a['token_unk'] = not (x.token_str.iat[0] in train_tokens)
    a['morph_unk'] = (~x.form.isin(train_morphs)).any()
    a['lemma_unk'] = (~x.lemma.isin(train_lemmas)).any()
    a['unk_type'] = get_unk_type(a['token_unk'], a['morph_unk'], a['lemma_unk'])
    a['has_ner'] = not (x.biose_layer0=='O').all()
    a['morpheme_count'] = len(x)
    a['token_id_rep'] = x.token_id.iat[0]
    return pd.Series(a)

test_unk = (test_gold.groupby(['sent_id', 'token_id', 'token_str'])
                           .apply(unk_funq)).reset_index()

# %%
test_unk.groupby(['unk_type', 'has_ner']).size().to_frame()
# Out:
#                      0
# unk_type has_ner
#          False    8746
#          True      940
# M        False      38
#          True        2
# T        False     944
#          True      102
# TM       False    1389
#          True      458

# %% [markdown]
# ## Create evalation

# %%
mev = pd.read_pickle('final_setup/mev2.pkl')
mev.head()
# Out:
#          gold_name   unit      arch     w_embed seed_num       p_m       r_m  \
# 0   morph_dev_gold  morph  char_cnn      ft_yap  44_seed  0.859155  0.733467
# 1    morph_dev_yap  morph  char_cnn      ft_yap  44_seed  0.780193  0.647295
# 2  morph_test_gold  morph  char_cnn      ft_yap  44_seed  0.804850  0.747854
# 3   morph_dev_gold  morph  char_cnn  ft_oov_tok  44_seed  0.843612  0.767535
# 4   morph_test_yap  morph  char_cnn      ft_yap  44_seed  0.721411  0.636266
#
#         f_m   pred_set     acc  ...  seg  \
# 0  0.791351   dev_gold  0.9667  ...  NaN
# 1  0.707558    dev_yap  0.9667  ...  NaN
# 2  0.775306  test_gold  0.9667  ...  NaN
# 3  0.803778   dev_gold  0.9690  ...  NaN
# 4  0.676169   test_yap  0.9667  ...  NaN
#
#                                model_file_name  \
# 0       morph.char_cnn.ft_yap.44_seed.83.model
# 1       morph.char_cnn.ft_yap.44_seed.83.model
# 2       morph.char_cnn.ft_yap.44_seed.83.model
# 3  morph.char_cnn.ft_oov_tok.44_seed.183.model
# 4       morph.char_cnn.ft_yap.44_seed.83.model
#
#                            dset_file_name relevant_score input_unit  \
# 0      morph.char_cnn.ft_yap.44_seed.dset         0.7905      morph
# 1      morph.char_cnn.ft_yap.44_seed.dset         0.7905      morph
# 2      morph.char_cnn.ft_yap.44_seed.dset         0.7905      morph
# 3  morph.char_cnn.ft_oov_tok.44_seed.dset         0.8038      morph
# 4      morph.char_cnn.ft_yap.44_seed.dset         0.7905      morph
#
#   embed_unit embed_type     cm pred_set_sub pred_set_main
# 0      morph         ft  Match         gold           dev
# 1      morph         ft  Match          yap           dev
# 2      morph         ft  Match         gold          test
# 3      token     ft_oov  Clash         gold           dev
# 4      morph         ft  Match          yap          test
#
# [5 rows x 56 columns]

# %%
output_folder = 'final_setup/decode_output'
pred_samp = nem.read_file_sents(os.path.join('final_setup/decode_output/morph_dev_gold.morph.char_cnn.ft_oov_tok.44_seed.bmes'))
pred_samp.head()
# Out:
# 0    [(עשרות, O), (אנשים, O), (מגיעים, O), (מ, O), ...
# 1    [(תופעה, O), (זו, O), (התבררה, O), (אתמול, O),...
# 2    [(יו"ר, O), (ה, O), (וועדה, O), (,, O), (ח"כ, ...
# 3    [(מ, O), (צד, O), (אחד, O), (רוצה, O), (ה, B-O...
# 4    [(נמיר, S-PER), (הודיעה, O), (כי, O), (תפנה, O...
# dtype: object

# %%
for_df = []
for i, line in pred_samp.iteritems():
    sent_id=i+1
    for j, (tok, bio) in enumerate(line):
        for_df.append((sent_id, j+1, bio))
ner_samp = pd.DataFrame(for_df, columns=['sent_id', 'id', 'biose_layer0'])
ner_samp.head()
# Out:
#    sent_id  id biose_layer0
# 0        1   1            O
# 1        1   2            O
# 2        1   3            O
# 3        1   4            O
# 4        1   5        S-GPE

# %%
yap_out = bclm.read_yap_output(treebank_set=None,
                               tokens_path=bclm.TREEBANK_TOKEN_PATHS['dev'], 
                                dep_path='final_setup/pruned/yap_output/dev.multitok.char_cnn.ft_oov_tok.53_seed.conll',
                                map_path='final_setup/pruned/yap_output/dev.multitok.char_cnn.ft_oov_tok.53_seed.map',)
yap_out.head()
# Out:
#    id    form   lemma      upostag      xpostag              feats  head  \
# 0   1   עשרות     עשר          CDT          CDT        gen=F|num=P     2
# 1   2   אנשים     איש           NN           NN        gen=M|num=P     3
# 2   3  מגיעים    הגיע           BN           BN  gen=M|num=P|per=A    14
# 3   4       מ       מ  PREPOSITION  PREPOSITION                NaN     3
# 4   5  תאילנד  תאילנד          NNP          NNP        gen=F|num=S     4
#
#   deprel deps misc  sent_id token_id token_str
# 0    num    _    _        1        1     עשרות
# 1   subj    _    _        1        2     אנשים
# 2   conj    _    _        1        3    מגיעים
# 3   comp    _    _        1        4   מתאילנד
# 4   pobj    _    _        1        4   מתאילנד

# %%
dev_gold = spdf[spdf.set=='dev']
dev_gold = dev_gold.merge(dev_unk, how='left')

# %%
full_samp = yap_out.merge(ner_samp)
full_samp = full_samp.merge(dev_unk, how='left')
full_samp.tail()
# Out:
#        id   form   lemma upostag xpostag              feats  head deprel deps  \
# 11220   1  מתחיל  התחייל     BNT     BNT  gen=M|num=S|per=A     0   ROOT    _
# 11221   2    מסע     מסע     NNT     NNT        gen=M|num=S     1   gobj    _
# 11222   3      ה       ה     DEF     DEF                NaN     4    def    _
# 11223   4   נקמה    נקמה      NN      NN        gen=F|num=S     2   gobj    _
# 11224   5      .     NaN   yyDOT   yyDOT                NaN     1  punct    _
#
#       misc  sent_id token_id token_str biose_layer0  token_unk  morph_unk  \
# 11220    _      500        1     מתחיל            O      False      False
# 11221    _      500        2       מסע            O      False      False
# 11222    _      500        3     הנקמה            O      False      False
# 11223    _      500        3     הנקמה            O      False      False
# 11224    _      500        4         .            O      False      False
#
#        lemma_unk unk_type  has_ner  morpheme_count
# 11220      False             False               1
# 11221      False             False               1
# 11222      False             False               2
# 11223      False             False               2
# 11224      False             False               1

# %%
full_samp = dev_gold.copy()
full_samp['biose_layer0'] = ner_samp['biose_layer0']
full_samp = full_samp.merge(dev_unk, how='left')
full_samp.tail()
# Out:
#        id   form  lemma upostag xpostag              feats  token_id  sent_id  \
# 11296   1  מתחיל  התחיל      BN      BN  gen=M|num=S|per=A         1      500
# 11297   2    מסע    מסע     NNT     NNT        gen=M|num=S         2      500
# 11298   3      ה      ה     DEF     DEF                  _         3      500
# 11299   4   נקמה   נקמה      NN      NN        gen=F|num=S         3      500
# 11300   5      .      _   yyDOT   yyDOT                  _         4      500
#
#       token_str  global_sent_id  ...  biose_layer0 biose_layer1 biose_layer2  \
# 11296     מתחיל             500  ...             O            O            O
# 11297       מסע             500  ...             O            O            O
# 11298     הנקמה             500  ...             O            O            O
# 11299     הנקמה             500  ...             O            O            O
# 11300         .             500  ...             O            O            O
#
#        biose_layer3 token_unk  morph_unk lemma_unk unk_type has_ner  \
# 11296             O     False      False     False            False
# 11297             O     False      False     False            False
# 11298             O     False      False     False            False
# 11299             O     False      False     False            False
# 11300             O     False      False     False            False
#
#       morpheme_count
# 11296              1
# 11297              1
# 11298              2
# 11299              2
# 11300              1
#
# [5 rows x 33 columns]

# %%
full_samp.shape, yap_out.shape, ner_samp.shape
# Out:
# ((11301, 33), (11301, 13), (11301, 3))

# %%
tuple(sorted(set([1,4,1,5,2])))
# Out:
# (1, 2, 4, 5)

# %% [markdown]
# ## Grouped mention evaluation

# %%
from collections import defaultdict

# %%
def ut_gm(x):
    filt_x = list(filter(lambda a: a != '', x))
    return tuple(sorted(set(filt_x)))
    
def sent_to_mentions_dict(sent, sent_id, truncate=None, group_maker=ut_gm, ment_len=False,
                         ment_cat=False):
    mentions = defaultdict(lambda: defaultdict(lambda: 0))
    current_mention= None
    current_cat = None
    current_group = []
    if truncate is not None:
        it = islice(sent, truncate)
    else:
        it = sent
    
    for tok, bio, cat, group in it:
        if bio=='S':
            current_group = [group]
            final_group = group_maker(current_group)
            if ment_len:
                if final_group is None:
                    final_group = 1
                else:
                    final_group = (final_group, 1)
            if ment_cat:
                final_group = (final_group, cat)
            mentions[final_group][(sent_id, tok, cat)]+=1
            current_mention= None
            current_cat = None
            current_group = []

        if bio=='B':
            current_mention = [tok]
            current_cat = cat
            current_group.append(group)
        if bio=='I' and current_mention is not None:
            current_mention.append(tok)
            current_group.append(group)
        if bio=='E' and current_mention is not None:
            current_mention.append(tok)
            current_group.append(group)
            final_group = group_maker(current_group)
            if ment_len:
                if final_group is None:
                    final_group = len(current_mention)
                else:
                    final_group = (final_group, len(current_mention))
                if ment_cat:
                    final_group = (final_group, current_cat)
            mentions[final_group][(sent_id, ' '.join(current_mention), current_cat)]+=1
            current_mention = None
            current_cat = None
            current_group = []
        if bio=='O':
            current_mention = None
            current_cat = None
            current_group = []

    return mentions

# %%
def get_sent(g, cols):
    sent = []
    for i, r in g.iterrows():
        sent.append(tuple(r[cols].tolist()))
    return sent

# %%
def get_sents_fixed(sents):
    sf = []
    for sent in sents:
        new_sent = []
        for tok, biose, *group in sent:
            if (len(group)==1):
                group = group[0]
            else:
                group = tuple(group)
            tag = biose.split('-')
            biose = tag[0]
            if len(tag)>1:
                cat = tag[1]
            else:
                cat = '_'
            new_sent.append((tok, biose, cat, group))
        sf.append(new_sent)
    sf = list(zip(list(sents.index), sf))
    return sf

# %%
def get_ment_set(sents):
    ment_set = defaultdict(list)
    for sent in sents:
        for group, gment in sent.items():
            for k, val in gment.items():
                for i in range(val):
                    ment_set[group].append((k[0], k[1], k[2], i+1))
    return ment_set

# %%
token_unk_sents = full_samp.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type'])
token_unk_sents_fixed = get_sents_fixed(token_unk_sents)
ments = [sent_to_mentions_dict(sent, sent_id) for sent_id, sent in token_unk_sents_fixed]
ment_set = get_ment_set(ments)
ment_set.keys()
# Out:
# dict_keys([('T',), (), ('TM',), ('T', 'TM')])

# %%
gold_dev_sents = dev_gold.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type'])
gold_dev_sents_fixed = get_sents_fixed(gold_dev_sents)
gold_ments = [sent_to_mentions_dict(sent, sent_id) for sent_id, sent in gold_dev_sents_fixed]
gold_ment_set = get_ment_set(gold_ments)
gold_ment_set.keys()
# Out:
# dict_keys([('T',), (), ('TM',), ('T', 'TM')])

# %%
ment_set.keys() | gold_ment_set.keys()
# Out:
# {(), ('T',), ('T', 'TM'), ('TM',)}

# %%
for k in ment_set.keys() | gold_ment_set.keys():
    print(k)
    nem.evaluate_mentions(gold_ment_set[k], ment_set[k])
# Out:
# ('T', 'TM')
# 6 mentions, 6 found, 3 correct.
# Precision: 0.5
# Recall:    0.5
# F1:        0.5
# FP ex.: ['שכונת קטמון', 'ארגון נפגעי ה משכנתאות', 'כביש באב אל - ואד']
# FN ex.: ['נאום אימפריית ה רשע', 'ארגון נפגעי ה משכנתאות ו חסרי ה דיור', 'ה קרב על מנזר סן סימון']
# ('TM',)
# 204 mentions, 178 found, 151 correct.
# Precision: 0.85
# Recall:    0.74
# F1:        0.79
# FP ex.: ['ל אקספרס', 'קטמון', 'איסט סייד', 'ירסקו', 'אולין']
# FN ex.: ['חברה קדישא', 'נווה - מונסון', 'מפם', 'טום דאיין', 'ה שדולה ה פרו - ישראלית']
# ()
# 244 mentions, 236 found, 194 correct.
# Precision: 0.82
# Recall:    0.8
# F1:        0.81
# FP ex.: ['גרוסבורד', 'מסצוסטס', 'שלום ה רב כהנא', 'קרן גון', 'ה שטחים']
# FN ex.: ['ה ליגה ל זכויות ה אדם', 'מסצוסטס', 'פיו', 'ה התאחדות ל עולם טוב יותר', 'פיו']
# ('T',)
# 45 mentions, 26 found, 23 correct.
# Precision: 0.88
# Recall:    0.51
# F1:        0.65
# FP ex.: ['ישיבת ה רעיון', 'ה ארה"ב', 'ה מסצוסטס']
# FN ex.: ['ארה"ב', 'תנועת ה מושבים', 'ה מצביע ה אמריקאי', 'ה קרב על סן סימון', 'תנועת ה מושבים']

# %% [markdown]
# ## Morpheme count

# %%
token_unk_sents = full_samp.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'morpheme_count'])
token_unk_sents_fixed = get_sents_fixed(token_unk_sents)
ments = [sent_to_mentions_dict(sent, sent_id, group_maker=max) for sent_id, sent in token_unk_sents_fixed]
ment_set = get_ment_set(ments)
ment_set.keys()
# Out:
# dict_keys([2, 3, 1])

# %%
gold_dev_sents = dev_gold.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'morpheme_count'])
gold_dev_sents_fixed = get_sents_fixed(gold_dev_sents)
gold_ments = [sent_to_mentions_dict(sent, sent_id, group_maker=max) for sent_id, sent in gold_dev_sents_fixed]
gold_ment_set = get_ment_set(gold_ments)
gold_ment_set.keys()
# Out:
# dict_keys([2, 3, 1])

# %%
ment_set.keys() | gold_ment_set.keys()
# Out:
# {1, 2, 3}

# %%
for k in ment_set.keys() | gold_ment_set.keys():
    print(k)
    nem.evaluate_mentions(gold_ment_set[k], ment_set[k], examples=11)
# Out:
# 1
# 275 mentions, 260 found, 225 correct.
# Precision: 0.87
# Recall:    0.82
# F1:        0.84
# FP ex.: ['גרוסבורד', 'מסצוסטס', 'קרן גון', 'סן סימון', 'קטמון', 'יונה', 'ירסקו', 'אולין', 'קטמון', 'וייטנאם', 'רעיה']
# FN ex.: ['מפם', 'טום דאיין', 'פיו', 'מסצוסטס', 'טובייה', 'פיו', 'ורמונט', 'דה מוין', 'מקארתור', 'סמית - ריצרדסון', 'קטמון']
# 2
# 188 mentions, 164 found, 133 correct.
# Precision: 0.81
# Recall:    0.71
# F1:        0.76
# FP ex.: ['ליון דן', 'שלום ה רב כהנא', 'ה שמרנים', 'לוס אוחוס', 'שיקאגו', 'ה ארץ', 'מדינות ה ברית', 'ישיבת ה רעיון ה יהודי', 'מקורות', 'ה ארץ', 'קטיף ה הדרים']
# FN ex.: ['ה ליגה ל זכויות ה אדם', 'חברה קדישא', 'ה שדולה ה פרו - ישראלית', 'קרן פורד', 'ליון', 'תנועת ה מושבים', 'ה מצביע ה אמריקאי', 'מלאך ה מוות', 'אושוויץ', 'ה ברוקרים של ה רעיונות : צוותות חשיבה ו עלייתה של עלית מדיניות חדשה', 'ה קרב על סן סימון']
# 3
# 36 mentions, 30 found, 25 correct.
# Precision: 0.83
# Recall:    0.69
# F1:        0.76
# FP ex.: ['ה שטחים', 'ה קטיף', 'ה קטיף', 'ה קטיף', 'ה קטיף']
# FN ex.: ['ה בית ה לבן', 'ה מלחמה ה קרה', 'ה קרב על ירושלים', 'ה קרב על מנזר סן סימון', 'ה קונסוליה ה ישראלית ב שיקאגו', 'מרכז ה מידע ל זכויות ה אדם ב ה שטחים', 'ה בית ה לבן', 'איסט סייד ה תחתית', 'ה עולם ה שלישי', 'ה מלחמה ה קרה', 'ה עבודה ו ה רווחה']

# %%
['ה בית ה לבן', 'ה מלחמה ה קרה', 'ה קרב על ירושלים', 'ה קרב על מנזר סן סימון', 'ה קונסוליה ה ישראלית ב שיקאגו', 'מרכז ה מידע ל זכויות ה אדם ב ה שטחים', 'ה בית ה לבן', 'איסט סייד ה תחתית', 'ה עולם ה שלישי', 'ה מלחמה ה קרה']
['ה בית ה לבן', 'ה מלחמה ה קרה', 'ה קרב על ירושלים', 'ה קרב על מנזר סן סימון', 'ה קונסוליה ה ישראלית ב שיקאגו', 'מרכז ה מידע ל זכויות ה אדם ב ה שטחים', 'ה בית ה לבן', 'איסט סייד ה תחתית', 'ה עולם ה שלישי', 'ה מלחמה ה קרה', 'ה עבודה ו ה רווחה']

# %%
pred_samp = nem.read_file_sents(os.path.join('final_setup/decode_output/morph_dev_gold.morph.char_cnn.glv_yap.44_seed.bmes'))
pred_samp.head()
# Out:
# 0    [(עשרות, O), (אנשים, O), (מגיעים, O), (מ, O), ...
# 1    [(תופעה, O), (זו, O), (התבררה, O), (אתמול, O),...
# 2    [(יו"ר, O), (ה, O), (וועדה, O), (,, O), (ח"כ, ...
# 3    [(מ, O), (צד, O), (אחד, O), (רוצה, O), (ה, B-O...
# 4    [(נמיר, S-PER), (הודיעה, O), (כי, O), (תפנה, O...
# dtype: object

# %%
for_df = []
for i, line in pred_samp.iteritems():
    sent_id=i+1
    for j, (tok, bio) in enumerate(line):
        for_df.append((sent_id, j+1, bio))
ner_samp = pd.DataFrame(for_df, columns=['sent_id', 'id', 'biose_layer0'])
ner_samp.head()
# Out:
#    sent_id  id biose_layer0
# 0        1   1            O
# 1        1   2            O
# 2        1   3            O
# 3        1   4            O
# 4        1   5        S-GPE

# %%
yap_out = bclm.read_yap_output(treebank_set=None,
                               tokens_path=bclm.TREEBANK_TOKEN_PATHS['dev'], 
                                dep_path=txt_map[('dev', 'char_cnn', 'glv_yap', 'conll')],
                                map_path=txt_map[('dev', 'char_cnn', 'glv_yap', 'map')],)
yap_out.head()
# Out:
#    id    form   lemma      upostag      xpostag              feats  head  \
# 0   1   עשרות     עשר          CDT          CDT        gen=F|num=P     2
# 1   2   אנשים     איש           NN           NN        gen=M|num=P     3
# 2   3  מגיעים    הגיע           BN           BN  gen=M|num=P|per=A    14
# 3   4       מ       מ  PREPOSITION  PREPOSITION                NaN     3
# 4   5  תאילנד  תאילנד          NNP          NNP        gen=F|num=S     4
#
#   deprel deps misc  sent_id token_id token_str
# 0    num    _    _        1        1     עשרות
# 1   subj    _    _        1        2     אנשים
# 2   conj    _    _        1        3    מגיעים
# 3   comp    _    _        1        4   מתאילנד
# 4   pobj    _    _        1        4   מתאילנד

# %%
full_samp = yap_out.merge(ner_samp)
full_samp = full_samp.merge(dev_unk, how='left')
full_samp.tail()
# Out:
#        id   form   lemma upostag xpostag              feats  head deprel deps  \
# 11188   1  מתחיל  התחייל     BNT     BNT  gen=M|num=S|per=A     0   ROOT    _
# 11189   2    מסע     מסע     NNT     NNT        gen=M|num=S     1   gobj    _
# 11190   3      ה       ה     DEF     DEF                NaN     4    def    _
# 11191   4   נקמה    נקמה      NN      NN        gen=F|num=S     2   gobj    _
# 11192   5      .     NaN   yyDOT   yyDOT                NaN     1  punct    _
#
#       misc  sent_id token_id token_str biose_layer0  token_unk  morph_unk  \
# 11188    _      500        1     מתחיל            O      False      False
# 11189    _      500        2       מסע            O      False      False
# 11190    _      500        3     הנקמה            O      False      False
# 11191    _      500        3     הנקמה            O      False      False
# 11192    _      500        4         .            O      False      False
#
#        lemma_unk unk_type  has_ner  morpheme_count
# 11188      False             False               1
# 11189      False             False               1
# 11190      False             False               2
# 11191      False             False               2
# 11192      False             False               1

# %%
full_samp = dev_gold.copy()
full_samp['biose_layer0'] = ner_samp['biose_layer0']
full_samp = full_samp.merge(dev_unk, how='left')
full_samp.tail()
# Out:
#        id   form  lemma upostag xpostag              feats  token_id  sent_id  \
# 11296   1  מתחיל  התחיל      BN      BN  gen=M|num=S|per=A         1      500
# 11297   2    מסע    מסע     NNT     NNT        gen=M|num=S         2      500
# 11298   3      ה      ה     DEF     DEF                  _         3      500
# 11299   4   נקמה   נקמה      NN      NN        gen=F|num=S         3      500
# 11300   5      .      _   yyDOT   yyDOT                  _         4      500
#
#       token_str  global_sent_id  ...  biose_layer0 biose_layer1 biose_layer2  \
# 11296     מתחיל             500  ...             O            O            O
# 11297       מסע             500  ...             O            O            O
# 11298     הנקמה             500  ...             O            O            O
# 11299     הנקמה             500  ...             O            O            O
# 11300         .             500  ...             O            O            O
#
#        biose_layer3 token_unk  morph_unk lemma_unk unk_type has_ner  \
# 11296             O     False      False     False            False
# 11297             O     False      False     False            False
# 11298             O     False      False     False            False
# 11299             O     False      False     False            False
# 11300             O     False      False     False            False
#
#       morpheme_count
# 11296              1
# 11297              1
# 11298              2
# 11299              2
# 11300              1
#
# [5 rows x 33 columns]

# %%
token_unk_sents = full_samp.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'morpheme_count'])
token_unk_sents_fixed = get_sents_fixed(token_unk_sents)
ments = [sent_to_mentions_dict(sent, sent_id, group_maker=max) for sent_id, sent in token_unk_sents_fixed]
ment_set = get_ment_set(ments)
ment_set.keys()
# Out:
# dict_keys([2, 3, 1])

# %%
gold_dev_sents = dev_gold.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'morpheme_count'])
gold_dev_sents_fixed = get_sents_fixed(gold_dev_sents)
gold_ments = [sent_to_mentions_dict(sent, sent_id, group_maker=max) for sent_id, sent in gold_dev_sents_fixed]
gold_ment_set = get_ment_set(gold_ments)
gold_ment_set.keys()
# Out:
# dict_keys([2, 3, 1])

# %%
ment_set.keys() | gold_ment_set.keys()
# Out:
# {1, 2, 3}

# %%
for k in ment_set.keys() | gold_ment_set.keys():
    print(k)
    nem.evaluate_mentions(gold_ment_set[k], ment_set[k], examples=10)
# Out:
# 1
# 275 mentions, 268 found, 220 correct.
# Precision: 0.82
# Recall:    0.8
# F1:        0.81
# FP ex.: ['אוחדה', 'גרוסבורד', 'הדסון', 'רץ', 'קדישא', 'יונה', 'אולין', 'ברוקינגס', 'רצ"ב', 'וייטנאם']
# FN ex.: ['קול ישראל', 'מפם', 'טום דאיין', 'פיו', 'מסצוסטס', 'טובייה', 'פיו', 'ריצארדס', 'דה מוין', 'מקארתור']
# 2
# 188 mentions, 156 found, 126 correct.
# Precision: 0.81
# Recall:    0.67
# F1:        0.73
# FP ex.: ['ליון דן', 'ה משטרה', 'שיקאגו', 'ה ארץ', 'מדינות ה ברית', 'מקורות', 'ה ארץ', 'שמואל ה נביא', 'עלי', 'מושלת טקסס']
# FN ex.: ['ה ליגה ל זכויות ה אדם', 'חברה קדישא', 'נווה - מונסון', 'ה שדולה ה פרו - ישראלית', 'קרן פורד', 'ליון', 'ה התאחדות ל עולם טוב יותר', 'ה מצביע ה אמריקאי', 'מלאך ה מוות', 'ה מיליציה ה צרפתית']
# 3
# 36 mentions, 28 found, 26 correct.
# Precision: 0.93
# Recall:    0.72
# F1:        0.81
# FP ex.: ['ה שטחים', 'ה איסט סייד']
# FN ex.: ['ה בית ה לבן', 'ה מלחמה ה קרה', 'ה קרב על ירושלים', 'ה קרב על מנזר סן סימון', 'מרכז ה מידע ל זכויות ה אדם ב ה שטחים', 'ה בית ה לבן', 'איסט סייד ה תחתית', 'ה עולם ה שלישי', 'ה מלחמה ה קרה', 'ה קונסוליה ה ישראלית ב שיקאגו']

# %% [markdown]
# ## Check morpheme count together with unk_type

# %%
def gm(l):
    uts, mcs = list(zip(*l))
    ut = ut_gm(uts)
    mc = max(mcs)
    return ut, mc

# %%
token_unk_sents = full_samp.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type', 'morpheme_count'])
token_unk_sents_fixed = get_sents_fixed(token_unk_sents)
ments = [sent_to_mentions_dict(sent, sent_id, group_maker=gm) for sent_id, sent in token_unk_sents_fixed]
ment_set = get_ment_set(ments)
ment_set.keys()
# Out:
# dict_keys([(('T',), 2), ((), 2), ((), 3), ((), 1), (('T',), 1), (('TM',), 1), (('T', 'TM'), 1), (('TM',), 2), (('T', 'TM'), 2), (('TM',), 3), (('T',), 3)])

# %%
gold_dev_sents = dev_gold.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type', 'morpheme_count'])
gold_dev_sents_fixed = get_sents_fixed(gold_dev_sents)
gold_ments = [sent_to_mentions_dict(sent, sent_id, group_maker=gm) for sent_id, sent in gold_dev_sents_fixed]
gold_ment_set = get_ment_set(gold_ments)
gold_ment_set.keys()
# Out:
# dict_keys([(('T',), 2), ((), 2), ((), 3), ((), 1), (('T',), 3), (('T',), 1), (('TM',), 1), (('T', 'TM'), 3), (('TM',), 2), (('T', 'TM'), 2), (('TM',), 3)])

# %%
ment_set.keys() | gold_ment_set.keys()
# Out:
# {((), 1),
#  ((), 2),
#  ((), 3),
#  (('T',), 1),
#  (('T',), 2),
#  (('T',), 3),
#  (('T', 'TM'), 1),
#  (('T', 'TM'), 2),
#  (('T', 'TM'), 3),
#  (('TM',), 1),
#  (('TM',), 2),
#  (('TM',), 3)}

# %%
for k in ment_set.keys() | gold_ment_set.keys():
    print(k)
    nem.evaluate_mentions(gold_ment_set[k], ment_set[k])
# Out:
# (('TM',), 3)
# 2 mentions, 5 found, 0 correct.
# Precision: 0.0
# Recall:    0.0
# F1:        -1
# FP ex.: ['ה קטיף', 'איסט סייד', 'ה קטיף', 'ה קטיף', 'ה קטיף']
# FN ex.: ['איסט סייד ה תחתית', 'ה קונסוליה ה ישראלית ב שיקאגו']
# (('TM',), 2)
# 47 mentions, 30 found, 26 correct.
# Precision: 0.87
# Recall:    0.55
# F1:        0.68
# FP ex.: ['נווה - מונסון', 'הרי בראדלו', 'קרן פורד שמרנים', 'קטיף ה הדרים']
# FN ex.: ['חברה קדישא', 'נווה - מונסון', 'ה שדולה ה פרו - ישראלית', 'ליון', 'קרן פורד']
# (('T', 'TM'), 3)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה קרב על מנזר סן סימון']
# (('T', 'TM'), 2)
# 5 mentions, 4 found, 3 correct.
# Precision: 0.75
# Recall:    0.6
# F1:        0.67
# FP ex.: ['ארגון נפגעי ה משכנתאות']
# FN ex.: ['נאום אימפריית ה רשע', 'ארגון נפגעי ה משכנתאות ו חסרי ה דיור']
# (('T',), 2)
# 34 mentions, 20 found, 19 correct.
# Precision: 0.95
# Recall:    0.56
# F1:        0.7
# FP ex.: ['ישיבת ה רעיון']
# FN ex.: ['ה קרב על סן סימון', 'תנועת ה מושבים', 'ה בית ה לבן', 'ה בית ה לבן', 'ישיבת ה רעיון ה יהודי']
# (('T', 'TM'), 1)
# 0 mentions, 2 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['שכונת קטמון', 'כביש באב אל - ואד']
# FN ex.: []
# (('T',), 3)
# 9 mentions, 4 found, 2 correct.
# Precision: 0.5
# Recall:    0.22
# F1:        0.31
# FP ex.: ['ה ארה"ב', 'ה מסצוסטס']
# FN ex.: ['ה בית ה לבן', 'ארה"ב', 'ה מלחמה ה קרה', 'מסצוסטס', 'ה בית ה לבן']
# ((), 2)
# 102 mentions, 102 found, 80 correct.
# Precision: 0.78
# Recall:    0.78
# F1:        0.78
# FP ex.: ['שלום ה רב כהנא', 'ה שמרנים', 'שיקאגו', 'ה ארץ', 'מדינות ה ברית']
# FN ex.: ['ה ליגה ל זכויות ה אדם', 'ה התאחדות ל עולם טוב יותר', 'אושוויץ', 'ה ארץ', 'ה ארץ']
# ((), 3)
# 24 mentions, 20 found, 18 correct.
# Precision: 0.9
# Recall:    0.75
# F1:        0.82
# FP ex.: ['ה שטחים', 'ה ארץ']
# FN ex.: ['ה ארץ', 'ה ארץ', 'ה קרב על ירושלים', 'מרכז ה מידע ל זכויות ה אדם ב ה שטחים', 'ה כנסת']
# (('T',), 1)
# 2 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((), 1)
# 118 mentions, 114 found, 96 correct.
# Precision: 0.84
# Recall:    0.81
# F1:        0.83
# FP ex.: ['מסצוסטס', 'הראל', 'גרוסבורד', 'מסצוסטס', 'מחוז פאריס']
# FN ex.: ['מסצוסטס', 'פיו', 'פיו', 'ה', 'מחוז פאריס']
# (('TM',), 1)
# 155 mentions, 143 found, 125 correct.
# Precision: 0.87
# Recall:    0.81
# F1:        0.84
# FP ex.: ['מנזר סן סימון', 'פראפראז', 'מכון ה דסון', 'סמית - ריצרדסון', 'ל אקספרס']
# FN ex.: ['מפם', 'טום דאיין', 'טובייה', 'ורמונט', 'לאקספרס']

# %% [markdown]
# ## Check length of mention

# %%
token_unk_sents = full_samp.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type', 'morpheme_count'])
token_unk_sents_fixed = get_sents_fixed(token_unk_sents)
ments = [sent_to_mentions_dict(sent, sent_id, group_maker=lambda x: None, ment_len=True) for sent_id, sent in token_unk_sents_fixed]
ment_set = get_ment_set(ments)
ment_set.keys()
# Out:
# dict_keys([1, 6, 2, 3, 4, 5, 7])

# %%
gold_dev_sents = dev_gold.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type', 'morpheme_count'])
gold_dev_sents_fixed = get_sents_fixed(gold_dev_sents)
gold_ments = [sent_to_mentions_dict(sent, sent_id, group_maker=lambda x: None, ment_len=True) for sent_id, sent in gold_dev_sents_fixed]
gold_ment_set = get_ment_set(gold_ments)
gold_ment_set.keys()
# Out:
# dict_keys([1, 6, 2, 5, 3, 4, 8, 7, 10, 14])

# %%
ment_set.keys() | gold_ment_set.keys()
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 10, 14}

# %%
for k in sorted(ment_set.keys() | gold_ment_set.keys()):
    print(k)
    nem.evaluate_mentions(gold_ment_set[k], ment_set[k])
# Out:
# 1
# 228 mentions, 207 found, 183 correct.
# Precision: 0.88
# Recall:    0.8
# F1:        0.84
# FP ex.: ['גרוסבורד', 'מסצוסטס', 'מסצוסטס', 'קטמון', 'יונה']
# FN ex.: ['ארה"ב', 'מפם', 'פיו', 'מסצוסטס', 'ליון']
# 2
# 154 mentions, 152 found, 123 correct.
# Precision: 0.81
# Recall:    0.8
# F1:        0.8
# FP ex.: ['קרן גון', 'ה שמרנים', 'ל אקספרס', 'ה שטחים', 'איסט סייד']
# FN ex.: ['חברה קדישא', 'טום דאיין', 'קרן פורד', 'ה ארץ', 'ה כנסת']
# 3
# 48 mentions, 44 found, 30 correct.
# Precision: 0.68
# Recall:    0.62
# F1:        0.65
# FP ex.: ['מנזר סן סימון', 'מכון ה דסון', 'סמית - ריצרדסון', 'נווה - מונסון', 'ישיבת ה רעיון']
# FN ex.: ['מלחמת ה עצמאות', 'ירושלים ה מערבית', 'נווה - מונסון', 'תנועת ה מושבים', 'אמריקן אקונומיק ריוויו']
# 4
# 45 mentions, 29 found, 24 correct.
# Precision: 0.83
# Recall:    0.53
# F1:        0.65
# FP ex.: ['שלום ה רב כהנא', 'ה מלחמת ה עצמאות', 'הר - ה בית', 'ארגון נפגעי ה משכנתאות', 'שכונת שמואל ה נביא']
# FN ex.: ['ה מצביע ה אמריקאי', 'ה עולם ה שלישי', 'לינד ו הרי בראדלו', 'ה קרב על ירושלים', 'איסט סייד ה תחתית']
# 5
# 12 mentions, 10 found, 7 correct.
# Precision: 0.7
# Recall:    0.58
# F1:        0.64
# FP ex.: ['ישיבת ה רעיון ה יהודי', 'אייפא"ק טום דאיין את הארקין', 'כביש באב אל - ואד']
# FN ex.: ['ה קרב על סן סימון', 'ישיבת ה רעיון ה יהודי', 'ישיבת ה רעיון ה יהודי', 'ה קרב על סן סימון', 'ה עבודה ו ה רווחה']
# 6
# 8 mentions, 3 found, 3 correct.
# Precision: 1.0
# Recall:    0.38
# F1:        0.55
# FP ex.: []
# FN ex.: ['ה ליגה ל זכויות ה אדם', 'ה שדולה ה פרו - ישראלית', 'ה התאחדות ל עולם טוב יותר', 'ה קרב על מנזר סן סימון', 'ה קונסוליה ה ישראלית ב שיקאגו']
# 7
# 1 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# 8
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ארגון נפגעי ה משכנתאות ו חסרי ה דיור']
# 10
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['מרכז ה מידע ל זכויות ה אדם ב ה שטחים']
# 14
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה ברוקרים של ה רעיונות : צוותות חשיבה ו עלייתה של עלית מדיניות חדשה']

# %% [markdown]
# ## Length+unk_type

# %%
token_unk_sents = full_samp.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type'])
token_unk_sents_fixed = get_sents_fixed(token_unk_sents)
ments = [sent_to_mentions_dict(sent, sent_id, group_maker=ut_gm, ment_len=True) for sent_id, sent in token_unk_sents_fixed]
ment_set = get_ment_set(ments)
ment_set.keys()
# Out:
# dict_keys([(('T',), 1), ((), 1), ((), 6), ((), 2), (('T',), 2), (('T',), 3), ((), 3), ((), 4), ((), 5), (('TM',), 2), (('T', 'TM'), 2), (('TM',), 1), (('TM',), 3), (('T', 'TM'), 5), (('T', 'TM'), 4), ((), 7), (('TM',), 5), (('T',), 5), (('TM',), 4)])

# %%
gold_dev_sents = dev_gold.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type'])
gold_dev_sents_fixed = get_sents_fixed(gold_dev_sents)
gold_ments = [sent_to_mentions_dict(sent, sent_id, group_maker=ut_gm, ment_len=True) for sent_id, sent in gold_dev_sents_fixed]
gold_ment_set = get_ment_set(gold_ments)
gold_ment_set.keys()
# Out:
# dict_keys([(('T',), 1), ((), 1), ((), 6), ((), 2), (('T',), 5), (('T',), 3), (('T',), 2), ((), 3), ((), 4), ((), 5), (('TM',), 2), (('TM',), 1), (('TM',), 3), (('T', 'TM'), 6), (('TM',), 4), (('T', 'TM'), 8), ((), 7), (('T',), 4), (('TM',), 6), ((), 10), (('T', 'TM'), 2), (('T', 'TM'), 4), (('TM',), 14)])

# %%
ment_set.keys() | gold_ment_set.keys()
# Out:
# {((), 1),
#  ((), 2),
#  ((), 3),
#  ((), 4),
#  ((), 5),
#  ((), 6),
#  ((), 7),
#  ((), 10),
#  (('T',), 1),
#  (('T',), 2),
#  (('T',), 3),
#  (('T',), 4),
#  (('T',), 5),
#  (('T', 'TM'), 2),
#  (('T', 'TM'), 4),
#  (('T', 'TM'), 5),
#  (('T', 'TM'), 6),
#  (('T', 'TM'), 8),
#  (('TM',), 1),
#  (('TM',), 2),
#  (('TM',), 3),
#  (('TM',), 4),
#  (('TM',), 5),
#  (('TM',), 6),
#  (('TM',), 14)}

# %%
for k in sorted(ment_set.keys() | gold_ment_set.keys()):
    print(k)
    nem.evaluate_mentions(gold_ment_set[k], ment_set[k])
# Out:
# ((), 1)
# 110 mentions, 108 found, 92 correct.
# Precision: 0.85
# Recall:    0.84
# F1:        0.84
# FP ex.: ['מסצוסטס', 'הראל', 'גרוסבורד', 'מסצוסטס', 'מסצוסטס']
# FN ex.: ['ה', 'כך', 'וייטנאם', 'מסצוסטס', 'פיו']
# ((), 2)
# 69 mentions, 69 found, 53 correct.
# Precision: 0.77
# Recall:    0.77
# F1:        0.77
# FP ex.: ['מחוז פאריס', 'ה שמרנים', 'סן סימון', 'ה שטחים', 'קרן גון']
# FN ex.: ['ה ארץ', 'מחוז פאריס', 'ה גרמנים', 'סנטר 1', 'ניו גרסי']
# ((), 3)
# 23 mentions, 23 found, 18 correct.
# Precision: 0.78
# Recall:    0.78
# F1:        0.78
# FP ex.: ['רצח ה נזירות', 'מדינות ה ברית', 'רחוב גבעת שאול', 'גורג ה מסכן', 'ה שירות פועל']
# FN ex.: ['בית מספר 3', 'ירושלים ה מערבית', 'רחוב גבעת שאול', 'מלחמת ה עצמאות', 'ניו - יורק']
# ((), 4)
# 29 mentions, 26 found, 22 correct.
# Precision: 0.85
# Recall:    0.76
# F1:        0.8
# FP ex.: ['הר - ה בית', 'שכונת שמואל ה נביא', 'שלום ה רב כהנא', 'ה מלחמת ה עצמאות']
# FN ex.: ['חטיבת " הראל "', 'פרס נובל ל שלום', 'ה קרב על ירושלים', 'הר - ה בית', 'שכונת שמואל ה נביא']
# ((), 5)
# 6 mentions, 6 found, 5 correct.
# Precision: 0.83
# Recall:    0.83
# F1:        0.83
# FP ex.: ['ישיבת ה רעיון ה יהודי']
# FN ex.: ['ישיבת ה רעיון ה יהודי']
# ((), 6)
# 5 mentions, 3 found, 3 correct.
# Precision: 1.0
# Recall:    0.6
# F1:        0.75
# FP ex.: []
# FN ex.: ['ה ליגה ל זכויות ה אדם', 'ה התאחדות ל עולם טוב יותר']
# ((), 7)
# 1 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((), 10)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['מרכז ה מידע ל זכויות ה אדם ב ה שטחים']
# (('T',), 1)
# 16 mentions, 12 found, 12 correct.
# Precision: 1.0
# Recall:    0.75
# F1:        0.86
# FP ex.: []
# FN ex.: ['קדיש', 'מסצוסטס', 'ארה"ב', 'לין']
# (('T',), 2)
# 7 mentions, 8 found, 6 correct.
# Precision: 0.75
# Recall:    0.86
# F1:        0.8
# FP ex.: ['ה ארה"ב', 'ה מסצוסטס']
# FN ex.: ['עין כרם']
# (('T',), 3)
# 7 mentions, 4 found, 3 correct.
# Precision: 0.75
# Recall:    0.43
# F1:        0.55
# FP ex.: ['ישיבת ה רעיון']
# FN ex.: ['תנועת ה מושבים', 'תנועת ה מושבים', 'תנועת ה מושבים', 'תנועת ה מושבים']
# (('T',), 4)
# 9 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה בית ה לבן', 'ה בית ה לבן', 'ה מלחמה ה קרה', 'ה בית ה לבן', 'ה מצביע ה אמריקאי']
# (('T',), 5)
# 6 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    0.33
# F1:        0.5
# FP ex.: []
# FN ex.: ['ה קרב על סן סימון', 'ישיבת ה רעיון ה יהודי', 'ה קרב על סן סימון', 'ה עבודה ו ה רווחה']
# (('T', 'TM'), 2)
# 3 mentions, 4 found, 3 correct.
# Precision: 0.75
# Recall:    1.0
# F1:        0.86
# FP ex.: ['שכונת קטמון']
# FN ex.: []
# (('T', 'TM'), 4)
# 1 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    0.0
# F1:        -1
# FP ex.: ['ארגון נפגעי ה משכנתאות']
# FN ex.: ['נאום אימפריית ה רשע']
# (('T', 'TM'), 5)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['כביש באב אל - ואד']
# FN ex.: []
# (('T', 'TM'), 6)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה קרב על מנזר סן סימון']
# (('T', 'TM'), 8)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ארגון נפגעי ה משכנתאות ו חסרי ה דיור']
# (('TM',), 1)
# 102 mentions, 87 found, 79 correct.
# Precision: 0.91
# Recall:    0.77
# F1:        0.84
# FP ex.: ['פראפראז', 'קטמון', 'ירסקו', 'לינד', 'גאנט']
# FN ex.: ['מפם', 'ליון', 'טובייה', 'ורמונט', 'לאקספרס']
# (('TM',), 2)
# 75 mentions, 71 found, 61 correct.
# Precision: 0.86
# Recall:    0.81
# F1:        0.84
# FP ex.: ['ל אקספרס', 'ה קטיף', 'איסט סייד', 'ה קטיף', 'ה קטיף']
# FN ex.: ['חברה קדישא', 'חברה קדישא', 'טום דאיין', 'ה גסטאפו', 'ה פלמ"ח']
# (('TM',), 3)
# 18 mentions, 17 found, 9 correct.
# Precision: 0.53
# Recall:    0.5
# F1:        0.51
# FP ex.: ['מנזר סן סימון', 'סמית - ריצרדסון', 'מכון ה דסון', 'נווה - מונסון', 'אמריקן אקונומיק ריוויו']
# FN ex.: ['אמריקן אקונומיק ריוויו', 'נווה - מונסון', 'מנזר סן סימון', 'מנזר סן סימון', 'מלאך ה מוות']
# (('TM',), 4)
# 6 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    0.33
# F1:        0.5
# FP ex.: []
# FN ex.: ['מענק " גאונות "', 'באב אל - ואד', 'לינד ו הרי בראדלו', 'איסט סייד ה תחתית']
# (('TM',), 5)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['אייפא"ק טום דאיין את הארקין']
# FN ex.: []
# (('TM',), 6)
# 2 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה שדולה ה פרו - ישראלית', 'ה קונסוליה ה ישראלית ב שיקאגו']
# (('TM',), 14)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה ברוקרים של ה רעיונות : צוותות חשיבה ו עלייתה של עלית מדיניות חדשה']

# %% [markdown]
# ## Length+unk_type+morpheme_count

# %%
token_unk_sents = full_samp.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type', 'morpheme_count'])
token_unk_sents_fixed = get_sents_fixed(token_unk_sents)
ments = [sent_to_mentions_dict(sent, sent_id, group_maker=gm, ment_len=True) for sent_id, sent in token_unk_sents_fixed]
ment_set = get_ment_set(ments)
ment_set.keys()
# Out:
# dict_keys([((('T',), 2), 1), (((), 2), 1), (((), 3), 6), (((), 2), 2), (((), 1), 2), (((), 1), 1), ((('T',), 1), 2), ((('T',), 2), 3), (((), 2), 3), ((('T',), 2), 2), (((), 2), 4), (((), 3), 5), ((('TM',), 1), 2), (((), 3), 2), ((('T', 'TM'), 1), 2), ((('TM',), 1), 1), ((('TM',), 1), 3), ((('TM',), 2), 3), ((('T', 'TM'), 1), 5), (((), 2), 5), ((('T', 'TM'), 2), 4), (((), 3), 4), ((('TM',), 2), 1), ((('TM',), 2), 2), (((), 2), 7), ((('TM',), 1), 5), ((('TM',), 3), 2), ((('T',), 2), 5), (((), 1), 3), ((('T', 'TM'), 2), 2), ((('T',), 3), 1), ((('TM',), 1), 4), ((('T',), 3), 2), (((), 1), 4)])

# %%
gold_dev_sents = dev_gold.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type', 'morpheme_count'])
gold_dev_sents_fixed = get_sents_fixed(gold_dev_sents)
gold_ments = [sent_to_mentions_dict(sent, sent_id, group_maker=gm, ment_len=True) for sent_id, sent in gold_dev_sents_fixed]
gold_ment_set = get_ment_set(gold_ments)
gold_ment_set.keys()
# Out:
# dict_keys([((('T',), 2), 1), (((), 2), 1), (((), 3), 6), (((), 2), 2), (((), 1), 2), (((), 1), 1), ((('T',), 3), 5), ((('T',), 2), 3), ((('T',), 1), 2), (((), 2), 3), ((('T',), 2), 2), (((), 2), 4), (((), 3), 5), ((('TM',), 1), 2), ((('TM',), 1), 1), (((), 3), 2), ((('T',), 2), 5), (((), 3), 4), ((('TM',), 1), 3), (((), 1), 4), ((('T', 'TM'), 3), 6), ((('TM',), 2), 3), ((('TM',), 2), 2), ((('TM',), 1), 4), (((), 2), 5), ((('T', 'TM'), 2), 8), ((('TM',), 2), 1), (((), 2), 7), ((('T',), 2), 4), ((('TM',), 2), 6), ((('TM',), 3), 6), (((), 3), 10), ((('TM',), 2), 4), (((), 2), 6), (((), 1), 3), ((('T', 'TM'), 2), 2), ((('T',), 3), 1), ((('TM',), 3), 4), ((('T', 'TM'), 2), 4), ((('T',), 3), 4), ((('TM',), 2), 14)])

# %%
ment_set.keys() | gold_ment_set.keys()
# Out:
# {(((), 1), 1),
#  (((), 1), 2),
#  (((), 1), 3),
#  (((), 1), 4),
#  (((), 2), 1),
#  (((), 2), 2),
#  (((), 2), 3),
#  (((), 2), 4),
#  (((), 2), 5),
#  (((), 2), 6),
#  (((), 2), 7),
#  (((), 3), 2),
#  (((), 3), 4),
#  (((), 3), 5),
#  (((), 3), 6),
#  (((), 3), 10),
#  ((('T',), 1), 2),
#  ((('T',), 2), 1),
#  ((('T',), 2), 2),
#  ((('T',), 2), 3),
#  ((('T',), 2), 4),
#  ((('T',), 2), 5),
#  ((('T',), 3), 1),
#  ((('T',), 3), 2),
#  ((('T',), 3), 4),
#  ((('T',), 3), 5),
#  ((('T', 'TM'), 1), 2),
#  ((('T', 'TM'), 1), 5),
#  ((('T', 'TM'), 2), 2),
#  ((('T', 'TM'), 2), 4),
#  ((('T', 'TM'), 2), 8),
#  ((('T', 'TM'), 3), 6),
#  ((('TM',), 1), 1),
#  ((('TM',), 1), 2),
#  ((('TM',), 1), 3),
#  ((('TM',), 1), 4),
#  ((('TM',), 1), 5),
#  ((('TM',), 2), 1),
#  ((('TM',), 2), 2),
#  ((('TM',), 2), 3),
#  ((('TM',), 2), 4),
#  ((('TM',), 2), 6),
#  ((('TM',), 2), 14),
#  ((('TM',), 3), 2),
#  ((('TM',), 3), 4),
#  ((('TM',), 3), 6)}

# %%
for k in sorted(ment_set.keys() | gold_ment_set.keys()):
    print(k)
    nem.evaluate_mentions(gold_ment_set[k], ment_set[k])
# Out:
# (((), 1), 1)
# 73 mentions, 68 found, 56 correct.
# Precision: 0.82
# Recall:    0.77
# F1:        0.79
# FP ex.: ['מסצוסטס', 'גרוסבורד', 'הראל', 'מסצוסטס', 'מסצוסטס']
# FN ex.: ['ה', 'כך', 'וייטנאם', 'מסצוסטס', 'פיו']
# (((), 1), 2)
# 39 mentions, 42 found, 36 correct.
# Precision: 0.86
# Recall:    0.92
# F1:        0.89
# FP ex.: ['מחוז פאריס', 'קרן גון', 'סן סימון', 'נא מילוא', 'שלום עכשיו']
# FN ex.: ['מחוז פאריס', 'בית נבחרים', 'סנטר 1']
# (((), 1), 3)
# 4 mentions, 3 found, 3 correct.
# Precision: 1.0
# Recall:    0.75
# F1:        0.86
# FP ex.: []
# FN ex.: ['בית מספר 3']
# (((), 1), 4)
# 2 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    0.5
# F1:        0.67
# FP ex.: []
# FN ex.: ['חטיבת " הראל "']
# (((), 2), 1)
# 37 mentions, 40 found, 36 correct.
# Precision: 0.9
# Recall:    0.97
# F1:        0.94
# FP ex.: ['ירושלים', 'מקורות', 'אושוויץ', 'שיקאגו']
# FN ex.: ['אושוויץ']
# (((), 2), 2)
# 19 mentions, 17 found, 9 correct.
# Precision: 0.53
# Recall:    0.47
# F1:        0.5
# FP ex.: ['ה שמרנים', 'ה ארץ', 'ה שמרנים', 'ה ארץ', 'ה קב"ה']
# FN ex.: ['ניו גרסי', 'ה גרמנים', 'ה מלחמה', 'ה קב"ה', 'ה משטרה']
# (((), 2), 3)
# 19 mentions, 20 found, 15 correct.
# Precision: 0.75
# Recall:    0.79
# F1:        0.77
# FP ex.: ['רצח ה נזירות', 'מדינות ה ברית', 'רחוב גבעת שאול', 'גורג ה מסכן', 'ה שירות פועל']
# FN ex.: ['ירושלים ה מערבית', 'מלחמת ה עצמאות', 'רחוב גבעת שאול', 'ניו - יורק']
# (((), 2), 4)
# 19 mentions, 19 found, 15 correct.
# Precision: 0.79
# Recall:    0.79
# F1:        0.79
# FP ex.: ['הר - ה בית', 'שכונת שמואל ה נביא', 'שלום ה רב כהנא', 'ה מלחמת ה עצמאות']
# FN ex.: ['הר - ה בית', 'שכונת שמואל ה נביא', 'פרס נובל ל שלום', 'ה עולם ה שלישי']
# (((), 2), 5)
# 5 mentions, 5 found, 4 correct.
# Precision: 0.8
# Recall:    0.8
# F1:        0.8
# FP ex.: ['ישיבת ה רעיון ה יהודי']
# FN ex.: ['ישיבת ה רעיון ה יהודי']
# (((), 2), 6)
# 2 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה ליגה ל זכויות ה אדם', 'ה התאחדות ל עולם טוב יותר']
# (((), 2), 7)
# 1 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# (((), 3), 2)
# 11 mentions, 10 found, 8 correct.
# Precision: 0.8
# Recall:    0.73
# F1:        0.76
# FP ex.: ['ה שטחים', 'ה ארץ']
# FN ex.: ['ה ארץ', 'ה ארץ', 'ה כנסת']
# (((), 3), 4)
# 8 mentions, 6 found, 6 correct.
# Precision: 1.0
# Recall:    0.75
# F1:        0.86
# FP ex.: []
# FN ex.: ['ה עולם ה שלישי', 'ה קרב על ירושלים']
# (((), 3), 5)
# 1 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# (((), 3), 6)
# 3 mentions, 3 found, 3 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# (((), 3), 10)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['מרכז ה מידע ל זכויות ה אדם ב ה שטחים']
# ((('T',), 1), 2)
# 2 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('T',), 2), 1)
# 12 mentions, 10 found, 10 correct.
# Precision: 1.0
# Recall:    0.83
# F1:        0.91
# FP ex.: []
# FN ex.: ['קדיש', 'לין']
# ((('T',), 2), 2)
# 5 mentions, 4 found, 4 correct.
# Precision: 1.0
# Recall:    0.8
# F1:        0.89
# FP ex.: []
# FN ex.: ['עין כרם']
# ((('T',), 2), 3)
# 7 mentions, 4 found, 3 correct.
# Precision: 0.75
# Recall:    0.43
# F1:        0.55
# FP ex.: ['ישיבת ה רעיון']
# FN ex.: ['תנועת ה מושבים', 'תנועת ה מושבים', 'תנועת ה מושבים', 'תנועת ה מושבים']
# ((('T',), 2), 4)
# 5 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה מלחמה ה קרה', 'ה בית ה לבן', 'ה בית ה לבן', 'צדקה מתחילה מ בית', 'ה מצביע ה אמריקאי']
# ((('T',), 2), 5)
# 5 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    0.4
# F1:        0.57
# FP ex.: []
# FN ex.: ['ה קרב על סן סימון', 'ישיבת ה רעיון ה יהודי', 'ה קרב על סן סימון']
# ((('T',), 3), 1)
# 4 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    0.5
# F1:        0.67
# FP ex.: []
# FN ex.: ['מסצוסטס', 'ארה"ב']
# ((('T',), 3), 2)
# 0 mentions, 2 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['ה ארה"ב', 'ה מסצוסטס']
# FN ex.: []
# ((('T',), 3), 4)
# 4 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה מלחמה ה קרה', 'ה בית ה לבן', 'ה בית ה לבן', 'ה מלחמה ה קרה']
# ((('T',), 3), 5)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה עבודה ו ה רווחה']
# ((('T', 'TM'), 1), 2)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['שכונת קטמון']
# FN ex.: []
# ((('T', 'TM'), 1), 5)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['כביש באב אל - ואד']
# FN ex.: []
# ((('T', 'TM'), 2), 2)
# 3 mentions, 3 found, 3 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('T', 'TM'), 2), 4)
# 1 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    0.0
# F1:        -1
# FP ex.: ['ארגון נפגעי ה משכנתאות']
# FN ex.: ['נאום אימפריית ה רשע']
# ((('T', 'TM'), 2), 8)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ארגון נפגעי ה משכנתאות ו חסרי ה דיור']
# ((('T', 'TM'), 3), 6)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה קרב על מנזר סן סימון']
# ((('TM',), 1), 1)
# 79 mentions, 67 found, 59 correct.
# Precision: 0.88
# Recall:    0.75
# F1:        0.81
# FP ex.: ['פראפראז', 'קטמון', 'ירסקו', 'לינד', 'גאנט']
# FN ex.: ['מפם', 'טובייה', 'ורמונט', 'לאקספרס', 'מקארתור']
# ((('TM',), 1), 2)
# 62 mentions, 61 found, 57 correct.
# Precision: 0.93
# Recall:    0.92
# F1:        0.93
# FP ex.: ['ל אקספרס', 'מחוז זירונד', 'דה מוין', 'שרה סקאיף']
# FN ex.: ['טום דאיין', 'שרה סקאיף', 'דה מוין', 'מחוז זירונד', 'מכון הדסון']
# ((('TM',), 1), 3)
# 11 mentions, 12 found, 7 correct.
# Precision: 0.58
# Recall:    0.64
# F1:        0.61
# FP ex.: ['מנזר סן סימון', 'סמית - ריצרדסון', 'מכון ה דסון', 'אמריקן אקונומיק ריוויו', 'גנאדאס דל ואיה']
# FN ex.: ['גנאדאס דל ואיה', 'סמית - ריצרדסון', 'אמריקן אקונומיק ריוויו', 'מנזר סן סימון']
# ((('TM',), 1), 4)
# 3 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    0.67
# F1:        0.8
# FP ex.: []
# FN ex.: ['באב אל - ואד']
# ((('TM',), 1), 5)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['אייפא"ק טום דאיין את הארקין']
# FN ex.: []
# ((('TM',), 2), 1)
# 23 mentions, 20 found, 20 correct.
# Precision: 1.0
# Recall:    0.87
# F1:        0.93
# FP ex.: []
# FN ex.: ['קריסטול', 'ליון', 'אלוקים']
# ((('TM',), 2), 2)
# 13 mentions, 5 found, 4 correct.
# Precision: 0.8
# Recall:    0.31
# F1:        0.44
# FP ex.: ['הרי בראדלו']
# FN ex.: ['חברה קדישא', 'חברה קדישא', 'ה גסטאפו', 'ה פלמ"ח', 'קרן פורד']
# ((('TM',), 2), 3)
# 7 mentions, 5 found, 2 correct.
# Precision: 0.4
# Recall:    0.29
# F1:        0.33
# FP ex.: ['נווה - מונסון', 'קרן פורד שמרנים', 'קטיף ה הדרים']
# FN ex.: ['נווה - מונסון', 'מנזר סן סימון', 'מלאך ה מוות', 'תיאוריית ה יחסות', 'תיאוריית ה קוונטים']
# ((('TM',), 2), 4)
# 2 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['מענק " גאונות "', 'לינד ו הרי בראדלו']
# ((('TM',), 2), 6)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה שדולה ה פרו - ישראלית']
# ((('TM',), 2), 14)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה ברוקרים של ה רעיונות : צוותות חשיבה ו עלייתה של עלית מדיניות חדשה']
# ((('TM',), 3), 2)
# 0 mentions, 5 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['ה קטיף', 'ה קטיף', 'ה קטיף', 'ה קטיף', 'איסט סייד']
# FN ex.: []
# ((('TM',), 3), 4)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['איסט סייד ה תחתית']
# ((('TM',), 3), 6)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה קונסוליה ה ישראלית ב שיקאגו']

# %% [markdown]
# ## Check OOEV

# %%
full_samp['ooev'] = ~full_samp.form.isin(emb_words['tok'])
full_samp.ooev.value_counts()
# Out:
# False    11127
# True       174
# Name: ooev, dtype: int64

# %%
ooev_tok_part = (full_samp.groupby(['sent_id', 'token_id'])
                 .ooev.apply(lambda x: x.any())
                 .reset_index().rename(columns={'ooev': 'ooev_tok_part'}))
ooev_tok_part.ooev_tok_part.value_counts()
# Out:
# False    8357
# True      174
# Name: ooev_tok_part, dtype: int64

# %%
full_samp = full_samp.merge(ooev_tok_part, how='left')
dev_gold = dev_gold.merge(ooev_tok_part, how='left')
full_samp.shape, dev_gold.shape
# Out:
# ((11301, 22), (11301, 34))

# %%
token_unk_sents = full_samp.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'ooev_tok_part'])
token_unk_sents_fixed = get_sents_fixed(token_unk_sents)
ments = [sent_to_mentions_dict(sent, sent_id) for sent_id, sent in token_unk_sents_fixed]
ment_set = get_ment_set(ments)
ment_set.keys()
# Out:
# dict_keys([(False,), (False, True), (True,)])

# %%
gold_dev_sents = dev_gold.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'ooev_tok_part'])
gold_dev_sents_fixed = get_sents_fixed(gold_dev_sents)
gold_ments = [sent_to_mentions_dict(sent, sent_id) for sent_id, sent in gold_dev_sents_fixed]
gold_ment_set = get_ment_set(gold_ments)
gold_ment_set.keys()
# Out:
# dict_keys([(False,), (False, True), (True,)])

# %%
ment_set.keys() | gold_ment_set.keys()
# Out:
# {(False,), (False, True), (True,)}

# %%
for k in ment_set.keys() | gold_ment_set.keys():
    print(k)
    nem.evaluate_mentions(gold_ment_set[k], ment_set[k])
# Out:
# (False, True)
# 24 mentions, 24 found, 17 correct.
# Precision: 0.71
# Recall:    0.71
# F1:        0.71
# FP ex.: ['סמית - ריצרדסון', 'אייפא"ק טום דאיין את הארקין', 'אמריקן אקונומיק ריוויו', 'הרי בראדלו', 'מחוז זירונד']
# FN ex.: ['אמריקן אקונומיק ריוויו', 'לינד ו הרי בראדלו', 'שרה סקאיף', 'גנאדאס דל ואיה', 'סמית - ריצרדסון']
# (False,)
# 441 mentions, 389 found, 330 correct.
# Precision: 0.85
# Recall:    0.75
# F1:        0.8
# FP ex.: ['שלום ה רב כהנא', 'קרן גון', 'סן סימון', 'ל אקספרס', 'קטמון']
# FN ex.: ['ה ליגה ל זכויות ה אדם', 'טום דאיין', 'טובייה', 'ה ברוקרים של ה רעיונות : צוותות חשיבה ו עלייתה של עלית מדיניות חדשה', 'ה קרב על מנזר סן סימון']
# (True,)
# 34 mentions, 33 found, 24 correct.
# Precision: 0.73
# Recall:    0.71
# F1:        0.72
# FP ex.: ['מסצוסטס', 'גרוסבורד', 'פראפראז', 'מסצוסטס', 'מסצוסטס']
# FN ex.: ['מסצוסטס', 'נבראסקה', 'מסצוסטס', 'ה קב"ה', 'אייפא"ק']

# %% [markdown]
# ## OOEV + unk_type

# %%
token_unk_sents = full_samp.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type', 'ooev_tok_part'])
token_unk_sents_fixed = get_sents_fixed(token_unk_sents)
ments = [sent_to_mentions_dict(sent, sent_id, group_maker=gm) for sent_id, sent in token_unk_sents_fixed]
ment_set = get_ment_set(ments)
ment_set.keys()
# Out:
# dict_keys([(('T',), False), ((), False), (('TM',), False), (('T', 'TM'), False), (('TM',), True), ((), True), (('T',), True), (('T', 'TM'), True)])

# %%
gold_dev_sents = dev_gold.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type', 'ooev_tok_part'])
gold_dev_sents_fixed = get_sents_fixed(gold_dev_sents)
gold_ments = [sent_to_mentions_dict(sent, sent_id, group_maker=gm) for sent_id, sent in gold_dev_sents_fixed]
gold_ment_set = get_ment_set(gold_ments)
gold_ment_set.keys()
# Out:
# dict_keys([(('T',), False), ((), False), (('TM',), False), (('T', 'TM'), False), (('TM',), True), ((), True), (('T',), True), (('T', 'TM'), True)])

# %%
ment_set.keys() | gold_ment_set.keys()
# Out:
# {((), False),
#  ((), True),
#  (('T',), False),
#  (('T',), True),
#  (('T', 'TM'), False),
#  (('T', 'TM'), True),
#  (('TM',), False),
#  (('TM',), True)}

# %%
for k in ment_set.keys() | gold_ment_set.keys():
    print(k)
    nem.evaluate_mentions(gold_ment_set[k], ment_set[k])
# Out:
# (('TM',), False)
# 170 mentions, 146 found, 128 correct.
# Precision: 0.88
# Recall:    0.75
# F1:        0.81
# FP ex.: ['מנזר סן סימון', 'מכון ה דסון', 'נווה - מונסון', 'ל אקספרס', 'קטמון']
# FN ex.: ['חברה קדישא', 'נווה - מונסון', 'מפם', 'טום דאיין', 'ה שדולה ה פרו - ישראלית']
# (('T', 'TM'), True)
# 1 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# (('T', 'TM'), False)
# 5 mentions, 5 found, 2 correct.
# Precision: 0.4
# Recall:    0.4
# F1:        0.4
# FP ex.: ['שכונת קטמון', 'ארגון נפגעי ה משכנתאות', 'כביש באב אל - ואד']
# FN ex.: ['נאום אימפריית ה רשע', 'ארגון נפגעי ה משכנתאות ו חסרי ה דיור', 'ה קרב על מנזר סן סימון']
# (('T',), False)
# 43 mentions, 24 found, 22 correct.
# Precision: 0.92
# Recall:    0.51
# F1:        0.66
# FP ex.: ['ישיבת ה רעיון', 'ה ארה"ב']
# FN ex.: ['ארה"ב', 'תנועת ה מושבים', 'ה מצביע ה אמריקאי', 'ה קרב על סן סימון', 'תנועת ה מושבים']
# (('T',), True)
# 2 mentions, 2 found, 1 correct.
# Precision: 0.5
# Recall:    0.5
# F1:        0.5
# FP ex.: ['ה מסצוסטס']
# FN ex.: ['מסצוסטס']
# ((), False)
# 223 mentions, 214 found, 178 correct.
# Precision: 0.83
# Recall:    0.8
# F1:        0.81
# FP ex.: ['שלום ה רב כהנא', 'קרן גון', 'ה שטחים', 'ה שמרנים', 'סן סימון']
# FN ex.: ['ה ליגה ל זכויות ה אדם', 'פיו', 'ה התאחדות ל עולם טוב יותר', 'פיו', 'אושוויץ']
# ((), True)
# 21 mentions, 22 found, 16 correct.
# Precision: 0.73
# Recall:    0.76
# F1:        0.74
# FP ex.: ['מסצוסטס', 'גרוסבורד', 'מסצוסטס', 'מסצוסטס', 'שיקאגו']
# FN ex.: ['מסצוסטס', 'ה קב"ה', 'מסצוסטס', 'ה כנסת', 'מסצוסטס']
# (('TM',), True)
# 34 mentions, 32 found, 23 correct.
# Precision: 0.72
# Recall:    0.68
# F1:        0.7
# FP ex.: ['פראפראז', 'סמית - ריצרדסון', 'ירסקו', 'אייפא"ק טום דאיין את הארקין', 'אמריקן אקונומיק ריוויו']
# FN ex.: ['אמריקן אקונומיק ריוויו', 'לינד ו הרי בראדלו', 'נבראסקה', 'שרה סקאיף', 'אייפא"ק']

# %% [markdown]
# ## EVERYTHING :OOO

# %%
token_unk_sents = full_samp.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type', 'morpheme_count', 'ooev_tok_part'])
token_unk_sents_fixed = get_sents_fixed(token_unk_sents)
ments = [sent_to_mentions_dict(sent, sent_id, ment_len=True) for sent_id, sent in token_unk_sents_fixed]
ment_set = get_ment_set(ments)
ment_set.keys()
# Out:
# dict_keys([((('T', 2, False),), 1), ((('', 2, False),), 1), ((('', 2, False), ('', 3, False)), 6), ((('', 2, False),), 2), ((('', 1, False),), 2), ((('', 1, False),), 1), ((('', 1, False), ('', 2, False), ('', 3, False)), 6), ((('', 1, False), ('T', 1, False)), 2), ((('', 2, False), ('T', 2, False)), 3), ((('', 1, False), ('', 2, False)), 3), ((('', 1, False), ('T', 2, False)), 2), ((('', 2, False),), 4), ((('', 2, False), ('', 3, False)), 5), ((('', 1, False), ('TM', 1, False)), 2), ((('', 3, False),), 2), ((('T', 1, False), ('TM', 1, False)), 2), ((('TM', 1, False),), 1), ((('', 1, False), ('TM', 1, False)), 3), ((('', 1, False), ('TM', 1, False), ('TM', 2, False)), 3), ((('TM', 1, False),), 2), ((('', 1, False), ('T', 1, False), ('TM', 1, False)), 5), ((('', 1, False), ('', 2, False)), 5), ((('TM', 1, False), ('TM', 1, True)), 2), ((('', 1, False), ('T', 2, False), ('TM', 1, False)), 4), ((('', 2, False), ('', 3, False)), 4), ((('TM', 2, False),), 1), ((('TM', 1, False), ('TM', 2, False)), 2), ((('', 1, False), ('', 2, False)), 7), ((('', 1, False), ('TM', 1, False), ('TM', 1, True)), 5), ((('TM', 2, False),), 3), ((('TM', 3, False),), 2), ((('', 1, False), ('T', 2, False)), 3), ((('', 1, False), ('', 2, False)), 4), ((('', 1, False), ('', 1, True)), 2), ((('', 1, True),), 1), ((('T', 2, True),), 1), ((('', 2, False), ('T', 2, False)), 5), ((('', 2, True),), 1), ((('', 2, False),), 3), ((('', 1, False), ('TM', 1, False), ('TM', 1, True)), 3), ((('', 1, False), ('TM', 1, True)), 2), ((('', 1, False),), 3), ((('', 1, False), ('', 2, False)), 2), ((('T', 2, False), ('TM', 1, False)), 2), ((('', 1, False), ('', 2, False), ('T', 2, False)), 5), ((('TM', 2, True),), 1), ((('T', 3, False),), 1), ((('', 1, False), ('TM', 1, True)), 3), ((('', 2, False), ('TM', 1, False)), 2), ((('TM', 1, True),), 1), ((('', 1, False), ('TM', 1, False), ('TM', 1, True)), 4), ((('', 2, False), ('TM', 1, True)), 2), ((('T', 2, False), ('TM', 1, True)), 2), ((('', 1, False), ('', 2, False), ('TM', 1, False)), 3), ((('TM', 1, False), ('TM', 3, False)), 2), ((('T', 3, True),), 2), ((('TM', 1, False),), 3), ((('', 2, False), ('T', 1, False)), 3), ((('', 2, True),), 2), ((('', 2, False),), 5), ((('', 1, False),), 4), ((('T', 3, False),), 2), ((('', 1, False), ('TM', 2, False)), 3)])

# %%
gold_dev_sents = dev_gold.groupby('sent_id').apply(get_sent, ['form', 'biose_layer0', 'unk_type', 'morpheme_count', 'ooev_tok_part'])
gold_dev_sents_fixed = get_sents_fixed(gold_dev_sents)
gold_ments = [sent_to_mentions_dict(sent, sent_id, ment_len=True) for sent_id, sent in gold_dev_sents_fixed]
gold_ment_set = get_ment_set(gold_ments)
gold_ment_set.keys()
# Out:
# dict_keys([((('T', 2, False),), 1), ((('', 2, False),), 1), ((('', 2, False), ('', 3, False)), 6), ((('', 2, False),), 2), ((('', 1, False),), 2), ((('', 1, False),), 1), ((('', 1, False), ('', 2, False), ('', 3, False)), 6), ((('', 3, False), ('T', 3, False)), 5), ((('', 1, False), ('T', 2, False)), 3), ((('', 1, False), ('T', 1, False)), 2), ((('', 2, False), ('T', 2, False)), 3), ((('', 1, False), ('', 2, False)), 3), ((('', 1, False), ('T', 2, False)), 2), ((('', 2, False),), 4), ((('', 2, False), ('', 3, False)), 5), ((('', 1, False), ('TM', 1, False)), 2), ((('TM', 1, False),), 1), ((('', 3, False),), 2), ((('', 1, False), ('T', 2, False)), 5), ((('', 2, False),), 3), ((('', 1, False), ('', 3, False)), 4), ((('', 1, False), ('TM', 1, False)), 3), ((('', 1, False),), 4), ((('', 1, False), ('T', 3, False), ('TM', 1, False)), 6), ((('', 1, False), ('TM', 2, False)), 3), ((('TM', 2, False),), 2), ((('', 1, False), ('TM', 1, False), ('TM', 2, False)), 3), ((('TM', 1, False),), 2), ((('', 1, False), ('TM', 1, False)), 4), ((('', 1, False), ('', 2, False)), 5), ((('TM', 1, False), ('TM', 1, True)), 2), ((('', 1, False), ('', 2, False), ('T', 2, False), ('TM', 1, False)), 8), ((('', 2, False), ('', 3, False)), 4), ((('TM', 2, False),), 1), ((('', 1, False), ('', 2, False)), 2), ((('', 2, False), ('TM', 1, False)), 3), ((('TM', 1, False), ('TM', 2, False)), 2), ((('', 1, False), ('', 2, False)), 7), ((('', 2, False), ('T', 2, False)), 4), ((('', 1, False), ('', 2, False), ('TM', 2, False)), 6), ((('TM', 1, True),), 1), ((('', 1, False), ('', 2, False)), 4), ((('', 1, False), ('', 1, True)), 2), ((('', 1, True),), 1), ((('T', 2, True),), 1), ((('', 2, False), ('T', 2, False)), 5), ((('', 2, False), ('', 2, True), ('TM', 3, False)), 6), ((('', 2, True),), 1), ((('', 1, False), ('', 2, False), ('', 3, False)), 10), ((('', 1, False), ('TM', 1, False), ('TM', 2, False)), 4), ((('', 1, False), ('TM', 1, False), ('TM', 1, True)), 3), ((('', 2, False), ('TM', 1, False)), 2), ((('', 1, False), ('', 2, False)), 6), ((('', 1, False), ('TM', 1, True)), 2), ((('', 1, False),), 3), ((('', 1, False), ('', 2, False), ('T', 1, False)), 4), ((('T', 2, False), ('TM', 1, False)), 2), ((('', 1, False), ('', 2, False), ('T', 2, False)), 5), ((('TM', 2, True),), 1), ((('T', 3, False),), 1), ((('', 1, False), ('TM', 1, True)), 3), ((('', 1, False), ('TM', 1, False), ('TM', 1, True)), 4), ((('', 2, False), ('TM', 1, False), ('TM', 1, True)), 4), ((('T', 2, False), ('TM', 1, True)), 2), ((('TM', 1, False), ('TM', 2, False)), 3), ((('TM', 2, False),), 3), ((('', 2, False), ('TM', 1, False), ('TM', 3, False)), 4), ((('', 1, False), ('T', 2, False), ('TM', 2, False)), 4), ((('T', 2, False), ('T', 3, False)), 4), ((('', 1, False), ('', 2, False), ('TM', 1, False), ('TM', 2, False)), 14), ((('', 3, False), ('T', 2, False)), 4), ((('T', 3, True),), 1), ((('TM', 1, False),), 3), ((('', 2, False),), 6), ((('', 2, False), ('T', 1, False)), 5), ((('', 2, True),), 2), ((('', 2, False),), 5), ((('', 3, True),), 2)])

# %%
ment_set.keys() | gold_ment_set.keys()
# Out:
# {((('', 1, False),), 1),
#  ((('', 1, False),), 2),
#  ((('', 1, False),), 3),
#  ((('', 1, False),), 4),
#  ((('', 1, False), ('', 1, True)), 2),
#  ((('', 1, False), ('', 2, False)), 2),
#  ((('', 1, False), ('', 2, False)), 3),
#  ((('', 1, False), ('', 2, False)), 4),
#  ((('', 1, False), ('', 2, False)), 5),
#  ((('', 1, False), ('', 2, False)), 6),
#  ((('', 1, False), ('', 2, False)), 7),
#  ((('', 1, False), ('', 2, False), ('', 3, False)), 6),
#  ((('', 1, False), ('', 2, False), ('', 3, False)), 10),
#  ((('', 1, False), ('', 2, False), ('T', 1, False)), 4),
#  ((('', 1, False), ('', 2, False), ('T', 2, False)), 5),
#  ((('', 1, False), ('', 2, False), ('T', 2, False), ('TM', 1, False)), 8),
#  ((('', 1, False), ('', 2, False), ('TM', 1, False)), 3),
#  ((('', 1, False), ('', 2, False), ('TM', 1, False), ('TM', 2, False)), 14),
#  ((('', 1, False), ('', 2, False), ('TM', 2, False)), 6),
#  ((('', 1, False), ('', 3, False)), 4),
#  ((('', 1, False), ('T', 1, False)), 2),
#  ((('', 1, False), ('T', 1, False), ('TM', 1, False)), 5),
#  ((('', 1, False), ('T', 2, False)), 2),
#  ((('', 1, False), ('T', 2, False)), 3),
#  ((('', 1, False), ('T', 2, False)), 5),
#  ((('', 1, False), ('T', 2, False), ('TM', 1, False)), 4),
#  ((('', 1, False), ('T', 2, False), ('TM', 2, False)), 4),
#  ((('', 1, False), ('T', 3, False), ('TM', 1, False)), 6),
#  ((('', 1, False), ('TM', 1, False)), 2),
#  ((('', 1, False), ('TM', 1, False)), 3),
#  ((('', 1, False), ('TM', 1, False)), 4),
#  ((('', 1, False), ('TM', 1, False), ('TM', 1, True)), 3),
#  ((('', 1, False), ('TM', 1, False), ('TM', 1, True)), 4),
#  ((('', 1, False), ('TM', 1, False), ('TM', 1, True)), 5),
#  ((('', 1, False), ('TM', 1, False), ('TM', 2, False)), 3),
#  ((('', 1, False), ('TM', 1, False), ('TM', 2, False)), 4),
#  ((('', 1, False), ('TM', 1, True)), 2),
#  ((('', 1, False), ('TM', 1, True)), 3),
#  ((('', 1, False), ('TM', 2, False)), 3),
#  ((('', 1, True),), 1),
#  ((('', 2, False),), 1),
#  ((('', 2, False),), 2),
#  ((('', 2, False),), 3),
#  ((('', 2, False),), 4),
#  ((('', 2, False),), 5),
#  ((('', 2, False),), 6),
#  ((('', 2, False), ('', 2, True), ('TM', 3, False)), 6),
#  ((('', 2, False), ('', 3, False)), 4),
#  ((('', 2, False), ('', 3, False)), 5),
#  ((('', 2, False), ('', 3, False)), 6),
#  ((('', 2, False), ('T', 1, False)), 3),
#  ((('', 2, False), ('T', 1, False)), 5),
#  ((('', 2, False), ('T', 2, False)), 3),
#  ((('', 2, False), ('T', 2, False)), 4),
#  ((('', 2, False), ('T', 2, False)), 5),
#  ((('', 2, False), ('TM', 1, False)), 2),
#  ((('', 2, False), ('TM', 1, False)), 3),
#  ((('', 2, False), ('TM', 1, False), ('TM', 1, True)), 4),
#  ((('', 2, False), ('TM', 1, False), ('TM', 3, False)), 4),
#  ((('', 2, False), ('TM', 1, True)), 2),
#  ((('', 2, True),), 1),
#  ((('', 2, True),), 2),
#  ((('', 3, False),), 2),
#  ((('', 3, False), ('T', 2, False)), 4),
#  ((('', 3, False), ('T', 3, False)), 5),
#  ((('', 3, True),), 2),
#  ((('T', 1, False), ('TM', 1, False)), 2),
#  ((('T', 2, False),), 1),
#  ((('T', 2, False), ('T', 3, False)), 4),
#  ((('T', 2, False), ('TM', 1, False)), 2),
#  ((('T', 2, False), ('TM', 1, True)), 2),
#  ((('T', 2, True),), 1),
#  ((('T', 3, False),), 1),
#  ((('T', 3, False),), 2),
#  ((('T', 3, True),), 1),
#  ((('T', 3, True),), 2),
#  ((('TM', 1, False),), 1),
#  ((('TM', 1, False),), 2),
#  ((('TM', 1, False),), 3),
#  ((('TM', 1, False), ('TM', 1, True)), 2),
#  ((('TM', 1, False), ('TM', 2, False)), 2),
#  ((('TM', 1, False), ('TM', 2, False)), 3),
#  ((('TM', 1, False), ('TM', 3, False)), 2),
#  ((('TM', 1, True),), 1),
#  ((('TM', 2, False),), 1),
#  ((('TM', 2, False),), 2),
#  ((('TM', 2, False),), 3),
#  ((('TM', 2, True),), 1),
#  ((('TM', 3, False),), 2)}

# %%
for k in ment_set.keys() | gold_ment_set.keys():
    print(k)
    nem.evaluate_mentions(gold_ment_set[k], ment_set[k])
# Out:
# ((('', 2, False),), 4)
# 12 mentions, 12 found, 11 correct.
# Precision: 0.92
# Recall:    0.92
# F1:        0.92
# FP ex.: ['ה מלחמת ה עצמאות']
# FN ex.: ['ה עולם ה שלישי']
# ((('', 1, False), ('TM', 1, False)), 4)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['באב אל - ואד']
# ((('', 1, False),), 2)
# 34 mentions, 37 found, 31 correct.
# Precision: 0.84
# Recall:    0.91
# F1:        0.87
# FP ex.: ['מחוז פאריס', 'קרן גון', 'סן סימון', 'נא מילוא', 'שלום עכשיו']
# FN ex.: ['מחוז פאריס', 'בית נבחרים', 'סנטר 1']
# ((('', 1, False), ('', 2, False)), 4)
# 7 mentions, 7 found, 4 correct.
# Precision: 0.57
# Recall:    0.57
# F1:        0.57
# FP ex.: ['הר - ה בית', 'שכונת שמואל ה נביא', 'שלום ה רב כהנא']
# FN ex.: ['הר - ה בית', 'שכונת שמואל ה נביא', 'פרס נובל ל שלום']
# ((('', 1, False), ('', 2, False), ('', 3, False)), 10)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['מרכז ה מידע ל זכויות ה אדם ב ה שטחים']
# ((('T', 2, False), ('TM', 1, True)), 2)
# 1 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 2, False),), 1)
# 36 mentions, 38 found, 35 correct.
# Precision: 0.92
# Recall:    0.97
# F1:        0.95
# FP ex.: ['ירושלים', 'אושוויץ', 'מקורות']
# FN ex.: ['אושוויץ']
# ((('TM', 3, False),), 2)
# 0 mentions, 4 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['ה קטיף', 'ה קטיף', 'ה קטיף', 'ה קטיף']
# FN ex.: []
# ((('T', 3, False),), 2)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['ה ארה"ב']
# FN ex.: []
# ((('TM', 1, False), ('TM', 3, False)), 2)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['איסט סייד']
# FN ex.: []
# ((('', 2, True),), 2)
# 1 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    0.0
# F1:        -1
# FP ex.: ['ה קב"ה']
# FN ex.: ['ה קב"ה']
# ((('', 2, False), ('', 3, False)), 4)
# 7 mentions, 6 found, 6 correct.
# Precision: 1.0
# Recall:    0.86
# F1:        0.92
# FP ex.: []
# FN ex.: ['ה עולם ה שלישי']
# ((('', 2, False),), 2)
# 12 mentions, 12 found, 5 correct.
# Precision: 0.42
# Recall:    0.42
# F1:        0.42
# FP ex.: ['ה שמרנים', 'ה ארץ', 'ה שמרנים', 'ה ארץ', 'ה תורה']
# FN ex.: ['ה גרמנים', 'ה מלחמה', 'ה משטרה', 'ה פנים', 'ה ארץ']
# ((('TM', 1, False),), 3)
# 2 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 2, False), ('T', 2, False)), 5)
# 1 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('T', 3, False),), 1)
# 3 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    0.67
# F1:        0.8
# FP ex.: []
# FN ex.: ['ארה"ב']
# ((('', 2, False), ('TM', 1, True)), 2)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['הרי בראדלו']
# FN ex.: []
# ((('', 1, False), ('TM', 2, False)), 3)
# 2 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    0.5
# F1:        0.67
# FP ex.: []
# FN ex.: ['מנזר סן סימון']
# ((('T', 2, False),), 1)
# 11 mentions, 9 found, 9 correct.
# Precision: 1.0
# Recall:    0.82
# F1:        0.9
# FP ex.: []
# FN ex.: ['קדיש', 'לין']
# ((('TM', 2, True),), 1)
# 2 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    0.5
# F1:        0.67
# FP ex.: []
# FN ex.: ['קריסטול']
# ((('', 2, False), ('TM', 1, False), ('TM', 3, False)), 4)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['איסט סייד ה תחתית']
# ((('', 1, False), ('', 2, False)), 2)
# 6 mentions, 4 found, 4 correct.
# Precision: 1.0
# Recall:    0.67
# F1:        0.8
# FP ex.: []
# FN ex.: ['מלחמת וייטנאם', 'ניו גרסי']
# ((('', 1, False), ('T', 2, False), ('TM', 1, False)), 4)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['ארגון נפגעי ה משכנתאות']
# FN ex.: []
# ((('TM', 1, False), ('TM', 2, False)), 3)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['תיאוריית ה קוונטים']
# ((('', 1, False), ('TM', 1, False), ('TM', 1, True)), 5)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['אייפא"ק טום דאיין את הארקין']
# FN ex.: []
# ((('', 1, False), ('TM', 1, True)), 3)
# 2 mentions, 2 found, 1 correct.
# Precision: 0.5
# Recall:    0.5
# F1:        0.5
# FP ex.: ['אמריקן אקונומיק ריוויו']
# FN ex.: ['אמריקן אקונומיק ריוויו']
# ((('TM', 2, False),), 1)
# 21 mentions, 19 found, 19 correct.
# Precision: 1.0
# Recall:    0.9
# F1:        0.95
# FP ex.: []
# FN ex.: ['ליון', 'אלוקים']
# ((('', 1, False), ('T', 2, False)), 5)
# 2 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה קרב על סן סימון', 'ה קרב על סן סימון']
# ((('', 1, False), ('T', 1, False), ('TM', 1, False)), 5)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['כביש באב אל - ואד']
# FN ex.: []
# ((('', 2, False),), 5)
# 1 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    0.0
# F1:        -1
# FP ex.: ['ישיבת ה רעיון ה יהודי']
# FN ex.: ['ישיבת ה רעיון ה יהודי']
# ((('', 1, False), ('', 3, False)), 4)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה קרב על ירושלים']
# ((('', 2, False), ('T', 2, False)), 3)
# 3 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    0.67
# F1:        0.8
# FP ex.: []
# FN ex.: ['תנועת ה מושבים']
# ((('', 1, False), ('TM', 1, False), ('TM', 2, False)), 3)
# 2 mentions, 2 found, 1 correct.
# Precision: 0.5
# Recall:    0.5
# F1:        0.5
# FP ex.: ['נווה - מונסון']
# FN ex.: ['נווה - מונסון']
# ((('TM', 1, True),), 1)
# 14 mentions, 13 found, 11 correct.
# Precision: 0.85
# Recall:    0.79
# F1:        0.81
# FP ex.: ['פראפראז', 'ירסקו']
# FN ex.: ['אייפא"ק', 'פראפראז', 'נבראסקה']
# ((('', 1, False),), 1)
# 60 mentions, 54 found, 46 correct.
# Precision: 0.85
# Recall:    0.77
# F1:        0.81
# FP ex.: ['הראל', 'ירושלים', 'יונה', 'גורג', 'גרסי']
# FN ex.: ['ה', 'כך', 'וייטנאם', 'פיו', 'גורג']
# ((('', 1, False), ('', 2, False)), 5)
# 4 mentions, 4 found, 4 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 1, False), ('', 2, False), ('TM', 1, False)), 3)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['קרן פורד שמרנים']
# FN ex.: []
# ((('', 1, False), ('', 2, False), ('', 3, False)), 6)
# 1 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 2, False),), 6)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה ליגה ל זכויות ה אדם']
# ((('', 1, False), ('TM', 1, False), ('TM', 1, True)), 3)
# 2 mentions, 2 found, 0 correct.
# Precision: 0.0
# Recall:    0.0
# F1:        -1
# FP ex.: ['גנאדאס דל ואיה', 'סמית - ריצרדסון']
# FN ex.: ['גנאדאס דל ואיה', 'סמית - ריצרדסון']
# ((('', 1, False), ('T', 2, False), ('TM', 2, False)), 4)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['נאום אימפריית ה רשע']
# ((('', 1, False), ('T', 1, False)), 2)
# 2 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 2, True),), 1)
# 1 mentions, 2 found, 1 correct.
# Precision: 0.5
# Recall:    1.0
# F1:        0.67
# FP ex.: ['שיקאגו']
# FN ex.: []
# ((('', 1, False), ('', 2, False)), 6)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה התאחדות ל עולם טוב יותר']
# ((('', 2, False), ('', 3, False)), 5)
# 1 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 3, False), ('T', 2, False)), 4)
# 3 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה בית ה לבן', 'ה בית ה לבן', 'ה מלחמה ה קרה']
# ((('', 2, False),), 3)
# 5 mentions, 4 found, 3 correct.
# Precision: 0.75
# Recall:    0.6
# F1:        0.67
# FP ex.: ['מדינות ה ברית']
# FN ex.: ['ירושלים ה מערבית', 'מלחמת ה עצמאות']
# ((('', 2, False), ('TM', 1, False), ('TM', 1, True)), 4)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['לינד ו הרי בראדלו']
# ((('', 2, False), ('T', 2, False)), 4)
# 4 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה בית ה לבן', 'ה מלחמה ה קרה', 'ה בית ה לבן', 'ה מצביע ה אמריקאי']
# ((('TM', 1, False), ('TM', 1, True)), 2)
# 4 mentions, 4 found, 4 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 1, True),), 1)
# 13 mentions, 14 found, 10 correct.
# Precision: 0.71
# Recall:    0.77
# F1:        0.74
# FP ex.: ['מסצוסטס', 'גרוסבורד', 'מסצוסטס', 'מסצוסטס']
# FN ex.: ['מסצוסטס', 'מסצוסטס', 'מסצוסטס']
# ((('', 1, False), ('', 2, False)), 3)
# 14 mentions, 16 found, 12 correct.
# Precision: 0.75
# Recall:    0.86
# F1:        0.8
# FP ex.: ['רחוב גבעת שאול', 'גורג ה מסכן', 'רצח ה נזירות', 'ה שירות פועל']
# FN ex.: ['רחוב גבעת שאול', 'ניו - יורק']
# ((('', 2, False), ('', 3, False)), 6)
# 2 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 1, False), ('', 2, False), ('T', 2, False)), 5)
# 1 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 1, False), ('TM', 1, True)), 2)
# 6 mentions, 6 found, 4 correct.
# Precision: 0.67
# Recall:    0.67
# F1:        0.67
# FP ex.: ['מחוז זירונד', 'שרה סקאיף']
# FN ex.: ['שרה סקאיף', 'מחוז זירונד']
# ((('', 2, False), ('TM', 1, False)), 3)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['מלאך ה מוות']
# ((('', 1, False), ('T', 2, False)), 2)
# 5 mentions, 4 found, 4 correct.
# Precision: 1.0
# Recall:    0.8
# F1:        0.89
# FP ex.: []
# FN ex.: ['עין כרם']
# ((('T', 1, False), ('TM', 1, False)), 2)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['שכונת קטמון']
# FN ex.: []
# ((('T', 3, True),), 1)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['מסצוסטס']
# ((('', 1, False), ('', 1, True)), 2)
# 5 mentions, 5 found, 5 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('T', 2, False), ('TM', 1, False)), 2)
# 2 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 1, False), ('TM', 1, False)), 2)
# 34 mentions, 33 found, 32 correct.
# Precision: 0.97
# Recall:    0.94
# F1:        0.96
# FP ex.: ['דה מוין']
# FN ex.: ['דה מוין', 'מכון הדסון']
# ((('TM', 2, False),), 3)
# 1 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    0.0
# F1:        -1
# FP ex.: ['קטיף ה הדרים']
# FN ex.: ['תיאוריית ה יחסות']
# ((('', 1, False), ('', 2, False), ('T', 2, False), ('TM', 1, False)), 8)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ארגון נפגעי ה משכנתאות ו חסרי ה דיור']
# ((('', 1, False), ('', 2, False), ('TM', 1, False), ('TM', 2, False)), 14)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה ברוקרים של ה רעיונות : צוותות חשיבה ו עלייתה של עלית מדיניות חדשה']
# ((('', 2, False), ('', 2, True), ('TM', 3, False)), 6)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה קונסוליה ה ישראלית ב שיקאגו']
# ((('', 1, False), ('T', 3, False), ('TM', 1, False)), 6)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה קרב על מנזר סן סימון']
# ((('', 1, False),), 3)
# 4 mentions, 3 found, 3 correct.
# Precision: 1.0
# Recall:    0.75
# F1:        0.86
# FP ex.: []
# FN ex.: ['בית מספר 3']
# ((('', 1, False), ('', 2, False)), 7)
# 1 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 2, False), ('T', 1, False)), 3)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['ישיבת ה רעיון']
# FN ex.: []
# ((('T', 2, True),), 1)
# 1 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 3, False),), 2)
# 10 mentions, 10 found, 8 correct.
# Precision: 0.8
# Recall:    0.8
# F1:        0.8
# FP ex.: ['ה שטחים', 'ה ארץ']
# FN ex.: ['ה ארץ', 'ה ארץ']
# ((('TM', 1, False),), 1)
# 65 mentions, 54 found, 48 correct.
# Precision: 0.89
# Recall:    0.74
# F1:        0.81
# FP ex.: ['קטמון', 'לינד', 'גאנט', 'אולין', 'קטמון']
# FN ex.: ['רוקפלר', 'הארקין', 'מפם', 'טוקי', 'סילבר']
# ((('T', 2, False), ('T', 3, False)), 4)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה מלחמה ה קרה']
# ((('', 3, False), ('T', 3, False)), 5)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה עבודה ו ה רווחה']
# ((('', 1, False), ('', 2, False), ('TM', 2, False)), 6)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה שדולה ה פרו - ישראלית']
# ((('TM', 1, False),), 2)
# 18 mentions, 18 found, 17 correct.
# Precision: 0.94
# Recall:    0.94
# F1:        0.94
# FP ex.: ['ל אקספרס']
# FN ex.: ['טום דאיין']
# ((('', 2, False), ('TM', 1, False)), 2)
# 7 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    0.14
# F1:        0.25
# FP ex.: []
# FN ex.: ['חברה קדישא', 'חברה קדישא', 'קרן פורד', 'חברה קדישא', 'לוס אוחוס']
# ((('', 1, False), ('TM', 1, False), ('TM', 2, False)), 4)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['מענק " גאונות "']
# ((('', 1, False), ('T', 2, False)), 3)
# 4 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    0.25
# F1:        0.4
# FP ex.: []
# FN ex.: ['תנועת ה מושבים', 'תנועת ה מושבים', 'תנועת ה מושבים']
# ((('', 1, False),), 4)
# 2 mentions, 1 found, 1 correct.
# Precision: 1.0
# Recall:    0.5
# F1:        0.67
# FP ex.: []
# FN ex.: ['חטיבת " הראל "']
# ((('', 2, False), ('T', 1, False)), 5)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ישיבת ה רעיון ה יהודי']
# ((('T', 3, True),), 2)
# 0 mentions, 1 found, 0 correct.
# Precision: 0.0
# Recall:    -1
# F1:        0.0
# FP ex.: ['ה מסצוסטס']
# FN ex.: []
# ((('TM', 1, False), ('TM', 2, False)), 2)
# 3 mentions, 3 found, 3 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 1, False), ('', 2, False), ('T', 1, False)), 4)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['צדקה מתחילה מ בית']
# ((('', 3, True),), 2)
# 1 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה כנסת']
# ((('', 1, False), ('TM', 1, False), ('TM', 1, True)), 4)
# 2 mentions, 2 found, 2 correct.
# Precision: 1.0
# Recall:    1.0
# F1:        1.0
# FP ex.: []
# FN ex.: []
# ((('', 1, False), ('TM', 1, False)), 3)
# 5 mentions, 6 found, 4 correct.
# Precision: 0.67
# Recall:    0.8
# F1:        0.73
# FP ex.: ['מנזר סן סימון', 'מכון ה דסון']
# FN ex.: ['מנזר סן סימון']
# ((('TM', 2, False),), 2)
# 3 mentions, 0 found, 0 correct.
# Precision: -1
# Recall:    0.0
# F1:        0.0
# FP ex.: []
# FN ex.: ['ה פלמ"ח', 'ה גסטאפו', 'ה גסטאפו']

# %% [markdown]
# ## Evaluate all

# %%
mev = pd.read_pickle('final_setup/mev2.pkl')
mev.head()
# Out:
#          gold_name   unit      arch     w_embed seed_num       p_m       r_m  \
# 0   morph_dev_gold  morph  char_cnn      ft_yap  44_seed  0.859155  0.733467
# 1    morph_dev_yap  morph  char_cnn      ft_yap  44_seed  0.780193  0.647295
# 2  morph_test_gold  morph  char_cnn      ft_yap  44_seed  0.804850  0.747854
# 3   morph_dev_gold  morph  char_cnn  ft_oov_tok  44_seed  0.843612  0.767535
# 4   morph_test_yap  morph  char_cnn      ft_yap  44_seed  0.721411  0.636266
#
#         f_m   pred_set     acc  ...  seg  \
# 0  0.791351   dev_gold  0.9667  ...  NaN
# 1  0.707558    dev_yap  0.9667  ...  NaN
# 2  0.775306  test_gold  0.9667  ...  NaN
# 3  0.803778   dev_gold  0.9690  ...  NaN
# 4  0.676169   test_yap  0.9667  ...  NaN
#
#                                model_file_name  \
# 0       morph.char_cnn.ft_yap.44_seed.83.model
# 1       morph.char_cnn.ft_yap.44_seed.83.model
# 2       morph.char_cnn.ft_yap.44_seed.83.model
# 3  morph.char_cnn.ft_oov_tok.44_seed.183.model
# 4       morph.char_cnn.ft_yap.44_seed.83.model
#
#                            dset_file_name relevant_score input_unit  \
# 0      morph.char_cnn.ft_yap.44_seed.dset         0.7905      morph
# 1      morph.char_cnn.ft_yap.44_seed.dset         0.7905      morph
# 2      morph.char_cnn.ft_yap.44_seed.dset         0.7905      morph
# 3  morph.char_cnn.ft_oov_tok.44_seed.dset         0.8038      morph
# 4      morph.char_cnn.ft_yap.44_seed.dset         0.7905      morph
#
#   embed_unit embed_type     cm pred_set_sub pred_set_main
# 0      morph         ft  Match         gold           dev
# 1      morph         ft  Match          yap           dev
# 2      morph         ft  Match         gold          test
# 3      token     ft_oov  Clash         gold           dev
# 4      morph         ft  Match          yap          test
#
# [5 rows x 56 columns]

# %%
dev_gold = spdf[spdf.set=='dev']
dev_gold = dev_gold.merge(dev_unk, how='left')
test_gold = spdf[spdf.set=='test']
test_gold = test_gold.merge(test_unk, how='left')
test_sent_id_map = (test_gold.groupby('sent_id').size()
                    .reset_index().drop(0, axis=1).reset_index()
                    .assign(index=lambda x: x+1).set_index('sent_id')['index'])

test_gold['sent_id'] = test_gold.sent_id.map(test_sent_id_map)
test_unk['sent_id'] = test_unk.sent_id.map(test_sent_id_map)
test_gold.tail()
# Out:
#        id   form  lemma upostag xpostag        feats  token_id  sent_id  \
# 16823   5     אך     אך      CC      CC            _         4      706
# 16824   6     לא     לא      RB      RB            _         5      706
# 16825   7      ה      ה     DEF     DEF            _         6      706
# 16826   8  תרופה  תרופה      NN      NN  gen=F|num=S         6      706
# 16827   9      .      _   yyDOT   yyDOT            _         7      706
#
#       token_str  global_sent_id  ...  biose_layer1 biose_layer2 biose_layer3  \
# 16823        אך            6153  ...             O            O            O
# 16824        לא            6153  ...             O            O            O
# 16825    התרופה            6153  ...             O            O            O
# 16826    התרופה            6153  ...             O            O            O
# 16827         .            6153  ...             O            O            O
#
#        token_unk morph_unk  lemma_unk unk_type has_ner morpheme_count  \
# 16823      False     False      False            False              1
# 16824      False     False      False            False              1
# 16825      False     False      False            False              2
# 16826      False     False      False            False              2
# 16827      False     False      False            False              1
#
#       token_id_rep
# 16823            4
# 16824            5
# 16825            6
# 16826            6
# 16827            7
#
# [5 rows x 34 columns]

# %%
test_unk.tail()
# Out:
#        sent_id  token_id token_str  token_unk  morph_unk  lemma_unk unk_type  \
# 12614      706         3      טובה      False      False      False
# 12615      706         4        אך      False      False      False
# 12616      706         5        לא      False      False      False
# 12617      706         6    התרופה      False      False      False
# 12618      706         7         .      False      False      False
#
#        has_ner  morpheme_count  token_id_rep
# 12614    False               1             3
# 12615    False               1             4
# 12616    False               1             5
# 12617    False               2             6
# 12618    False               1             7

# %%
dev_gold['ooev_tok'] = ~dev_gold.form.isin(emb_words['tok'])
dev_gold['ooev_yap'] = ~dev_gold.form.isin(emb_words['yap'])

test_gold['ooev_tok'] = ~test_gold.form.isin(emb_words['tok'])
test_gold['ooev_yap'] = ~test_gold.form.isin(emb_words['yap'])

# %%
dev_gold['ooev_word'] = True
test_gold['ooev_word'] = True

# %%
def get_df_from_sents(sents):
    for_df = []
    for i, line in sents.iteritems():
        sent_id=i+1
        for j, (tok, bio) in enumerate(line):
            for_df.append((sent_id, j+1, bio))
    df = pd.DataFrame(for_df, columns=['sent_id', 'id', 'biose_layer0'])
    return df

# %%
yap_output_folder = 'final_setup/pruned/yap_output'

txt_map = defaultdict(dict)

for file in os.scandir(yap_output_folder):
    if file.name in ('.ipynb_checkpoints', '.conll', '.seg', '.map'):
        continue
    ds, unit, arch, w_embed, seed_num, output_type = file.name.split('.')
    if '_tok' in w_embed:
        w_embed = w_embed.replace('_tok', '_yap')
    else:
        w_embed = w_embed.replace('_yap', '_tok')
    txt_map[(ds, arch, w_embed, output_type)] = file.path

# %%
from functools import lru_cache

@lru_cache(32)
def get_matching_yap_out(ds_sub, ds, arch, w_embed):
    if ds_sub=='yap':
        yap_out = bclm.read_yap_output(treebank_set=ds)
    if ds_sub=='pruned':
        yap_out = bclm.read_yap_output(treebank_set=None,
                                       tokens_path=bclm.TREEBANK_TOKEN_PATHS[ds], 
                                        dep_path=txt_map[(ds, arch, w_embed, 'conll')],
                                        map_path=txt_map[(ds, arch, w_embed, 'map')],)
    return yap_out

# %%
gold_dfs = {'dev': dev_gold, 'test': test_gold}

# %%
unks = {'dev': dev_unk, 'test': test_unk}

# %%
emb_words['word'] = []

# %%
scores2 = pickle.load(open('final_setup/oov_scores.pkl', 'rb'))

# %%
new_scores2 = {}
for sc_id in scores2:
    if not 'test' in sc_id[0]:
        new_scores2[sc_id] = scores2[sc_id]

# %%
scores2 = new_scores2

# %% [raw]
# output_folder = 'final_setup/decode_output'
# cols = ['form', 'biose_layer0', 'unk_type', 'morpheme_count', 'ooev_tok_part']
#
# for file in os.scandir(output_folder):
#     if file.name=='.ipynb_checkpoints':
#         continue
#
#     sc_id = tuple(file.name.split('.')[:-1])
#     gold_name, inp, arch, w_embed, seed_num = sc_id
#     emb_unit = w_embed.split('_')[-1]
#
#     if sc_id not in scores:
#         print(file.path)
#         scores[sc_id] = {}
#         ner_df = get_df_from_sents(nem.read_file_sents(file.path))
#
#         if len(gold_name.split('_'))>2:
#             unit, pred_set, ps_sub = gold_name.split('_')
#
#             if ps_sub in ('pruned', 'yap'):
#                 yap_out = get_matching_yap_out(ps_sub, pred_set, arch, w_embed)
#                 yap_out['ooev'] = ~yap_out.form.isin(emb_words[emb_unit])
#                 full_df = yap_out.merge(ner_df)
#
#             elif ps_sub == 'gold':
#                 full_df = gold_dfs[pred_set].copy()
#                 full_df['biose_layer0'] = ner_df.biose_layer0
#                 full_df['ooev'] = full_df['ooev_'+emb_unit]
#
#             full_df = full_df.merge(unks[pred_set], how='left')
#             ooev_tok_part = (full_df.groupby(['sent_id', 'token_id'])
#                              .ooev.apply(lambda x: x.any())
#                              .reset_index().rename(columns={'ooev': 'ooev_tok_part'}))
#
#             full_df = full_df.merge(ooev_tok_part, how='left')
#             gold_ooev = gold_dfs[pred_set].merge(ooev_tok_part, how='left')
#             token_unk_sents = full_df.groupby('sent_id').apply(get_sent, cols)
#             token_unk_sents_fixed = get_sents_fixed(token_unk_sents)
#             ments = [sent_to_mentions_dict(sent, sent_id, ment_len=True)
#                      for sent_id, sent
#                      in token_unk_sents_fixed]
#             ment_set = get_ment_set(ments)
#             gold_sents = gold_ooev.groupby('sent_id').apply(get_sent, cols)
#             gold_sents_fixed = get_sents_fixed(gold_sents)
#             gold_ments = [sent_to_mentions_dict(sent, sent_id, ment_len=True)
#                           for sent_id, sent
#                           in gold_sents_fixed]
#             gold_ment_set = get_ment_set(gold_ments)
#             for k in ment_set.keys() | gold_ment_set.keys():
#                 scores[sc_id][k] = nem.evaluate_mentions(gold_ment_set[k],
#                                                         ment_set[k],
#                                                         verbose=False,
#                                                         return_tpc=True)
#
#         else:
#             unit, pred_set = gold_name.split('_')
#             #print ('token')
#         #p, r, f = nem.evaluate_files(gold_path, file)
#         #scores[(gold_name, inp, arch, w_embed, seed_num)] = (p, r, f)

# %% [markdown]
# ## TOKEN

# %%
tok_dev_gold = (bclm
                .get_token_df(spdf[spdf.set=='dev'], biose=['biose_layer0'], add_set=False))
tok_dev_gold = tok_dev_gold.merge(dev_unk, how='left')
tok_test_gold = bclm.get_token_df(spdf[spdf.set=='test'], biose=['biose_layer0'], add_set=False)
tok_test_gold['sent_id'] = tok_test_gold.sent_id.map(test_sent_id_map)
tok_test_gold = tok_test_gold.merge(test_unk, how='left')
# Out:
# /home/nlp/danb/anaconda3/envs/tf/lib/python3.7/site-packages/pandas/core/frame.py:3509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
tok_dev_gold['ooev_tok'] = ~tok_dev_gold.token_str.isin(emb_words['tok'])
tok_dev_gold['ooev_yap'] = ~tok_dev_gold.token_str.isin(emb_words['yap'])

tok_test_gold['ooev_tok'] = ~tok_test_gold.token_str.isin(emb_words['tok'])
tok_test_gold['ooev_yap'] = ~tok_test_gold.token_str.isin(emb_words['yap'])

# %%
tok_dev_gold['ooev_word'] = True
tok_test_gold['ooev_word'] = True

# %%
tok_gold_dfs = {'dev': tok_dev_gold, 'test': tok_test_gold}

# %%
tok_cols = ['token_str', 'biose_layer0', 'unk_type', 'morpheme_count', 'ooev', 'token_id_rep']

tok_gold_ment_sets = {}
for pred_set, df in tok_gold_dfs.items():
    for emb_unit in ('tok', 'yap', 'word'):
        tok_gold_dfs[pred_set]['ooev'] = tok_gold_dfs[pred_set]['ooev_'+emb_unit]
        gold_sents = tok_gold_dfs[pred_set].groupby('sent_id').apply(get_sent, tok_cols)
        gold_sents_fixed = get_sents_fixed(gold_sents)
        tok_gold_ments = [sent_to_mentions_dict(sent, sent_id, ment_len=True, ment_cat=True) 
                      for sent_id, sent 
                      in gold_sents_fixed]
        gold_ment_set = get_ment_set(tok_gold_ments)
        tok_gold_ment_sets[(pred_set, emb_unit)] = gold_ment_set

# %%
scores5 = {}

# %%
output_folder = 'final_setup/decode_output'
cols = ['form', 'biose_layer0', 'unk_type', 'morpheme_count', 'ooev_tok_part', 'token_id_rep']
tok_cols = ['token_str', 'biose_layer0', 'unk_type', 'morpheme_count', 'ooev', 'token_id_rep']

for file in os.scandir(output_folder):
    if file.name=='.ipynb_checkpoints':
        continue
        
    sc_id = tuple(file.name.split('.')[:-1])
    gold_name, inp, arch, w_embed, seed_num = sc_id
    emb_unit = w_embed.split('_')[-1]

    if sc_id not in scores5:
        print(file.path)
        scores5[sc_id] = {}
        ner_df = get_df_from_sents(nem.read_file_sents(file.path))

        if len(gold_name.split('_'))>2:
            unit, pred_set, ps_sub = gold_name.split('_')
            
            if ps_sub in ('pruned', 'yap'):
                yap_out = get_matching_yap_out(ps_sub, pred_set, arch, w_embed)
                yap_out['ooev'] = ~yap_out.form.isin(emb_words[emb_unit])
                full_df = yap_out.merge(ner_df)

            elif ps_sub == 'gold':
                full_df = gold_dfs[pred_set].copy()
                full_df['biose_layer0'] = ner_df.biose_layer0
                full_df['ooev'] = full_df['ooev_'+emb_unit]
                
            full_df = full_df.merge(unks[pred_set], how='left')
            ooev_tok_part = (full_df.groupby(['sent_id', 'token_id'])
                             .ooev.apply(lambda x: x.any())
                             .reset_index().rename(columns={'ooev': 'ooev_tok_part'}))

            full_df = full_df.merge(ooev_tok_part, how='left')
            gold_ooev = gold_dfs[pred_set].merge(ooev_tok_part, how='left')
            token_unk_sents = full_df.groupby('sent_id').apply(get_sent, cols)
            token_unk_sents_fixed = get_sents_fixed(token_unk_sents)
            ments = [sent_to_mentions_dict(sent, sent_id, 
                                           ment_len=True, ment_cat=True) 
                     for sent_id, sent 
                     in token_unk_sents_fixed]
            ment_set = get_ment_set(ments)
            gold_sents = gold_ooev.groupby('sent_id').apply(get_sent, cols)
            gold_sents_fixed = get_sents_fixed(gold_sents)
            gold_ments = [sent_to_mentions_dict(sent, sent_id, 
                                                ment_len=True, ment_cat=True) 
                          for sent_id, sent 
                          in gold_sents_fixed]
            gold_ment_set = get_ment_set(gold_ments)
            for k in ment_set.keys() | gold_ment_set.keys():
                scores5[sc_id][k] = nem.evaluate_mentions(gold_ment_set[k], 
                                                        ment_set[k], 
                                                        verbose=False, 
                                                        return_tpc=True)

        ##TOKEN
        else:
            ner_df = ner_df.rename(columns= {'id': 'token_id'})
            unit, pred_set = gold_name.split('_')
            full_df = tok_gold_dfs[pred_set].copy()
            full_df['biose_layer0'] = ner_df.biose_layer0
            full_df['ooev'] = full_df['ooev_'+emb_unit]
                
            token_unk_sents = full_df.groupby('sent_id').apply(get_sent, tok_cols)
            token_unk_sents_fixed = get_sents_fixed(token_unk_sents)
            ments = [sent_to_mentions_dict(sent, sent_id, 
                                           ment_len=True, ment_cat=True) 
                     for sent_id, sent 
                     in token_unk_sents_fixed]
            ment_set = get_ment_set(ments)

            gold_ment_set = tok_gold_ment_sets[(pred_set, emb_unit)]
            for k in ment_set.keys() | gold_ment_set.keys():
                scores5[sc_id][k] = nem.evaluate_mentions(gold_ment_set[k], 
                                                        ment_set[k], 
                                                        verbose=False, 
                                                        return_tpc=True)
# Out:
# final_setup/decode_output/morph_dev_gold.morph.char_cnn.ft_yap.44_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.char_cnn.ft_yap.44_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.char_cnn.ft_yap.44_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.char_cnn.ft_oov_tok.44_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.char_cnn.ft_yap.44_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.char_cnn.ft_oov_tok.44_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.char_cnn.ft_oov_tok.44_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.char_cnn.glv_tok.45_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.char_cnn.glv_tok.45_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.char_cnn.ft_oov_tok.44_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.char_cnn.glv_tok.45_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.glv_yap.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.glv_yap.44_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.char_cnn.glv_tok.45_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.glv_tok.44_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.char_cnn.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.no_word.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.glv_tok.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.no_word.44_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.char_cnn.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.char_cnn.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.ft_tok.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.char_cnn.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.ft_tok.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.ft_oov_tok.44_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.char_cnn.ft_tok.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.ft_oov_tok.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.ft_oov_tok.44_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.char_cnn.ft_tok.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.ft_oov_tok.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.ft_yap.44_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.char_cnn.ft_tok.44_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.char_cnn.glv_yap.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.ft_yap.44_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.char_cnn.ft_tok.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.char_cnn.glv_yap.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.ft_tok.44_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.char_cnn.glv_yap.44_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.no_char.ft_tok.45_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.ft_tok.44_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.no_char.ft_tok.45_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.char_cnn.glv_yap.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.glv_tok.44_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.no_char.ft_tok.45_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.no_char.ft_oov_tok.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.glv_tok.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.glv_yap.45_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.no_char.ft_tok.45_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.no_char.ft_oov_tok.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.no_word.45_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.glv_yap.45_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.no_char.ft_oov_tok.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.ft_tok.45_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.no_word.45_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.ft_tok.45_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.ft_oov_tok.45_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.no_char.ft_oov_tok.44_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.char_lstm.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/token_dev.token.char_cnn.ft_tok.44_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.char_lstm.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.ft_oov_tok.45_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.glv_tok.45_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.char_lstm.ft_tok.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.glv_tok.45_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.ft_oov_yap.45_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.char_lstm.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.char_lstm.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.char_lstm.ft_tok.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.ft_oov_yap.45_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.ft_yap.45_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.ft_oov_yap.45_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.char_lstm.ft_tok.44_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.no_char.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.ft_yap.45_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.ft_oov_tok.45_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.ft_oov_yap.45_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.no_char.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.char_lstm.ft_tok.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.ft_tok.45_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.ft_oov_tok.45_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.char_lstm.glv_tok.44_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.no_char.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.ft_tok.45_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.no_word.46_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.char_lstm.glv_tok.44_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.no_char.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.glv_tok.45_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.no_word.46_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.no_char.glv_yap.44_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.char_lstm.glv_tok.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.ft_oov_tok.46_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.glv_tok.45_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.no_char.glv_yap.44_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.char_lstm.glv_tok.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.glv_yap.46_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.ft_oov_tok.46_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.no_char.glv_yap.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.ft_oov_yap.46_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.glv_yap.46_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.char_lstm.no_word.44_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.no_char.glv_yap.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.glv_tok.46_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.ft_oov_yap.46_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.char_lstm.no_word.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_cnn.ft_tok.46_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.glv_tok.46_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.ft_yap.46_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.char_lstm.no_word.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_cnn.ft_tok.46_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.ft_tok.46_seed.bmes
# final_setup/decode_output/morph_test_yap.morph.char_lstm.no_word.44_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.ft_yap.46_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.ft_oov_yap.46_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.ft_tok.46_seed.bmes
# final_setup/decode_output/token_dev.multitok.char_lstm.ft_oov_tok.46_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.ft_oov_yap.46_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.char_cnn.ft_yap.45_seed.bmes
# final_setup/decode_output/token_test.multitok.char_lstm.ft_oov_tok.46_seed.bmes
# final_setup/decode_output/token_dev.token.char_cnn.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.char_cnn.ft_yap.45_seed.bmes
# final_setup/decode_output/token_dev.multitok.no_char.ft_oov_tok.44_seed.bmes
# final_setup/decode_output/morph_dev_gold.morph.char_cnn.ft_oov_tok.45_seed.bmes
# final_setup/decode_output/token_test.token.char_cnn.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/token_dev.multitok.no_char.ft_oov_yap.44_seed.bmes
# final_setup/decode_output/morph_test_gold.morph.char_cnn.ft_yap.45_seed.bmes
# final_setup/decode_output/morph_dev_yap.morph.char_cnn.ft_oov_tok.45_seed.bmes
# final_setup/decode_output/token_test.multitok.no_char.ft_oov_tok.44_seed.bmes

# %%
import pickle
pickle.dump(scores5, open('final_setup/oov_scores5.pkl', 'wb'))

# %%
len(scores5)
# Out:
# 2100

# %%
def prf_from_tpc(t, p, c):
    if p==0:
        prec=-1
    else:
        prec = c / p
    
    if t==0:
        recall=-1
    else:
        recall = c / t

    if prec+recall==0:
        f1=-1
    else:
        f1 = 2*prec*recall/(prec+recall)    
    return prec, recall, f1

# %%
same = lambda x: x

def ignore(x):
    return 'all'

four_up = lambda x: x if x<=3 else 4

def ut_gm(x):
    filt_x = list(filter(lambda a: a != '', x))
    return tuple(sorted(set(filt_x)))

lenset = lambda x: min(len(set(x)), 4)

# %%
scid_names = ['gold_name', 'unit', 'arch', 'w_embed', 'seed_num']
def group_scores(scs, groupers, names = ['unk_type', 'morpheme_count', 'ooev', 'token_id_rep'], 
                 ment_grouper=same, ment_cat_grouper=ignore):
    grouped_scs = []
    for sc_id, keys in scs.items():
        single_gsc = defaultdict(lambda: [0, 0, 0])
        for k in keys:
            score = scs[sc_id][k]
            (umo, ment_len), ment_cat = k
            ment_len = ment_grouper(ment_len)
            ment_cat = ment_cat_grouper(ment_cat)
            umo = list(zip(*umo))
            grouped_umo = [grouper(x) 
                                 for grouper, x in zip(groupers, umo)]
            grouped_umo.append(ment_len)
            grouped_umo.append(ment_cat)
            grouped_umo = tuple(grouped_umo)
            single_gsc[grouped_umo][0] += score[3]
            single_gsc[grouped_umo][1] += score[4]
            single_gsc[grouped_umo][2] += score[5]

        
        gsc = []
        for grp_k in single_gsc:
            t,p,c = single_gsc[grp_k]
            prec, recall, f1 = prf_from_tpc(t,p,c)
            if f1==-1:
                f1=0
            gsc.append(tuple(list(sc_id)+list(grp_k)+[t,p,c, prec, recall, f1]))
        grouped_scs.extend(gsc)
        
    names = scid_names+names+['ment_len', 'ment_cat']+['true','pred','correct', 'p', 'r', 'f']
    return pd.DataFrame(grouped_scs, columns=names)

# %%
gsc = group_scores(scores5, groupers=[ignore, ignore, ignore, lenset], ment_grouper=ignore)
gsc.head()
# Out:
#         gold_name   unit      arch w_embed seed_num unk_type morpheme_count  \
# 0  morph_dev_gold  morph  char_cnn  ft_yap  44_seed      all            all
# 1  morph_dev_gold  morph  char_cnn  ft_yap  44_seed      all            all
# 2  morph_dev_gold  morph  char_cnn  ft_yap  44_seed      all            all
# 3  morph_dev_gold  morph  char_cnn  ft_yap  44_seed      all            all
# 4   morph_dev_yap  morph  char_cnn  ft_yap  44_seed      all            all
#
#   ooev  token_id_rep ment_len ment_cat  true  pred  correct         p  \
# 0  all             1      all      all   255   224      194  0.866071
# 1  all             2      all      all   183   159      141  0.886792
# 2  all             4      all      all    15     8        6  0.750000
# 3  all             3      all      all    46    35       25  0.714286
# 4  all             1      all      all   255   222      166  0.747748
#
#           r         f
# 0  0.760784  0.810021
# 1  0.770492  0.824561
# 2  0.400000  0.521739
# 3  0.543478  0.617284
# 4  0.650980  0.696017

# %%
gsc.groupby('w_embed').size()
# Out:
# w_embed
# ft_oov_tok    1200
# ft_oov_yap    1200
# ft_tok        1200
# ft_yap        1200
# glv_tok       1200
# glv_yap       1200
# no_word       1200
# dtype: int64

# %%
gsc = group_scores(scores5, groupers=[ignore, ignore, ignore, lenset], ment_grouper=ignore, ment_cat_grouper=ignore)
(gsc[gsc.gold_name.str.contains('dev')]
 .groupby(['gold_name', 'unit', 'arch', 'w_embed', 'token_id_rep'])
 .f.mean().mul(100).round(2).unstack())
# Out:
# token_id_rep                                        1      2      3      4
# gold_name        unit     arch      w_embed
# morph_dev_gold   morph    char_cnn  ft_oov_tok  81.62  83.52  61.51  44.72
#                                     ft_oov_yap  81.71  83.81  61.97  51.07
#                                     ft_tok      80.98  83.42  61.36  48.60
#                                     ft_yap      80.02  83.43  61.79  48.80
#                                     glv_tok     80.26  81.46  59.17  41.30
#                                     glv_yap     80.14  81.09  60.94  42.80
#                                     no_word     61.72  69.73  49.43  38.58
#                           char_lstm ft_oov_tok  81.15  83.06  61.48  45.70
#                                     ft_oov_yap  82.21  83.06  59.19  44.97
#                                     ft_tok      80.37  82.91  60.72  47.90
#                                     ft_yap      80.47  82.96  58.64  48.54
#                                     glv_tok     80.09  81.40  60.01  40.98
#                                     glv_yap     80.42  81.39  64.35  47.10
#                                     no_word     62.47  69.47  44.22  35.83
#                           no_char   ft_oov_tok  81.44  83.02  62.86  48.97
#                                     ft_oov_yap  81.67  83.38  60.79  45.21
#                                     ft_tok      79.19  83.20  63.15  47.92
#                                     ft_yap      78.61  82.91  61.03  48.50
#                                     glv_tok     77.82  81.01  59.88  36.58
#                                     glv_yap     77.06  80.94  61.81  47.00
#                                     no_word     60.40  64.79  42.86  28.93
# morph_dev_pruned morph    char_cnn  ft_oov_tok  79.67  80.83  59.92  40.28
#                                     ft_oov_yap  79.93  82.01  59.15  47.67
#                                     ft_tok      77.16  81.09  58.62  43.03
#                                     ft_yap      77.96  81.56  58.88  45.89
#                                     glv_tok     77.50  78.61  56.60  38.09
#                                     glv_yap     78.14  78.97  58.96  41.93
#                                     no_word     57.28  66.14  46.98  34.34
#                           char_lstm ft_oov_tok  78.29  81.06  59.23  39.50
#                                     ft_oov_yap  80.20  82.04  56.81  43.09
#                                     ft_tok      76.40  80.26  58.77  43.64
#                                     ft_yap      78.18  81.13  56.55  45.73
#                                     glv_tok     76.40  79.38  55.76  40.74
#                                     glv_yap     78.06  79.21  62.96  41.23
#                                     no_word     58.56  65.64  40.59  35.13
#                           no_char   ft_oov_tok  78.49  81.65  62.66  40.49
#                                     ft_oov_yap  79.34  80.48  55.65  42.97
#                                     ft_tok      75.35  80.62  61.78  45.46
#                                     ft_yap      77.15  81.34  57.37  47.09
#                                     glv_tok     75.22  78.62  56.53  37.28
#                                     glv_yap     74.61  78.50  58.54  43.29
#                                     no_word     55.22  61.11  39.53  25.43
# morph_dev_yap    morph    char_cnn  ft_oov_tok  71.40  78.95  57.32  44.16
#                                     ft_oov_yap  71.88  78.99  56.54  48.04
#                                     ft_tok      70.63  78.23  55.63  47.61
#                                     ft_yap      69.94  78.03  55.34  46.17
#                                     glv_tok     70.52  75.43  53.24  40.58
#                                     glv_yap     70.44  74.87  53.39  40.70
#                                     no_word     53.41  65.76  43.54  39.05
#                           char_lstm ft_oov_tok  70.98  78.16  56.03  40.63
#                                     ft_oov_yap  72.23  78.26  54.53  41.53
#                                     ft_tok      70.07  77.21  55.27  44.71
#                                     ft_yap      69.90  77.22  52.80  44.29
#                                     glv_tok     69.98  75.40  54.01  42.34
#                                     glv_yap     70.22  75.55  57.13  44.74
#                                     no_word     54.28  66.32  39.28  33.29
#                           no_char   ft_oov_tok  70.91  78.15  58.40  44.89
#                                     ft_oov_yap  72.10  78.65  55.70  43.03
#                                     ft_tok      69.37  77.63  58.13  43.82
#                                     ft_yap      68.86  77.83  54.94  45.73
#                                     glv_tok     68.23  75.84  54.10  36.41
#                                     glv_yap     67.30  75.38  55.78  46.84
#                                     no_word     51.81  61.64  40.32  30.74
# token_dev        multitok char_cnn  ft_oov_tok  77.80  81.30  61.18  42.78
#                                     ft_oov_yap  76.27  77.80  60.99  47.07
#                                     ft_tok      74.46  80.64  60.44  42.78
#                                     ft_yap      71.22  75.84  55.58  42.15
#                                     glv_tok     72.69  77.42  59.08  39.86
#                                     glv_yap     70.50  73.48  56.34  41.33
#                                     no_word     53.88  61.12  42.74  27.14
#                           char_lstm ft_oov_tok  78.95  81.16  61.48  43.99
#                                     ft_oov_yap  76.21  78.84  61.31  51.90
#                                     ft_tok      74.61  80.40  62.44  48.45
#                                     ft_yap      72.37  75.70  55.06  44.10
#                                     glv_tok     73.31  77.08  58.46  40.89
#                                     glv_yap     69.22  73.32  55.07  40.52
#                                     no_word     54.46  60.96  45.17  26.66
#                           no_char   ft_oov_tok  79.91  81.45  60.08  46.34
#                                     ft_oov_yap  74.97  77.85  56.14  46.41
#                                     ft_tok      75.00  80.01  57.27  45.08
#                                     ft_yap      69.57  72.51  53.94  25.41
#                                     glv_tok     70.26  76.33  55.93  33.70
#                                     glv_yap     66.03  70.29  50.11  23.18
#                                     no_word     48.28  52.45  40.51  14.56
#                  token    char_cnn  ft_oov_tok  79.75  82.34  62.61  43.86
#                                     ft_oov_yap  77.09  78.27  66.14  50.51
#                                     ft_tok      76.12  80.79  60.51  48.85
#                                     ft_yap      70.77  75.41  55.75  40.57
#                                     glv_tok     75.37  77.32  61.45  43.20
#                                     glv_yap     69.60  73.68  54.72  26.75
#                                     no_word     56.42  60.72  43.96  36.64
#                           char_lstm ft_oov_tok  79.35  82.12  62.22  47.19
#                                     ft_oov_yap  77.02  78.05  63.74  51.15
#                                     ft_tok      77.58  81.25  60.25  50.69
#                                     ft_yap      71.90  74.35  55.26  44.40
#                                     glv_tok     75.69  77.25  60.03  42.36
#                                     glv_yap     70.24  73.91  55.51  23.05
#                                     no_word     56.23  60.38  45.57  38.62
#                           no_char   ft_oov_tok  78.73  81.26  61.89  42.71
#                                     ft_oov_yap  75.62  77.75  63.62  50.89
#                                     ft_tok      74.43  80.77  58.38  47.64
#                                     ft_yap      70.21  73.62  54.02  28.79
#                                     glv_tok     70.94  76.49  59.17  37.26
#                                     glv_yap     66.06  72.36  53.47  19.64
#                                     no_word     53.92  55.50  40.94  31.84

# %% [markdown]
# ## OOTV

# %%
gsc = group_scores(scores5, groupers=[ut_gm, ignore, ignore, ignore], ment_grouper=ignore, ment_cat_grouper=ignore)
(gsc[gsc.gold_name.str.contains('morph_dev')]
 .groupby(['gold_name', 'unit', 'arch', 'w_embed', 'unk_type'])
 .f.mean().unstack())
# Out:
# unk_type                                           ()      (T,)   (T, TM)  \
# gold_name        unit  arch      w_embed
# morph_dev_gold   morph char_cnn  ft_oov_tok  0.822178  0.687515  0.533535
#                                  ft_oov_yap  0.830871  0.694968  0.457172
#                                  ft_tok      0.821035  0.681985  0.469091
#                                  ft_yap      0.832321  0.693843  0.418535
#                                  glv_tok     0.818826  0.659414  0.211555
#                                  glv_yap     0.820197  0.685386  0.342424
#                                  no_word     0.787278  0.648385 -0.519596
#                        char_lstm ft_oov_tok  0.815305  0.686438  0.511717
#                                  ft_oov_yap  0.825925  0.696072  0.401616
#                                  ft_tok      0.817964  0.686331  0.475960
#                                  ft_yap      0.827873  0.690425  0.392020
#                                  glv_tok     0.811900  0.657389  0.372960
#                                  glv_yap     0.817194  0.691865  0.437778
#                                  no_word     0.786730  0.639893 -0.557778
#                        no_char   ft_oov_tok  0.829734  0.691140  0.534545
#                                  ft_oov_yap  0.834369  0.692069  0.434343
#                                  ft_tok      0.824097  0.690885  0.480497
#                                  ft_yap      0.836068  0.693894  0.375758
#                                  glv_tok     0.815581  0.648311  0.318135
#                                  glv_yap     0.816494  0.679197  0.487778
#                                  no_word     0.791939  0.619117 -0.452778
# morph_dev_pruned morph char_cnn  ft_oov_tok  0.805038  0.696114  0.364697
#                                  ft_oov_yap  0.813882  0.664788  0.457172
#                                  ft_tok      0.806279  0.588589  0.138333
#                                  ft_yap      0.815244  0.657342  0.273889
#                                  glv_tok     0.801752  0.611594  0.317203
#                                  glv_yap     0.809456  0.663865  0.226919
#                                  no_word     0.756395  0.461964 -0.510556
#                        char_lstm ft_oov_tok  0.804639  0.621249  0.358333
#                                  ft_oov_yap  0.816085  0.647243  0.435556
#                                  ft_tok      0.801067  0.632550  0.303586
#                                  ft_yap      0.815245  0.654562  0.261111
#                                  glv_tok     0.796789  0.599711  0.393636
#                                  glv_yap     0.802280  0.648965  0.424927
#                                  no_word     0.760139  0.499232 -0.657778
#                        no_char   ft_oov_tok  0.811197  0.684377  0.351111
#                                  ft_oov_yap  0.812010  0.644579  0.235354
#                                  ft_tok      0.804631  0.615118 -0.045625
#                                  ft_yap      0.819558  0.644799  0.251515
#                                  glv_tok     0.804865  0.600740  0.205606
#                                  glv_yap     0.799961  0.633909  0.395253
#                                  no_word     0.763380  0.342433 -0.700000
# morph_dev_yap    morph char_cnn  ft_oov_tok  0.753748  0.602180  0.452727
#                                  ft_oov_yap  0.758316  0.607201  0.451919
#                                  ft_tok      0.750643  0.585296  0.385820
#                                  ft_yap      0.760511  0.603091  0.383283
#                                  glv_tok     0.744839  0.564701  0.230553
#                                  glv_yap     0.744501  0.597494  0.196022
#                                  no_word     0.712863  0.562143 -0.517374
#                        char_lstm ft_oov_tok  0.747125  0.602362  0.408889
#                                  ft_oov_yap  0.753730  0.608250  0.406061
#                                  ft_tok      0.745565  0.590927  0.367024
#                                  ft_yap      0.750877  0.596415  0.346869
#                                  glv_tok     0.737459  0.560213  0.353956
#                                  glv_yap     0.742670  0.601904  0.398430
#                                  no_word     0.719516  0.550475 -0.661111
#                        no_char   ft_oov_tok  0.758894  0.607067  0.422222
#                                  ft_oov_yap  0.762401  0.609822  0.404444
#                                  ft_tok      0.753776  0.599997  0.350163
#                                  ft_yap      0.763223  0.605705  0.312475
#                                  glv_tok     0.745827  0.566924  0.197424
#                                  glv_yap     0.747084  0.586978  0.446768
#                                  no_word     0.721850  0.534444 -0.552778
#
# unk_type                                        (TM,)
# gold_name        unit  arch      w_embed
# morph_dev_gold   morph char_cnn  ft_oov_tok  0.793864
#                                  ft_oov_yap  0.790695
#                                  ft_tok      0.789779
#                                  ft_yap      0.761516
#                                  glv_tok     0.766338
#                                  glv_yap     0.757847
#                                  no_word     0.350990
#                        char_lstm ft_oov_tok  0.795430
#                                  ft_oov_yap  0.790227
#                                  ft_tok      0.777748
#                                  ft_yap      0.764060
#                                  glv_tok     0.771990
#                                  glv_yap     0.774625
#                                  no_word     0.350393
#                        no_char   ft_oov_tok  0.782692
#                                  ft_oov_yap  0.778655
#                                  ft_tok      0.762230
#                                  ft_yap      0.732187
#                                  glv_tok     0.732253
#                                  glv_yap     0.718766
#                                  no_word     0.199328
# morph_dev_pruned morph char_cnn  ft_oov_tok  0.763052
#                                  ft_oov_yap  0.770258
#                                  ft_tok      0.752539
#                                  ft_yap      0.741341
#                                  glv_tok     0.727122
#                                  glv_yap     0.725131
#                                  no_word     0.330533
#                        char_lstm ft_oov_tok  0.760861
#                                  ft_oov_yap  0.770089
#                                  ft_tok      0.731483
#                                  ft_yap      0.737194
#                                  glv_tok     0.725134
#                                  glv_yap     0.746633
#                                  no_word     0.316903
#                        no_char   ft_oov_tok  0.755512
#                                  ft_oov_yap  0.751582
#                                  ft_tok      0.731914
#                                  ft_yap      0.721813
#                                  glv_tok     0.689444
#                                  glv_yap     0.686761
#                                  no_word     0.185191
# morph_dev_yap    morph char_cnn  ft_oov_tok  0.714417
#                                  ft_oov_yap  0.714039
#                                  ft_tok      0.706064
#                                  ft_yap      0.674773
#                                  glv_tok     0.682556
#                                  glv_yap     0.671523
#                                  no_word     0.312513
#                        char_lstm ft_oov_tok  0.708251
#                                  ft_oov_yap  0.712404
#                                  ft_tok      0.692798
#                                  ft_yap      0.676311
#                                  glv_tok     0.686935
#                                  glv_yap     0.684278
#                                  no_word     0.313294
#                        no_char   ft_oov_tok  0.697720
#                                  ft_oov_yap  0.706724
#                                  ft_tok      0.681027
#                                  ft_yap      0.654892
#                                  glv_tok     0.650126
#                                  glv_yap     0.634460
#                                  no_word     0.170977

# %%
gsc = group_scores(scores5, groupers=[ut_gm, ignore, ignore, ignore], ment_grouper=ignore, ment_cat_grouper=ignore)
(gsc[((gsc.gold_name.isin(['morph_dev_gold','morph_dev_pruned']))
      & (gsc.arch=='char_cnn')
      & (gsc.w_embed=='ft_oov_yap')

     )
    |
     (
        (gsc.gold_name.isin(['token_dev']))
      & (gsc.arch=='char_lstm')
      & (gsc.w_embed=='ft_oov_tok')

     )]
 .groupby(['gold_name', 'unit', 'unk_type'])
 .f.mean().mul(100).round(2).unstack())
# Out:
# unk_type                      ()   (T,)  (T, TM)  (TM,)
# gold_name        unit
# morph_dev_gold   morph     83.09  69.50    45.72  79.07
# morph_dev_pruned morph     81.39  66.48    45.72  77.03
# token_dev        multitok  80.06  63.40    32.36  78.23
#                  token     81.64  64.21    26.87  77.67

# %%
def unk_type_replace(t):
    if t==('T',):
        return 'Comp'
    if t==():
        return 'Known'
    if t==('TM',):
        return 'Real'
    if t==('T', 'TM'):
        return 'R+C'

# %%
x.columns
# Out:
# Index([(), ('T',), ('T', 'TM'), ('TM',)], dtype='object', name='unk_type')

# %%
gsc = (group_scores(scores5, groupers=[ut_gm, ignore, ignore, ignore], ment_grouper=ignore, ment_cat_grouper=ignore)
      .assign(unk_type = lambda x: x.unk_type.apply(unk_type_replace)))
x = (gsc[((gsc.gold_name.isin(['morph_dev_gold','morph_dev_pruned']))
      & (gsc.arch=='char_cnn')
      & (gsc.w_embed=='ft_oov_yap')

     )
    |
     (
        (gsc.gold_name.isin(['token_dev']))
      & (gsc.arch=='char_lstm')
      & (gsc.w_embed=='ft_oov_tok')

     )]
 .groupby(['gold_name', 'unit', 'unk_type'])
 .f.agg(['mean', 'std']).mul(100).round(2)
         .assign(mean = lambda x: '$'+x['mean'].apply('{:,.2f}'.format).astype(str)+' ± '+ x['std'].round(1).astype(str)+'$')[['mean']]
         .unstack())
x.columns = x.columns.droplevel(0)
print (x[['Known', 'Real', 'Comp', 'R+C']].to_latex(bold_rows=True).replace('±', '\pm').replace('\$', '$'))
# Out:
# \begin{tabular}{llllll}
# \toprule
#           & \textbf{unk\_type} &          Known &           Real &           Comp &            R+C \\
# \textbf{gold\_name} & \textbf{unit} &                &                &                &                \\
# \midrule
# \textbf{morph\_dev\_gold} & \textbf{morph} &  $83.09 \pm 0.9$ &  $79.07 \pm 1.4$ &  $69.50 \pm 1.3$ &  $45.72 \pm 9.9$ \\
# \textbf{morph\_dev\_pruned} & \textbf{morph} &  $81.39 \pm 1.0$ &  $77.03 \pm 1.5$ &  $66.48 \pm 1.2$ &  $45.72 \pm 9.9$ \\
# \textbf{token\_dev} & \textbf{multitok} &  $80.06 \pm 1.0$ &  $78.23 \pm 1.2$ &  $63.40 \pm 2.6$ &  $32.36 \pm 7.3$ \\
#           & \textbf{token} &  $81.64 \pm 0.9$ &  $77.67 \pm 0.8$ &  $64.21 \pm 2.5$ &  $26.87 \pm 8.5$ \\
# \bottomrule
# \end{tabular}

# %%
from scipy.stats import ttest_ind

# %%
tt = (gsc[(gsc.unk_type=='Comp') & ( ((gsc.gold_name=='morph_dev_pruned')
      & (gsc.arch=='char_cnn')
      & (gsc.w_embed=='ft_oov_yap')

     )
    |
     (
        (gsc.gold_name.isin(['token_dev']))
      & (gsc.arch=='char_lstm')
      & (gsc.w_embed=='ft_oov_tok')

     ))]
)

ttest_ind(tt[tt.unit=='morph'].f, tt[tt.unit=='token'].f)
# Out:
# Ttest_indResult(statistic=2.5674395676052857, pvalue=0.01937938613779738)

# %%
tt = (gsc[(gsc.unk_type=='Real') & ( ((gsc.gold_name=='morph_dev_pruned')
      & (gsc.arch=='char_cnn')
      & (gsc.w_embed=='ft_oov_yap')

     )
    |
     (
        (gsc.gold_name.isin(['token_dev']))
      & (gsc.arch=='char_lstm')
      & (gsc.w_embed=='ft_oov_tok')

     ))]
)

ttest_ind(tt[tt.unit=='morph'].f, tt[tt.unit=='multitok'].f)
# Out:
# Ttest_indResult(statistic=-1.9369654553486633, pvalue=0.06860642276609745)

# %%
gsc = group_scores(scores4, groupers=[ut_gm, ignore, ignore], ment_grouper=ignore, ment_cat_grouper=ignore)
(gsc[gsc.gold_name.str.contains('token_dev')]
 .groupby(['gold_name', 'unit', 'arch', 'w_embed', 'unk_type'])
 .f.mean().unstack())
# Out:
# unk_type                                       ()      (T,)   (T, TM)  \
# gold_name unit     arch      w_embed
# token_dev multitok char_cnn  ft_oov_tok  0.797595  0.630318  0.308345
#                              ft_oov_yap  0.796952  0.597179  0.249293
#                              ft_tok      0.800908  0.623261  0.142172
#                              ft_yap      0.790428  0.457796 -1.000000
#                              glv_tok     0.782409  0.544636 -0.046713
#                              glv_yap     0.782695  0.340578 -0.875000
#                              no_word     0.754914  0.086791 -0.700000
#                    char_lstm ft_oov_tok  0.800648  0.633958  0.323636
#                              ft_oov_yap  0.799922  0.593703  0.291515
#                              ft_tok      0.801149  0.622028  0.028030
#                              ft_yap      0.790918  0.477419 -1.000000
#                              glv_tok     0.789994  0.554734 -0.271708
#                              glv_yap     0.777500  0.361928 -0.880000
#                              no_word     0.755416  0.160329 -0.800000
#                    no_char   ft_oov_tok  0.799358  0.660507  0.169417
#                              ft_oov_yap  0.779761  0.594731  0.012727
#                              ft_tok      0.798358  0.628164 -0.171888
#                              ft_yap      0.780837  0.442400 -1.000000
#                              glv_tok     0.781651  0.531278 -0.761818
#                              glv_yap     0.767949  0.324679 -0.880000
#                              no_word     0.734351  0.099745 -1.000000
#           token    char_cnn  ft_oov_tok  0.817111  0.652524  0.306970
#                              ft_oov_yap  0.805971  0.584149  0.109798
#                              ft_tok      0.810920  0.641690 -0.397778
#                              ft_yap      0.795888  0.474744 -1.000000
#                              glv_tok     0.792902  0.531939 -0.530303
#                              glv_yap     0.770903  0.369180 -0.760000
#                              no_word     0.773292  0.136044 -1.000000
#                    char_lstm ft_oov_tok  0.816433  0.642129  0.268687
#                              ft_oov_yap  0.799790  0.581078  0.353636
#                              ft_tok      0.813877  0.644188 -0.259596
#                              ft_yap      0.791385  0.468675 -0.880000
#                              glv_tok     0.795105  0.544663  0.067980
#                              glv_yap     0.776317  0.367429 -0.637778
#                              no_word     0.756457  0.102009 -0.900000
#                    no_char   ft_oov_tok  0.813061  0.608385  0.313333
#                              ft_oov_yap  0.805618  0.521275  0.321414
#                              ft_tok      0.811931  0.597331 -0.513333
#                              ft_yap      0.793418  0.416617 -1.000000
#                              glv_tok     0.792238  0.473870 -0.881818
#                              glv_yap     0.769771  0.340744 -0.875000
#                              no_word     0.744116  0.090221 -0.200000
#
# unk_type                                    (TM,)
# gold_name unit     arch      w_embed
# token_dev multitok char_cnn  ft_oov_tok  0.771243
#                              ft_oov_yap  0.727613
#                              ft_tok      0.715171
#                              ft_yap      0.661115
#                              glv_tok     0.703852
#                              glv_yap     0.659396
#                              no_word     0.285574
#                    char_lstm ft_oov_tok  0.782296
#                              ft_oov_yap  0.736229
#                              ft_tok      0.722791
#                              ft_yap      0.668950
#                              glv_tok     0.697833
#                              glv_yap     0.640901
#                              no_word     0.291716
#                    no_char   ft_oov_tok  0.795378
#                              ft_oov_yap  0.727356
#                              ft_tok      0.721140
#                              ft_yap      0.608777
#                              glv_tok     0.656692
#                              glv_yap     0.567150
#                              no_word     0.202486
#           token    char_cnn  ft_oov_tok  0.780089
#                              ft_oov_yap  0.745051
#                              ft_tok      0.726085
#                              ft_yap      0.635088
#                              glv_tok     0.732236
#                              glv_yap     0.647498
#                              no_word     0.262716
#                    char_lstm ft_oov_tok  0.776677
#                              ft_oov_yap  0.745659
#                              ft_tok      0.746869
#                              ft_yap      0.649295
#                              glv_tok     0.725099
#                              glv_yap     0.651485
#                              no_word     0.301990
#                    no_char   ft_oov_tok  0.767210
#                              ft_oov_yap  0.726865
#                              ft_tok      0.704907
#                              ft_yap      0.610300
#                              glv_tok     0.667783
#                              glv_yap     0.578671
#                              no_word     0.178180

# %% [markdown]
# Maybe T has more ORGs, and that's why it's harder?

# %%
pd.set_option("max_rows", 300)

# %%
gsc = group_scores(scores4, groupers=[ut_gm, ignore, ignore], 
                   ment_grouper=ignore, ment_cat_grouper=same)
xx = (gsc[gsc.gold_name.str.contains('morph_dev')]
 .groupby(['ment_cat', 'unk_type'])
 .true.mean().unstack())
xx
# Out:
# unk_type    ()  (T,)  (T, TM)  (TM,)
# ment_cat
# ANG        3.0   0.0      NaN    0.0
# DUC        1.0   0.0      0.0    1.0
# EVE        5.0   5.0      2.0    0.0
# FAC        5.0   5.0      0.0    2.0
# GPE       76.0  15.0      NaN   30.0
# LOC       20.0   2.0      0.0    6.0
# ORG       61.0  11.0      4.0   43.0
# PER       70.0   4.0      0.0  119.0
# WOA        3.0   3.0      0.0    3.0

# %%
(xx.T / xx.T.sum()).T
# Out:
# unk_type        ()      (T,)   (T, TM)     (TM,)
# ment_cat
# ANG       1.000000  0.000000       NaN  0.000000
# DUC       0.500000  0.000000  0.000000  0.500000
# EVE       0.416667  0.416667  0.166667  0.000000
# FAC       0.416667  0.416667  0.000000  0.166667
# GPE       0.628099  0.123967       NaN  0.247934
# LOC       0.714286  0.071429  0.000000  0.214286
# ORG       0.512605  0.092437  0.033613  0.361345
# PER       0.362694  0.020725  0.000000  0.616580
# WOA       0.333333  0.333333  0.000000  0.333333

# %%
gsc = group_scores(scores4, groupers=[ut_gm, ignore, ignore], ment_grouper=ignore, ment_cat_grouper=same)
(gsc[(gsc.gold_name.str.contains('morph_dev')) & (gsc.ment_cat=='ORG')]
 .groupby(['gold_name', 'unit', 'arch', 'w_embed', 'unk_type'])
 .f.mean().unstack())
#0.805956	0.665775	0.521717	0.779888
# Out:
# unk_type                                           ()      (T,)   (T, TM)  \
# gold_name        unit  arch      w_embed
# morph_dev_gold   morph char_cnn  ft_oov_tok  0.754281  0.677696  0.732143
#                                  ft_oov_yap  0.753601  0.705882  0.628571
#                                  ft_tok      0.757968  0.696315  0.627778
#                                  ft_yap      0.759375  0.713072  0.594048
#                                  glv_tok     0.737404  0.650245  0.422619
#                                  glv_yap     0.751105  0.683893  0.551429
#                                  no_word     0.696903  0.595184 -0.389286
#                        char_lstm ft_oov_tok  0.757239  0.692565  0.696429
#                                  ft_oov_yap  0.754131  0.713072  0.571429
#                                  ft_tok      0.757545  0.700178  0.635714
#                                  ft_yap      0.754693  0.709150  0.559524
#                                  glv_tok     0.733897  0.682190  0.608333
#                                  glv_yap     0.746523  0.710997  0.661905
#                                  no_word     0.674480  0.525507 -0.433333
#                        no_char   ft_oov_tok  0.763919  0.698039  0.700000
#                                  ft_oov_yap  0.760657  0.713072  0.607143
#                                  ft_tok      0.767361  0.701961  0.621429
#                                  ft_yap      0.766936  0.705882  0.535714
#                                  glv_tok     0.733222  0.639134  0.528571
#                                  glv_yap     0.746239  0.686144  0.700000
#                                  no_word     0.688105  0.484172 -0.233333
# morph_dev_pruned morph char_cnn  ft_oov_tok  0.733686  0.673775  0.502381
#                                  ft_oov_yap  0.735008  0.694118  0.628571
#                                  ft_tok      0.739054  0.681527  0.248810
#                                  ft_yap      0.726999  0.705229  0.373810
#                                  glv_tok     0.724567  0.627292  0.510714
#                                  glv_yap     0.735896  0.676539  0.389524
#                                  no_word     0.674766  0.572472 -0.380952
#                        char_lstm ft_oov_tok  0.740776  0.615833  0.500000
#                                  ft_oov_yap  0.742663  0.709150  0.571429
#                                  ft_tok      0.721855  0.688368  0.423810
#                                  ft_yap      0.741256  0.629412  0.354762
#                                  glv_tok     0.720376  0.653655  0.608333
#                                  glv_yap     0.730325  0.706422  0.666667
#                                  no_word     0.654506  0.525817 -0.433333
#                        no_char   ft_oov_tok  0.744478  0.701961  0.471429
#                                  ft_oov_yap  0.733918  0.618137  0.328571
#                                  ft_tok      0.743230  0.621324  0.048810
#                                  ft_yap      0.752647  0.610703  0.376190
#                                  glv_tok     0.727446  0.560392  0.340476
#                                  glv_yap     0.742650  0.655394  0.566667
#                                  no_word     0.661586  0.513313 -0.400000
# morph_dev_yap    morph char_cnn  ft_oov_tok  0.716405  0.593824  0.628571
#                                  ft_oov_yap  0.711427  0.613971  0.621429
#                                  ft_tok      0.709761  0.601618  0.577778
#                                  ft_yap      0.711741  0.629412  0.552381
#                                  glv_tok     0.685922  0.546046  0.422619
#                                  glv_yap     0.702825  0.599232  0.389524
#                                  no_word     0.638431  0.519281 -0.285714
#                        char_lstm ft_oov_tok  0.716419  0.615833  0.571429
#                                  ft_oov_yap  0.713452  0.633088  0.571429
#                                  ft_tok      0.703021  0.611471  0.532143
#                                  ft_yap      0.701572  0.629412  0.500000
#                                  glv_tok     0.681397  0.579869  0.581667
#                                  glv_yap     0.701187  0.645899  0.666667
#                                  no_word     0.626685  0.436242 -0.433333
#                        no_char   ft_oov_tok  0.720240  0.617647  0.564286
#                                  ft_oov_yap  0.720024  0.629412  0.571429
#                                  ft_tok      0.723514  0.625000  0.492857
#                                  ft_yap      0.714204  0.625000  0.452381
#                                  glv_tok     0.685318  0.553382  0.361905
#                                  glv_yap     0.705938  0.601161  0.647619
#                                  no_word     0.622339  0.411214 -0.333333
#
# unk_type                                        (TM,)
# gold_name        unit  arch      w_embed
# morph_dev_gold   morph char_cnn  ft_oov_tok  0.530702
#                                  ft_oov_yap  0.553281
#                                  ft_tok      0.530970
#                                  ft_yap      0.534189
#                                  glv_tok     0.426602
#                                  glv_yap     0.450434
#                                  no_word     0.226856
#                        char_lstm ft_oov_tok  0.544201
#                                  ft_oov_yap  0.545209
#                                  ft_tok      0.520620
#                                  ft_yap      0.562202
#                                  glv_tok     0.433548
#                                  glv_yap     0.478477
#                                  no_word     0.214480
#                        no_char   ft_oov_tok  0.509599
#                                  ft_oov_yap  0.530753
#                                  ft_tok      0.534548
#                                  ft_yap      0.545916
#                                  glv_tok     0.442740
#                                  glv_yap     0.458695
#                                  no_word     0.140628
# morph_dev_pruned morph char_cnn  ft_oov_tok  0.456523
#                                  ft_oov_yap  0.501492
#                                  ft_tok      0.497062
#                                  ft_yap      0.517877
#                                  glv_tok     0.359413
#                                  glv_yap     0.376554
#                                  no_word     0.171393
#                        char_lstm ft_oov_tok  0.463889
#                                  ft_oov_yap  0.521660
#                                  ft_tok      0.468025
#                                  ft_yap      0.459583
#                                  glv_tok     0.361926
#                                  glv_yap     0.418184
#                                  no_word     0.117691
#                        no_char   ft_oov_tok  0.440417
#                                  ft_oov_yap  0.501661
#                                  ft_tok      0.508105
#                                  ft_yap      0.545437
#                                  glv_tok     0.360642
#                                  glv_yap     0.391374
#                                  no_word     0.120680
# morph_dev_yap    morph char_cnn  ft_oov_tok  0.458156
#                                  ft_oov_yap  0.490028
#                                  ft_tok      0.462495
#                                  ft_yap      0.463550
#                                  glv_tok     0.355605
#                                  glv_yap     0.374200
#                                  no_word     0.192721
#                        char_lstm ft_oov_tok  0.447852
#                                  ft_oov_yap  0.483582
#                                  ft_tok      0.444307
#                                  ft_yap      0.478954
#                                  glv_tok     0.368878
#                                  glv_yap     0.399180
#                                  no_word     0.141314
#                        no_char   ft_oov_tok  0.421550
#                                  ft_oov_yap  0.476407
#                                  ft_tok      0.461258
#                                  ft_yap      0.471672
#                                  glv_tok     0.376896
#                                  glv_yap     0.393071
#                                  no_word     0.084699

# %% [markdown]
# Answer is NO - ORG does have more T's but score is actually better in T and T,TM for ORG than for the rest

# %% [markdown]
# ## THIS!!!
# for morph, ft_oov_yap is significantly better on OOEV than ft_oov_tok, while it is slightly worse on IEV.

# %%
gsc = group_scores(scores5, groupers=[ignore, ignore, max, ignore], ment_grouper=ignore)
gsc[gsc.gold_name.str.contains('morph_dev')].fillna('x').groupby(['gold_name', 'unit', 'arch', 'w_embed', 'ooev'], sort=False).f.mean().unstack().sort_index()
# Out:
# ooev                                            False     True
# gold_name        unit  arch      w_embed
# morph_dev_gold   morph char_cnn  ft_oov_tok  0.803294  0.752472
#                                  ft_oov_yap  0.800105  0.801235
#                                  ft_tok      0.801067  0.738266
#                                  ft_yap      0.798384  0.724326
#                                  glv_tok     0.781946  0.758756
#                                  glv_yap     0.782598  0.763396
#                                  no_word          NaN  0.630313
#                        char_lstm ft_oov_tok  0.799784  0.751506
#                                  ft_oov_yap  0.797692  0.792757
#                                  ft_tok      0.795577  0.729034
#                                  ft_yap      0.796089  0.724924
#                                  glv_tok     0.780353  0.765531
#                                  glv_yap     0.787229  0.779572
#                                  no_word          NaN  0.628893
#                        no_char   ft_oov_tok  0.804740  0.738246
#                                  ft_oov_yap  0.800819  0.769181
#                                  ft_tok      0.798702  0.675565
#                                  ft_yap      0.798172  0.637938
#                                  glv_tok     0.774054  0.679241
#                                  glv_yap     0.777644  0.663680
#                                  no_word          NaN  0.597824
# morph_dev_pruned morph char_cnn  ft_oov_tok  0.781063  0.734953
#                                  ft_oov_yap  0.781268  0.781371
#                                  ft_tok      0.769256  0.710554
#                                  ft_yap      0.780773  0.686235
#                                  glv_tok     0.755051  0.727229
#                                  glv_yap     0.762051  0.745924
#                                  no_word          NaN  0.591396
#                        char_lstm ft_oov_tok  0.775301  0.720980
#                                  ft_oov_yap  0.781342  0.777014
#                                  ft_tok      0.761941  0.704041
#                                  ft_yap      0.775658  0.701529
#                                  glv_tok     0.754236  0.706132
#                                  glv_yap     0.768953  0.727962
#                                  no_word          NaN  0.591850
#                        no_char   ft_oov_tok  0.783031  0.714378
#                                  ft_oov_yap  0.779654  0.703037
#                                  ft_tok      0.765577  0.660737
#                                  ft_yap      0.785093  0.595679
#                                  glv_tok     0.749318  0.652870
#                                  glv_yap     0.760127  0.590709
#                                  no_word          NaN  0.553703
# morph_dev_yap    morph char_cnn  ft_oov_tok  0.734973  0.640723
#                                  ft_oov_yap  0.728185  0.710992
#                                  ft_tok      0.728827  0.619247
#                                  ft_yap      0.721258  0.633719
#                                  glv_tok     0.711112  0.627565
#                                  glv_yap     0.708551  0.636644
#                                  no_word          NaN  0.567970
#                        char_lstm ft_oov_tok  0.728251  0.636989
#                                  ft_oov_yap  0.725335  0.704232
#                                  ft_tok      0.720579  0.614307
#                                  ft_yap      0.716322  0.624931
#                                  glv_tok     0.708154  0.632977
#                                  glv_yap     0.714142  0.636351
#                                  no_word          NaN  0.570697
#                        no_char   ft_oov_tok  0.732080  0.627821
#                                  ft_oov_yap  0.730928  0.683529
#                                  ft_tok      0.726145  0.569184
#                                  ft_yap      0.725599  0.537925
#                                  glv_tok     0.705431  0.563898
#                                  glv_yap     0.706231  0.543455
#                                  no_word          NaN  0.539510

# %%
def get_cm(s):
    if s.unit=='morph':
        if '_yap' in s.w_embed:
            return 'Match'
        else:
            return 'Clash'
    else:
        if '_tok' in s.w_embed:
            return 'Match'
        else:
            return 'Clash'
    return 'na'

# %%
gsc = (group_scores(scores5, groupers=[ignore, ignore, max, ignore], ment_grouper=ignore, ment_cat_grouper=ignore))
gsc['cm'] = gsc.apply(get_cm, axis=1)
gsc['embed_type'] = gsc.w_embed.str.replace('_tok|_yap', '')

# %%
x = (gsc[((gsc.gold_name.isin(['morph_dev_gold','morph_dev_pruned']))
      & (gsc.arch=='char_cnn')
      & (gsc.w_embed!='no_word')

     )
    |
     (
        (gsc.gold_name.isin(['token_dev']))
      & (gsc.arch=='char_lstm')
      & (gsc.w_embed!='no_word')

     )]
 .groupby(['gold_name', 'unit', 'cm', 'embed_type', 'ooev'])
 .f.agg(['mean', 'std']).mul(100).round(2)
         .assign(mean = lambda x: '$'+x['mean'].apply('{:,.2f}'.format).astype(str)+' ± '+ x['std'].round(1).astype(str)+'$')[['mean']]
         .unstack([-2,-1]))
x.columns = x.columns.droplevel(0)
x[[('glv', False), ('glv', True), ('ft', False), 
       ('ft', True), ('ft_oov', False), ('ft_oov', True)]]
# Out:
# embed_type                                 glv                            ft  \
# ooev                                     False          True           False
# gold_name        unit     cm
# morph_dev_gold   morph    Clash  $78.19 ± 0.6$  $75.88 ± 2.3$  $80.11 ± 0.8$
#                           Match  $78.23 ± 0.6$  $76.34 ± 3.3$  $79.84 ± 0.4$
# morph_dev_pruned morph    Clash  $75.51 ± 0.9$  $72.72 ± 2.6$  $76.93 ± 1.0$
#                           Match  $76.21 ± 0.5$  $74.59 ± 3.0$  $78.08 ± 0.3$
# token_dev        multitok Clash  $74.62 ± 0.9$  $56.17 ± 2.1$  $78.13 ± 1.3$
#                           Match  $74.26 ± 0.8$  $62.79 ± 2.4$  $77.02 ± 0.8$
#                  token    Clash  $75.37 ± 1.1$  $55.97 ± 2.0$  $77.67 ± 1.1$
#                           Match  $74.95 ± 0.7$  $68.80 ± 2.4$  $78.16 ± 0.6$
#
# embed_type                                             ft_oov
# ooev                                     True           False          True
# gold_name        unit     cm
# morph_dev_gold   morph    Clash  $73.83 ± 3.8$  $80.33 ± 0.6$  $75.25 ± 1.8$
#                           Match  $72.43 ± 2.2$  $80.01 ± 0.6$  $80.12 ± 2.3$
# morph_dev_pruned morph    Clash  $71.06 ± 3.7$  $78.11 ± 0.7$  $73.50 ± 2.3$
#                           Match  $68.62 ± 1.9$  $78.13 ± 0.6$  $78.14 ± 2.2$
# token_dev        multitok Clash  $56.18 ± 1.1$  $78.16 ± 1.2$  $69.71 ± 1.4$
#                           Match  $62.90 ± 3.1$  $77.52 ± 0.9$  $77.58 ± 2.6$
#                  token    Clash  $54.67 ± 1.7$  $78.92 ± 0.7$  $69.26 ± 1.3$
#                           Match  $67.76 ± 4.2$  $78.44 ± 0.6$  $76.36 ± 2.7$

# %%
print (x[[('glv', False), ('glv', True), ('ft', False), 
       ('ft', True), ('ft_oov', False), ('ft_oov', True)]]
       .to_latex(bold_rows=True).replace('±', '\pm').replace('\$', '$'))
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#           &       & \textbf{embed\_type} & \multicolumn{2}{l}{glv} & \multicolumn{2}{l}{ft} & \multicolumn{2}{l}{ft\_oov} \\
#           &       & \textbf{ooev} &          False &          True  &          False &          True  &          False &          True  \\
# \textbf{gold\_name} & \textbf{unit} & \textbf{cm} &                &                &                &                &                &                \\
# \midrule
# \textbf{morph\_dev\_gold} & \textbf{morph} & \textbf{Clash} &  $78.19 \pm 0.6$ &  $75.88 \pm 2.3$ &  $80.11 \pm 0.8$ &  $73.83 \pm 3.8$ &  $80.33 \pm 0.6$ &  $75.25 \pm 1.8$ \\
#           &       & \textbf{Match} &  $78.23 \pm 0.6$ &  $76.34 \pm 3.3$ &  $79.84 \pm 0.4$ &  $72.43 \pm 2.2$ &  $80.01 \pm 0.6$ &  $80.12 \pm 2.3$ \\
# \textbf{morph\_dev\_pruned} & \textbf{morph} & \textbf{Clash} &  $75.51 \pm 0.9$ &  $72.72 \pm 2.6$ &  $76.93 \pm 1.0$ &  $71.06 \pm 3.7$ &  $78.11 \pm 0.7$ &  $73.50 \pm 2.3$ \\
#           &       & \textbf{Match} &  $76.21 \pm 0.5$ &  $74.59 \pm 3.0$ &  $78.08 \pm 0.3$ &  $68.62 \pm 1.9$ &  $78.13 \pm 0.6$ &  $78.14 \pm 2.2$ \\
# \textbf{token\_dev} & \textbf{multitok} & \textbf{Clash} &  $74.62 \pm 0.9$ &  $56.17 \pm 2.1$ &  $78.13 \pm 1.3$ &  $56.18 \pm 1.1$ &  $78.16 \pm 1.2$ &  $69.71 \pm 1.4$ \\
#           &       & \textbf{Match} &  $74.26 \pm 0.8$ &  $62.79 \pm 2.4$ &  $77.02 \pm 0.8$ &  $62.90 \pm 3.1$ &  $77.52 \pm 0.9$ &  $77.58 \pm 2.6$ \\
#           & \textbf{token} & \textbf{Clash} &  $75.37 \pm 1.1$ &  $55.97 \pm 2.0$ &  $77.67 \pm 1.1$ &  $54.67 \pm 1.7$ &  $78.92 \pm 0.7$ &  $69.26 \pm 1.3$ \\
#           &       & \textbf{Match} &  $74.95 \pm 0.7$ &  $68.80 \pm 2.4$ &  $78.16 \pm 0.6$ &  $67.76 \pm 4.2$ &  $78.44 \pm 0.6$ &  $76.36 \pm 2.7$ \\
# \bottomrule
# \end{tabular}

# %%
from scipy.stats import ttest_ind

# %%
tt = (gsc[(gsc.unk_type=='Comp') & ( ((gsc.gold_name=='morph_dev_pruned')
      & (gsc.arch=='char_cnn')
      & (gsc.w_embed=='ft_oov_yap')

     )
    |
     (
        (gsc.gold_name.isin(['token_dev']))
      & (gsc.arch=='char_lstm')
      & (gsc.w_embed=='ft_oov_tok')

     ))]
)

ttest_ind(tt[tt.unit=='morph'].f, tt[tt.unit=='token'].f)
# Out:
# Ttest_indResult(statistic=2.5674395676052857, pvalue=0.01937938613779738)

# %%
(gsc[gsc.gold_name.str.contains('morph_dev')]
 .groupby(['gold_name', 'unit', 'arch', 'w_embed', 'ooev'], sort=False) 
 [['true', 'pred', 'correct']].mean().unstack()).sort_index().round(1)
# Out:
#                                               true          pred         \
# ooev                                         False  True   False  True
# gold_name        unit  arch      w_embed
# morph_dev_gold   morph char_cnn  ft_oov_tok  441.0   58.0  399.8   56.3
#                                  ft_oov_yap  434.0   65.0  385.9   63.3
#                                  ft_tok      441.0   58.0  395.9   50.3
#                                  ft_yap      434.0   65.0  379.4   50.1
#                                  glv_tok     441.0   58.0  391.8   50.0
#                                  glv_yap     434.0   65.0  386.6   54.4
#                                  no_word       NaN  499.0    NaN  331.4
#                        char_lstm ft_oov_tok  441.0   58.0  404.5   55.9
#                                  ft_oov_yap  434.0   65.0  383.6   62.4
#                                  ft_tok      441.0   58.0  400.2   48.4
#                                  ft_yap      434.0   65.0  386.5   51.4
#                                  glv_tok     441.0   58.0  402.2   51.2
#                                  glv_yap     434.0   65.0  400.6   56.1
#                                  no_word       NaN  499.0    NaN  336.5
#                        no_char   ft_oov_tok  441.0   58.0  398.3   54.7
#                                  ft_oov_yap  434.0   65.0  384.9   59.8
#                                  ft_tok      441.0   58.0  400.1   43.0
#                                  ft_yap      434.0   65.0  382.1   41.9
#                                  glv_tok     441.0   58.0  399.0   41.8
#                                  glv_yap     434.0   65.0  392.6   44.6
#                                  no_word       NaN  499.0    NaN  308.9
# morph_dev_pruned morph char_cnn  ft_oov_tok  440.0   59.0  395.3   55.3
#                                  ft_oov_yap  434.0   65.0  381.6   61.7
#                                  ft_tok      438.0   61.0  388.8   50.4
#                                  ft_yap      432.0   67.0  373.1   50.1
#                                  glv_tok     439.0   60.0  387.7   49.4
#                                  glv_yap     436.0   63.0  386.0   52.8
#                                  no_word       NaN  499.0    NaN  320.1
#                        char_lstm ft_oov_tok  440.0   59.0  398.4   53.9
#                                  ft_oov_yap  435.0   64.0  380.0   61.1
#                                  ft_tok      441.0   58.0  398.0   47.1
#                                  ft_yap      435.0   64.0  382.1   50.0
#                                  glv_tok     440.0   59.0  396.1   50.3
#                                  glv_yap     434.0   65.0  398.6   56.2
#                                  no_word       NaN  499.0    NaN  330.0
#                        no_char   ft_oov_tok  438.0   61.0  392.9   53.5
#                                  ft_oov_yap  430.0   69.0  376.0   59.3
#                                  ft_tok      441.0   58.0  391.3   41.9
#                                  ft_yap      431.0   68.0  374.0   41.4
#                                  glv_tok     440.0   59.0  391.7   39.9
#                                  glv_yap     429.0   70.0  384.3   47.2
#                                  no_word       NaN  499.0    NaN  293.1
# morph_dev_yap    morph char_cnn  ft_oov_tok  437.0   62.0  387.0   53.2
#                                  ft_oov_yap  435.0   64.0  376.6   58.1
#                                  ft_tok      437.0   62.0  386.0   47.8
#                                  ft_yap      435.0   64.0  373.6   44.2
#                                  glv_tok     437.0   62.0  385.1   46.9
#                                  glv_yap     435.0   64.0  381.3   51.0
#                                  no_word       NaN  499.0    NaN  320.4
#                        char_lstm ft_oov_tok  437.0   62.0  392.4   52.6
#                                  ft_oov_yap  435.0   64.0  374.0   56.7
#                                  ft_tok      437.0   62.0  392.7   45.4
#                                  ft_yap      435.0   64.0  381.4   45.8
#                                  glv_tok     437.0   62.0  394.5   48.6
#                                  glv_yap     435.0   64.0  395.7   52.0
#                                  no_word       NaN  499.0    NaN  325.4
#                        no_char   ft_oov_tok  437.0   62.0  385.9   51.4
#                                  ft_oov_yap  435.0   64.0  374.9   54.5
#                                  ft_tok      437.0   62.0  389.3   40.2
#                                  ft_yap      435.0   64.0  373.7   37.1
#                                  glv_tok     437.0   62.0  390.3   37.6
#                                  glv_yap     435.0   64.0  384.0   40.0
#                                  no_word       NaN  499.0    NaN  297.6
#
#                                             correct
# ooev                                          False  True
# gold_name        unit  arch      w_embed
# morph_dev_gold   morph char_cnn  ft_oov_tok   337.7   43.0
#                                  ft_oov_yap   328.0   51.4
#                                  ft_tok       335.2   40.0
#                                  ft_yap       324.7   41.7
#                                  glv_tok      325.6   41.0
#                                  glv_yap      321.1   45.6
#                                  no_word        NaN  261.7
#                        char_lstm ft_oov_tok   338.1   42.8
#                                  ft_oov_yap   326.1   50.5
#                                  ft_tok       334.6   38.8
#                                  ft_yap       326.6   42.2
#                                  glv_tok      329.0   41.8
#                                  glv_yap      328.5   47.2
#                                  no_word        NaN  262.7
#                        no_char   ft_oov_tok   337.7   41.6
#                                  ft_oov_yap   327.9   48.0
#                                  ft_tok       335.9   34.1
#                                  ft_yap       325.7   34.1
#                                  glv_tok      325.1   33.9
#                                  glv_yap      321.4   36.4
#                                  no_word        NaN  241.5
# morph_dev_pruned morph char_cnn  ft_oov_tok   326.2   42.0
#                                  ft_oov_yap   318.6   49.5
#                                  ft_tok       318.0   39.6
#                                  ft_yap       314.3   40.2
#                                  glv_tok      312.1   39.8
#                                  glv_yap      313.2   43.2
#                                  no_word        NaN  242.2
#                        char_lstm ft_oov_tok   325.0   40.7
#                                  ft_oov_yap   318.4   48.6
#                                  ft_tok       319.6   37.0
#                                  ft_yap       316.9   40.0
#                                  glv_tok      315.3   38.6
#                                  glv_yap      320.1   44.1
#                                  no_word        NaN  245.3
#                        no_char   ft_oov_tok   325.3   40.9
#                                  ft_oov_yap   314.2   45.1
#                                  ft_tok       318.6   33.0
#                                  ft_yap       316.0   32.6
#                                  glv_tok      311.6   32.3
#                                  glv_yap      309.1   34.6
#                                  no_word        NaN  219.3
# morph_dev_yap    morph char_cnn  ft_oov_tok   302.8   36.9
#                                  ft_oov_yap   295.5   43.4
#                                  ft_tok       299.9   34.0
#                                  ft_yap       291.6   34.3
#                                  glv_tok      292.3   34.2
#                                  glv_yap      289.2   36.6
#                                  no_word        NaN  232.7
#                        char_lstm ft_oov_tok   302.0   36.5
#                                  ft_oov_yap   293.4   42.5
#                                  ft_tok       298.9   33.0
#                                  ft_yap       292.4   34.3
#                                  glv_tok      294.4   35.0
#                                  glv_yap      296.6   36.9
#                                  no_word        NaN  235.2
#                        no_char   ft_oov_tok   301.2   35.6
#                                  ft_oov_yap   296.0   40.5
#                                  ft_tok       300.0   29.1
#                                  ft_yap       293.4   27.2
#                                  glv_tok      291.8   28.1
#                                  glv_yap      289.2   28.3
#                                  no_word        NaN  214.9

# %%
(gsc[gsc.gold_name.str.contains('token_dev')]
 .groupby(['gold_name', 'unit', 'arch', 'w_embed', 'ooev'], sort=False)
 .f.mean().sort_index().unstack().sort_index())
# Out:
# ooev                                        False     True
# gold_name unit     arch      w_embed
# token_dev multitok char_cnn  ft_oov_tok  0.773465  0.741613
#                              ft_oov_yap  0.781569  0.681281
#                              ft_tok      0.768752  0.612234
#                              ft_yap      0.773227  0.562520
#                              glv_tok     0.740920  0.627760
#                              glv_yap     0.752973  0.572257
#                              no_word          NaN  0.550150
#                    char_lstm ft_oov_tok  0.775198  0.775788
#                              ft_oov_yap  0.781631  0.697106
#                              ft_tok      0.770221  0.628964
#                              ft_yap      0.781301  0.561815
#                              glv_tok     0.742581  0.627882
#                              glv_yap     0.746166  0.561709
#                              no_word          NaN  0.555078
#                    no_char   ft_oov_tok  0.784532  0.760158
#                              ft_oov_yap  0.761864  0.691422
#                              ft_tok      0.777844  0.547463
#                              ft_yap      0.757022  0.504673
#                              glv_tok     0.732084  0.516589
#                              glv_yap     0.718755  0.502185
#                              no_word          NaN  0.487085
#           token    char_cnn  ft_oov_tok  0.786543  0.767509
#                              ft_oov_yap  0.792602  0.694606
#                              ft_tok      0.773597  0.655330
#                              ft_yap      0.769943  0.552841
#                              glv_tok     0.750528  0.683003
#                              glv_yap     0.751140  0.549205
#                              no_word          NaN  0.563771
#                    char_lstm ft_oov_tok  0.784439  0.763648
#                              ft_oov_yap  0.789244  0.692630
#                              ft_tok      0.781560  0.677570
#                              ft_yap      0.776668  0.546738
#                              glv_tok     0.749766  0.688014
#                              glv_yap     0.753654  0.559651
#                              no_word          NaN  0.564065
#                    no_char   ft_oov_tok  0.781285  0.729724
#                              ft_oov_yap  0.786229  0.671648
#                              ft_tok      0.772143  0.569550
#                              ft_yap      0.766293  0.515855
#                              glv_tok     0.735932  0.539780
#                              glv_yap     0.728861  0.511592
#                              no_word          NaN  0.528494

# %%
(gsc[gsc.gold_name.str.contains('dev')]
 .groupby(['gold_name', 'unit', 'arch', 'w_embed', 'ooev'], sort=False)
 .f.mean().mul(100).round(2).sort_index().unstack().sort_index())
# Out:
# ooev                                            False  True
# gold_name        unit     arch      w_embed
# morph_dev_gold   morph    char_cnn  ft_oov_tok  80.33  75.25
#                                     ft_oov_yap  80.01  80.12
#                                     ft_tok      80.11  73.83
#                                     ft_yap      79.84  72.43
#                                     glv_tok     78.19  75.88
#                                     glv_yap     78.26  76.34
#                                     no_word       NaN  63.03
#                           char_lstm ft_oov_tok  79.98  75.15
#                                     ft_oov_yap  79.77  79.28
#                                     ft_tok      79.56  72.90
#                                     ft_yap      79.61  72.49
#                                     glv_tok     78.04  76.55
#                                     glv_yap     78.72  77.96
#                                     no_word       NaN  62.89
#                           no_char   ft_oov_tok  80.47  73.82
#                                     ft_oov_yap  80.08  76.92
#                                     ft_tok      79.87  67.56
#                                     ft_yap      79.82  63.79
#                                     glv_tok     77.41  67.92
#                                     glv_yap     77.76  66.37
#                                     no_word       NaN  59.78
# morph_dev_pruned morph    char_cnn  ft_oov_tok  78.11  73.50
#                                     ft_oov_yap  78.13  78.14
#                                     ft_tok      76.93  71.06
#                                     ft_yap      78.08  68.62
#                                     glv_tok     75.51  72.72
#                                     glv_yap     76.21  74.59
#                                     no_word       NaN  59.14
#                           char_lstm ft_oov_tok  77.53  72.10
#                                     ft_oov_yap  78.13  77.70
#                                     ft_tok      76.19  70.40
#                                     ft_yap      77.57  70.15
#                                     glv_tok     75.42  70.61
#                                     glv_yap     76.90  72.80
#                                     no_word       NaN  59.19
#                           no_char   ft_oov_tok  78.30  71.44
#                                     ft_oov_yap  77.97  70.30
#                                     ft_tok      76.56  66.07
#                                     ft_yap      78.51  59.57
#                                     glv_tok     74.93  65.29
#                                     glv_yap     76.01  59.07
#                                     no_word       NaN  55.37
# morph_dev_yap    morph    char_cnn  ft_oov_tok  73.50  64.07
#                                     ft_oov_yap  72.82  71.10
#                                     ft_tok      72.88  61.92
#                                     ft_yap      72.13  63.37
#                                     glv_tok     71.11  62.76
#                                     glv_yap     70.86  63.66
#                                     no_word       NaN  56.80
#                           char_lstm ft_oov_tok  72.83  63.70
#                                     ft_oov_yap  72.53  70.42
#                                     ft_tok      72.06  61.43
#                                     ft_yap      71.63  62.49
#                                     glv_tok     70.82  63.30
#                                     glv_yap     71.41  63.64
#                                     no_word       NaN  57.07
#                           no_char   ft_oov_tok  73.21  62.78
#                                     ft_oov_yap  73.09  68.35
#                                     ft_tok      72.61  56.92
#                                     ft_yap      72.56  53.79
#                                     glv_tok     70.54  56.39
#                                     glv_yap     70.62  54.35
#                                     no_word       NaN  53.95
# token_dev        multitok char_cnn  ft_oov_tok  77.35  74.16
#                                     ft_oov_yap  78.16  68.13
#                                     ft_tok      76.88  61.22
#                                     ft_yap      77.32  56.25
#                                     glv_tok     74.09  62.78
#                                     glv_yap     75.30  57.23
#                                     no_word       NaN  55.02
#                           char_lstm ft_oov_tok  77.52  77.58
#                                     ft_oov_yap  78.16  69.71
#                                     ft_tok      77.02  62.90
#                                     ft_yap      78.13  56.18
#                                     glv_tok     74.26  62.79
#                                     glv_yap     74.62  56.17
#                                     no_word       NaN  55.51
#                           no_char   ft_oov_tok  78.45  76.02
#                                     ft_oov_yap  76.19  69.14
#                                     ft_tok      77.78  54.75
#                                     ft_yap      75.70  50.47
#                                     glv_tok     73.21  51.66
#                                     glv_yap     71.88  50.22
#                                     no_word       NaN  48.71
#                  token    char_cnn  ft_oov_tok  78.65  76.75
#                                     ft_oov_yap  79.26  69.46
#                                     ft_tok      77.36  65.53
#                                     ft_yap      76.99  55.28
#                                     glv_tok     75.05  68.30
#                                     glv_yap     75.11  54.92
#                                     no_word       NaN  56.38
#                           char_lstm ft_oov_tok  78.44  76.36
#                                     ft_oov_yap  78.92  69.26
#                                     ft_tok      78.16  67.76
#                                     ft_yap      77.67  54.67
#                                     glv_tok     74.98  68.80
#                                     glv_yap     75.37  55.97
#                                     no_word       NaN  56.41
#                           no_char   ft_oov_tok  78.13  72.97
#                                     ft_oov_yap  78.62  67.16
#                                     ft_tok      77.21  56.96
#                                     ft_yap      76.63  51.59
#                                     glv_tok     73.59  53.98
#                                     glv_yap     72.89  51.16
#                                     no_word       NaN  52.85

# %% [markdown]
# ## morpheme count
# GloVe is consistently better on tokens that were segmented into more morphemes. It is actually the only one better on 3-morpheme than 2-morpheme.

# %%
dev_unk.morpheme_count.value_counts()
# Out:
# 1    6078
# 2    2143
# 3     303
# 4       7
# Name: morpheme_count, dtype: int64

# %%
dev_unk[dev_unk.morpheme_count==4]
# Out:
#       sent_id  token_id    token_str  token_unk  morph_unk  lemma_unk  \
# 583        27        22       שבמנזר       True       True       True
# 1581       74         3   ולאינפלציה       True      False      False
# 1981       98        19  ושהאותוריטה       True       True       True
# 4853      259        24       שבעתיד       True      False      False
# 5265      279         3      שבהצבעה       True      False      False
# 6494      351        23       ובמקום       True      False      False
# 8391      487        12     וברגליים       True      False      False
#
#      unk_type  has_ner  morpheme_count
# 583        TM    False               4
# 1581        T    False               4
# 1981       TM    False               4
# 4853        T    False               4
# 5265        T    False               4
# 6494        T    False               4
# 8391        T    False               4

# %%
gsc = group_scores(scores5, groupers=[ignore, max, ignore, ignore], ment_grouper=ignore)
g = (gsc[gsc.gold_name.str.contains('dev')].fillna('x')
 .groupby(['gold_name', 'unit', 'arch', 'w_embed', 'morpheme_count'], sort=False)
 .f.mean().mul(100).round(2).unstack()).sort_index()
g.reindex(sorted(g.columns), axis=1)
# Out:
# morpheme_count                                      1      2      3      4
# gold_name        unit     arch      w_embed
# morph_dev_gold   morph    char_cnn  ft_oov_tok  83.11  75.21  75.89    0.0
#                                     ft_oov_yap  83.55  75.19  76.70    NaN
#                                     ft_tok      82.74  74.77  76.48    NaN
#                                     ft_yap      82.33  74.17  76.46    NaN
#                                     glv_tok     81.18  72.79  78.35    NaN
#                                     glv_yap     80.77  73.37  80.08    NaN
#                                     no_word     62.45  60.84  78.14    NaN
#                           char_lstm ft_oov_tok  82.13  76.01  74.67    NaN
#                                     ft_oov_yap  83.25  74.75  76.54    NaN
#                                     ft_tok      81.77  74.74  76.19    NaN
#                                     ft_yap      81.64  74.70  76.19    NaN
#                                     glv_tok     81.19  72.86  77.03    NaN
#                                     glv_yap     81.27  74.51  78.69    NaN
#                                     no_word     62.52  60.60  76.96    NaN
#                           no_char   ft_oov_tok  82.39  76.28  75.50    NaN
#                                     ft_oov_yap  82.90  75.26  76.53    NaN
#                                     ft_tok      81.13  75.41  74.27    NaN
#                                     ft_yap      79.86  75.39  76.33    NaN
#                                     glv_tok     78.96  72.20  77.93    NaN
#                                     glv_yap     78.25  73.10  79.53    NaN
#                                     no_word     55.80  61.71  77.07    NaN
# morph_dev_pruned morph    char_cnn  ft_oov_tok  81.32  72.58  72.45    NaN
#                                     ft_oov_yap  82.46  73.12  68.33    NaN
#                                     ft_tok      80.98  70.75  65.87    NaN
#                                     ft_yap      81.52  71.58  66.96    NaN
#                                     glv_tok     79.69  68.70  71.76    NaN
#                                     glv_yap     79.32  71.11  74.63    NaN
#                                     no_word     60.53  55.31  68.04    NaN
#                           char_lstm ft_oov_tok  80.19  73.64  66.07    NaN
#                                     ft_oov_yap  82.44  72.68  70.33    NaN
#                                     ft_tok      79.95  70.31  66.78    NaN
#                                     ft_yap      80.07  72.62  70.10    NaN
#                                     glv_tok     79.57  68.69  68.05    NaN
#                                     glv_yap     79.45  72.00  73.95    NaN
#                                     no_word     60.25  56.50  64.77    NaN
#                           no_char   ft_oov_tok  80.74  73.72  70.03    NaN
#                                     ft_oov_yap  81.96  69.98  70.97    NaN
#                                     ft_tok      79.81  70.53  65.20    NaN
#                                     ft_yap      79.87  72.06  68.90    NaN
#                                     glv_tok     77.68  69.07  68.03    NaN
#                                     glv_yap     77.25  68.82  73.05    NaN
#                                     no_word     54.83  55.13  60.38    NaN
# morph_dev_yap    morph    char_cnn  ft_oov_tok  78.48  63.44  66.39    0.0
#                                     ft_oov_yap  78.86  63.67  66.18    NaN
#                                     ft_tok      77.93  62.55  65.41    NaN
#                                     ft_yap      77.37  62.23  65.46    NaN
#                                     glv_tok     76.31  60.64  66.99    NaN
#                                     glv_yap     75.90  60.21  70.80    NaN
#                                     no_word     59.73  50.18  67.94    NaN
#                           char_lstm ft_oov_tok  77.07  64.07  65.49    NaN
#                                     ft_oov_yap  78.48  63.21  66.38    NaN
#                                     ft_tok      76.66  62.62  65.03    NaN
#                                     ft_yap      76.38  62.17  65.61    NaN
#                                     glv_tok     76.35  60.30  65.78    NaN
#                                     glv_yap     76.40  60.95  70.38    NaN
#                                     no_word     59.41  51.61  66.53    NaN
#                           no_char   ft_oov_tok  77.34  64.25  65.97    NaN
#                                     ft_oov_yap  78.50  63.90  66.67    NaN
#                                     ft_tok      76.44  63.32  64.42    NaN
#                                     ft_yap      75.34  63.88  64.90    NaN
#                                     glv_tok     74.25  60.85  67.60    NaN
#                                     glv_yap     73.87  60.59  69.64    NaN
#                                     no_word     53.39  51.98  67.22    NaN
# token_dev        multitok char_cnn  ft_oov_tok  80.11  71.78  76.49 -100.0
#                                     ft_oov_yap  78.50  68.32  77.75    NaN
#                                     ft_tok      78.89  68.22  74.79 -100.0
#                                     ft_yap      77.43  59.26  73.38    NaN
#                                     glv_tok     76.98  65.50  71.88  -90.0
#                                     glv_yap     75.88  58.14  73.54    NaN
#                                     no_word     57.22  49.66  64.28    NaN
#                           char_lstm ft_oov_tok  80.93  72.32  76.02 -100.0
#                                     ft_oov_yap  78.86  69.62  75.65    NaN
#                                     ft_tok      78.76  69.21  74.75 -100.0
#                                     ft_yap      78.04  60.02  72.32    NaN
#                                     glv_tok     76.53  67.13  69.31  -90.0
#                                     glv_yap     74.97  57.72  71.69    NaN
#                                     no_word     57.33  50.72  64.86    NaN
#                           no_char   ft_oov_tok  81.65  72.20  78.98 -100.0
#                                     ft_oov_yap  77.96  67.16  74.23    NaN
#                                     ft_tok      78.81  68.07  75.15 -100.0
#                                     ft_yap      73.96  58.36  72.17    NaN
#                                     glv_tok     75.18  63.05  69.76  -90.0
#                                     glv_yap     71.11  53.88  73.77    NaN
#                                     no_word     49.96  45.50  55.07    NaN
#                  token    char_cnn  ft_oov_tok  82.08  72.76  76.81 -100.0
#                                     ft_oov_yap  80.79  68.50  75.16    NaN
#                                     ft_tok      79.47  69.62  77.44 -100.0
#                                     ft_yap      76.26  60.70  71.85    NaN
#                                     glv_tok     80.45  64.25  72.08 -100.0
#                                     glv_yap     74.70  58.61  72.27    NaN
#                                     no_word     57.15  52.35  69.99    NaN
#                           char_lstm ft_oov_tok  81.96  72.25  76.87 -100.0
#                                     ft_oov_yap  80.44  68.42  74.27    NaN
#                                     ft_tok      81.11  70.29  74.13 -100.0
#                                     ft_yap      76.34  61.34  71.21    NaN
#                                     glv_tok     79.79  65.87  69.62  -90.0
#                                     glv_yap     75.36  58.88  71.43    NaN
#                                     no_word     58.28  51.68  64.90    NaN
#                           no_char   ft_oov_tok  81.48  71.23  75.37 -100.0
#                                     ft_oov_yap  79.98  66.55  75.36    NaN
#                                     ft_tok      78.64  68.58  74.33 -100.0
#                                     ft_yap      74.91  58.93  73.41    NaN
#                                     glv_tok     77.14  61.73  70.38  -90.0
#                                     glv_yap     72.03  55.45  73.26    NaN
#                                     no_word     52.39  50.63  66.70    NaN

# %%
gsc = group_scores(scores5, groupers=[ignore, lambda x: min(max(x), 2), ignore, ignore], ment_grouper=ignore, ment_cat_grouper=ignore)
gsc['cm'] = gsc.apply(get_cm, axis=1)
gsc['embed_type'] = gsc.w_embed.str.replace('_tok|_yap', '')

# %%
x = (gsc[((gsc.gold_name.isin(['morph_dev_gold','morph_dev_pruned']))
      & (gsc.arch=='char_cnn')
      & (gsc.w_embed!='no_word')
      & (gsc.cm=='Match')

     )
    |
     (
        (gsc.gold_name.isin(['token_dev']))
      & (gsc.arch=='char_lstm')
      & (gsc.w_embed!='no_word')
      & (gsc.cm=='Match')
     )]
 .groupby(['gold_name', 'unit', 'morpheme_count', 'embed_type'])
 .f.agg(['mean', 'std']).mul(100).round(2)
         .assign(mean = lambda x: '$'+x['mean'].apply('{:,.2f}'.format).astype(str)+' ± '+ x['std'].round(1).astype(str)+'$')[['mean']]
         .unstack([-2,-1]))
x.columns = x.columns.droplevel(0)
x[[(1, 'glv'), (1, 'ft'), (1, 'ft_oov'), 
   (2, 'glv'), (2, 'ft'), (2, 'ft_oov'),  ]]
# Out:
# morpheme_count                         1                                \
# embed_type                           glv             ft         ft_oov
# gold_name        unit
# morph_dev_gold   morph     $80.77 ± 0.8$  $82.33 ± 0.7$  $83.55 ± 1.2$
# morph_dev_pruned morph     $79.32 ± 0.9$  $81.52 ± 0.5$  $82.46 ± 1.2$
# token_dev        multitok  $76.53 ± 1.0$  $78.76 ± 1.3$  $80.93 ± 0.7$
#                  token     $79.79 ± 0.8$  $81.11 ± 0.4$  $81.96 ± 0.8$
#
# morpheme_count                         2
# embed_type                           glv             ft         ft_oov
# gold_name        unit
# morph_dev_gold   morph     $74.37 ± 0.7$  $74.53 ± 0.6$  $75.43 ± 0.5$
# morph_dev_pruned morph     $71.66 ± 0.5$  $70.83 ± 0.7$  $72.36 ± 0.3$
# token_dev        multitok  $67.47 ± 1.0$  $70.09 ± 1.1$  $72.89 ± 1.1$
#                  token     $66.43 ± 1.4$  $70.91 ± 0.9$  $72.97 ± 0.9$

# %%
print (x[[(1, 'glv'), (1, 'ft'), (1, 'ft_oov'), 
   (2, 'glv'), (2, 'ft'), (2, 'ft_oov'), 
]]
       .to_latex(bold_rows=True).replace('±', '\pm').replace('\$', '$'))
# Out:
# \begin{tabular}{llllllll}
# \toprule
#           & \textbf{morpheme\_count} & \multicolumn{3}{l}{1} & \multicolumn{3}{l}{2} \\
#           & \textbf{embed\_type} &            glv &             ft &         ft\_oov &            glv &             ft &         ft\_oov \\
# \textbf{gold\_name} & \textbf{unit} &                &                &                &                &                &                \\
# \midrule
# \textbf{morph\_dev\_gold} & \textbf{morph} &  $80.77 \pm 0.8$ &  $82.33 \pm 0.7$ &  $83.55 \pm 1.2$ &  $74.37 \pm 0.7$ &  $74.53 \pm 0.6$ &  $75.43 \pm 0.5$ \\
# \textbf{morph\_dev\_pruned} & \textbf{morph} &  $79.32 \pm 0.9$ &  $81.52 \pm 0.5$ &  $82.46 \pm 1.2$ &  $71.66 \pm 0.5$ &  $70.83 \pm 0.7$ &  $72.36 \pm 0.3$ \\
# \textbf{token\_dev} & \textbf{multitok} &  $76.53 \pm 1.0$ &  $78.76 \pm 1.3$ &  $80.93 \pm 0.7$ &  $67.47 \pm 1.0$ &  $70.09 \pm 1.1$ &  $72.89 \pm 1.1$ \\
#           & \textbf{token} &  $79.79 \pm 0.8$ &  $81.11 \pm 0.4$ &  $81.96 \pm 0.8$ &  $66.43 \pm 1.4$ &  $70.91 \pm 0.9$ &  $72.97 \pm 0.9$ \\
# \bottomrule
# \end{tabular}

# %%
from scipy.stats import ttest_ind

# %%
tt = (gsc[(gsc.unk_type=='Comp') & ( ((gsc.gold_name=='morph_dev_pruned')
      & (gsc.arch=='char_cnn')
      & (gsc.w_embed=='ft_oov_yap')

     )
    |
     (
        (gsc.gold_name.isin(['token_dev']))
      & (gsc.arch=='char_lstm')
      & (gsc.w_embed=='ft_oov_tok')

     ))]
)

ttest_ind(tt[tt.unit=='morph'].f, tt[tt.unit=='token'].f)
# Out:
# Ttest_indResult(statistic=2.5674395676052857, pvalue=0.01937938613779738)

# %%
gsc = group_scores(scores2, groupers=[ignore, max, ignore], ment_grouper=ignore)
g = (gsc[gsc.gold_name.str.contains('morph_dev')].fillna('x')
 .groupby(['gold_name', 'unit', 'arch', 'w_embed', 'morpheme_count'], sort=False)
 [['true', 'pred', 'correct']].mean().unstack()).sort_index().round(1)
g.reindex(sorted(g.columns), axis=1)

# %%
g = (gsc[gsc.gold_name.str.contains('token_dev')].fillna('x')
 .groupby(['gold_name', 'unit', 'arch', 'w_embed', 'morpheme_count'], sort=False)
 .f.mean().sort_index().unstack())
g.reindex(sorted(g.columns), axis=1)

# %% [markdown]
# ## Mention length

# %%
gsc = group_scores(scores4, groupers=[ignore, ignore, ignore], ment_grouper=four_up)
(gsc[gsc.gold_name.str.contains('dev')].fillna('x')
 .groupby(['gold_name', 'unit', 'arch', 'w_embed', 'ment_len'])
 .f.mean().mul(100).round(2).unstack())
# Out:
# ment_len                                            1      2      3      4
# gold_name        unit     arch      w_embed
# morph_dev_gold   morph    char_cnn  ft_oov_tok  84.66  82.72  64.99  63.72
#                                     ft_oov_yap  84.18  83.90  65.69  64.77
#                                     ft_tok      83.72  82.87  64.78  64.67
#                                     ft_yap      82.41  82.99  66.12  64.93
#                                     glv_tok     82.38  81.61  65.77  60.04
#                                     glv_yap     81.95  81.56  66.25  61.99
#                                     no_word     62.13  69.09  55.15  56.93
#                           char_lstm ft_oov_tok  83.95  82.32  64.62  64.76
#                                     ft_oov_yap  84.74  82.63  64.58  63.43
#                                     ft_tok      83.17  82.02  64.20  64.88
#                                     ft_yap      82.63  82.84  64.09  64.25
#                                     glv_tok     82.55  80.91  64.28  62.13
#                                     glv_yap     82.44  81.25  69.12  63.91
#                                     no_word     62.39  69.21  55.27  54.18
#                           no_char   ft_oov_tok  83.99  82.61  65.75  65.72
#                                     ft_oov_yap  83.98  83.08  66.47  63.81
#                                     ft_tok      81.54  82.99  65.52  65.35
#                                     ft_yap      80.29  83.09  65.90  64.88
#                                     glv_tok     79.67  81.10  65.48  59.91
#                                     glv_yap     78.78  80.99  66.68  62.85
#                                     no_word     59.99  62.95  56.51  53.74
# morph_dev_pruned morph    char_cnn  ft_oov_tok  82.97  79.97  61.08  62.70
#                                     ft_oov_yap  83.00  81.53  61.16  63.62
#                                     ft_tok      80.27  79.32  61.52  63.76
#                                     ft_yap      80.97  80.07  61.66  64.78
#                                     glv_tok     80.13  78.05  61.11  59.07
#                                     glv_yap     80.76  77.74  63.11  62.55
#                                     no_word     57.92  65.81  49.87  53.73
#                           char_lstm ft_oov_tok  81.40  79.65  61.08  63.93
#                                     ft_oov_yap  83.29  80.31  62.39  63.39
#                                     ft_tok      80.14  77.48  61.00  64.15
#                                     ft_yap      80.91  80.19  60.11  64.47
#                                     glv_tok     79.66  77.62  60.09  60.45
#                                     glv_yap     80.74  77.46  66.03  63.99
#                                     no_word     58.86  65.55  49.14  51.50
#                           no_char   ft_oov_tok  81.28  80.56  64.50  64.18
#                                     ft_oov_yap  82.02  80.90  57.06  61.93
#                                     ft_tok      77.65  79.64  62.82  65.34
#                                     ft_yap      79.18  81.55  60.42  63.54
#                                     glv_tok     77.44  77.78  62.19  59.14
#                                     glv_yap     76.76  77.18  63.59  62.12
#                                     no_word     55.19  59.18  49.63  51.01
# morph_dev_yap    morph    char_cnn  ft_oov_tok  75.45  74.62  60.89  63.04
#                                     ft_oov_yap  75.55  75.19  60.85  63.39
#                                     ft_tok      74.27  74.42  58.67  63.55
#                                     ft_yap      73.44  74.09  59.32  63.46
#                                     glv_tok     73.59  72.30  59.07  59.29
#                                     glv_yap     73.28  71.91  58.53  60.48
#                                     no_word     54.73  62.03  49.01  56.00
#                           char_lstm ft_oov_tok  74.79  73.74  59.31  63.67
#                                     ft_oov_yap  75.91  74.05  59.81  62.69
#                                     ft_tok      73.78  73.15  57.66  63.59
#                                     ft_yap      73.05  73.69  57.28  62.93
#                                     glv_tok     73.36  71.62  57.55  61.63
#                                     glv_yap     73.30  71.71  61.10  63.36
#                                     no_word     55.02  62.93  50.82  53.50
#                           no_char   ft_oov_tok  74.48  74.02  61.58  64.49
#                                     ft_oov_yap  75.64  74.51  61.66  63.25
#                                     ft_tok      72.68  74.10  59.17  64.53
#                                     ft_yap      71.57  74.60  59.38  63.91
#                                     glv_tok     70.93  72.39  60.18  59.64
#                                     glv_yap     69.95  72.03  60.70  62.01
#                                     no_word     52.36  56.50  52.71  54.02
# token_dev        multitok char_cnn  ft_oov_tok  77.80  81.14  61.69  42.78
#                                     ft_oov_yap  76.27  77.59  61.62  47.33
#                                     ft_tok      74.46  80.60  60.51  42.99
#                                     ft_yap      71.22  75.82  55.65  42.15
#                                     glv_tok     72.69  77.43  59.81  39.86
#                                     glv_yap     70.50  73.43  56.49  41.33
#                                     no_word     53.88  60.96  43.21  27.14
#                           char_lstm ft_oov_tok  78.95  81.09  61.71  43.99
#                                     ft_oov_yap  76.21  78.68  61.70  52.33
#                                     ft_tok      74.61  80.37  62.52  48.45
#                                     ft_yap      72.37  75.65  55.13  44.29
#                                     glv_tok     73.31  76.93  58.87  41.12
#                                     glv_yap     69.22  73.30  55.15  40.52
#                                     no_word     54.50  60.94  45.36  26.78
#                           no_char   ft_oov_tok  79.91  81.42  60.15  46.34
#                                     ft_oov_yap  74.97  77.76  56.13  47.37
#                                     ft_tok      75.00  80.01  57.27  45.08
#                                     ft_yap      69.57  72.51  53.79  25.72
#                                     glv_tok     70.26  76.03  56.82  33.86
#                                     glv_yap     66.03  70.25  50.25  23.18
#                                     no_word     48.53  52.34  40.87  14.63
#                  token    char_cnn  ft_oov_tok  79.75  82.34  62.61  43.86
#                                     ft_oov_yap  77.09  78.18  66.32  51.01
#                                     ft_tok      76.12  80.75  60.65  48.85
#                                     ft_yap      70.77  75.31  55.96  40.71
#                                     glv_tok     75.37  77.14  62.03  43.20
#                                     glv_yap     69.60  73.68  54.36  27.35
#                                     no_word     56.42  60.72  43.96  36.64
#                           char_lstm ft_oov_tok  79.35  82.12  62.22  47.19
#                                     ft_oov_yap  77.02  78.01  63.90  51.15
#                                     ft_tok      77.58  81.18  60.46  50.69
#                                     ft_yap      71.90  74.26  55.40  44.83
#                                     glv_tok     75.69  77.29  60.10  42.36
#                                     glv_yap     70.24  73.91  55.37  23.27
#                                     no_word     56.23  60.34  45.69  38.62
#                           no_char   ft_oov_tok  78.73  81.26  61.89  42.71
#                                     ft_oov_yap  75.62  77.64  64.02  50.89
#                                     ft_tok      74.43  80.62  58.81  47.64
#                                     ft_yap      70.21  73.46  54.47  28.88
#                                     glv_tok     70.94  76.38  59.52  37.26
#                                     glv_yap     66.06  72.36  53.18  20.17
#                                     no_word     53.92  55.47  41.06  31.84

# %%
g = (gsc[gsc.gold_name.str.contains('token_dev')].fillna('x')
 .groupby(['gold_name', 'unit', 'arch', 'w_embed', 'ment_len'], sort=False)
 .f.mean().unstack())
g.reindex(sorted(g.columns), axis=1)
# Out:
# ment_len                                        1         2         3  \
# gold_name unit     arch      w_embed
# token_dev multitok char_lstm glv_yap     0.699029  0.733733  0.555272
#                              ft_oov_yap  0.761828  0.788465  0.620608
#                              ft_yap      0.725362  0.757029  0.552000
#                              ft_oov_tok  0.784379  0.810604  0.615246
#                              no_word     0.546456  0.608189  0.455459
#                              glv_tok     0.726478  0.773129  0.586930
#                              ft_tok      0.746806  0.804697  0.611426
#                    no_char   glv_yap     0.657524  0.700506  0.498668
#                              ft_oov_yap  0.745697  0.775270  0.562606
#                              ft_yap      0.695767  0.726564  0.536864
#                              ft_oov_tok  0.803346  0.814032  0.599927
#                              no_word     0.486396  0.525734  0.405665
#                              glv_tok     0.701759  0.761577  0.568133
#                              ft_tok      0.748602  0.798457  0.573925
#                    char_cnn  glv_yap     0.698517  0.735627  0.558933
#                              ft_oov_yap  0.763519  0.776049  0.615391
#                              ft_yap      0.712203  0.758217  0.556519
#                              ft_oov_tok  0.774597  0.808944  0.626337
#                              no_word     0.541179  0.608129  0.438947
#                              glv_tok     0.729265  0.778832  0.601311
#                              ft_tok      0.741900  0.805653  0.602329
#           token    char_lstm glv_yap     0.700136  0.739657  0.556682
#                              ft_oov_yap  0.771904  0.781070  0.631965
#                              ft_yap      0.717893  0.744241  0.556784
#                              ft_oov_tok  0.793525  0.821159  0.622206
#                              no_word     0.561934  0.600432  0.448080
#                              glv_tok     0.756017  0.772499  0.602589
#                              ft_tok      0.776515  0.813706  0.600388
#                    no_char   glv_yap     0.660745  0.723062  0.538836
#                              ft_oov_yap  0.756193  0.776365  0.640224
#                              ft_yap      0.702124  0.734639  0.544667
#                              ft_oov_tok  0.789761  0.814234  0.612996
#                              no_word     0.538321  0.550956  0.410934
#                              glv_tok     0.708212  0.762532  0.614444
#                              ft_tok      0.744900  0.806901  0.591698
#                    char_cnn  glv_yap     0.696574  0.737746  0.544838
#                              ft_oov_yap  0.777077  0.777736  0.680300
#                              ft_yap      0.705519  0.753632  0.552980
#                              ft_oov_tok  0.798248  0.824216  0.625852
#                              no_word     0.566245  0.606834  0.434072
#                              glv_tok     0.751950  0.770538  0.619574
#                              ft_tok      0.762446  0.807673  0.595774
#
# ment_len                                        4
# gold_name unit     arch      w_embed
# token_dev multitok char_lstm glv_yap     0.413200
#                              ft_oov_yap  0.489524
#                              ft_yap      0.450476
#                              ft_oov_tok  0.464762
#                              no_word     0.292277
#                              glv_tok     0.389474
#                              ft_tok      0.473734
#                    no_char   glv_yap     0.188712
#                              ft_oov_yap  0.447049
#                              ft_yap      0.255766
#                              ft_oov_tok  0.486409
#                              no_word     0.151654
#                              glv_tok     0.345853
#                              ft_tok      0.451034
#                    char_cnn  glv_yap     0.411429
#                              ft_oov_yap  0.455758
#                              ft_yap      0.421536
#                              ft_oov_tok  0.483377
#                              no_word     0.291395
#                              glv_tok     0.415639
#                              ft_tok      0.424211
#           token    char_lstm glv_yap     0.272348
#                              ft_oov_yap  0.514340
#                              ft_yap      0.445184
#                              ft_oov_tok  0.471861
#                              no_word     0.389278
#                              glv_tok     0.420587
#                              ft_tok      0.503092
#                    no_char   glv_yap     0.175172
#                              ft_oov_yap  0.508903
#                              ft_yap      0.288822
#                              ft_oov_tok  0.407125
#                              no_word     0.336959
#                              glv_tok     0.353383
#                              ft_tok      0.477528
#                    char_cnn  glv_yap     0.277344
#                              ft_oov_yap  0.504348
#                              ft_yap      0.411905
#                              ft_oov_tok  0.417538
#                              no_word     0.371962
#                              glv_tok     0.447890
#                              ft_tok      0.504762

# %%
pd.set_option("max_rows", 100)
gsc[gsc.gold_name.str.contains('morph_dev')].fillna('x').groupby(['gold_name', 'unit', 'arch', 'w_embed', 'unk_type', 'ooev'], sort=False).f.mean().unstack([-1, -2])
